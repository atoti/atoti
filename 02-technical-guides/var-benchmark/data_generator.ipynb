# %% [markdown]
# # Atoti Value-at-Risk Benchmark Data Generator
#
# A data generator to simulate the data used in a [blog post by Altinity on calculating Value-at-Risk (VaR)](https://altinity.com/blog/clickhouse-vs-redshift-performance-for-fintech-risk-management).
#
# 💡 **Note:** Generating VaR benchmark data with default parameters will produce a `33GB` CSV data file and a `6.7GB` parquet data file. This may take approximately `15` minutes or more depending on your machine specifications.

# %%
import random
import string
from time import time
import numpy as np
import pandas as pd

pd.set_option("display.max_columns", 500)

# %%
# DATA GENERATOR parameters

# length of array in arrFloat column
arr_length = 1000

# number of rows in the partition 0
nb_rows = 10000

# number of partition :
# each partition is copied and modified from the previous tableset and appended to it
# max number of copied rows is 200_000
nb_part = 13

# %%
# number of distinct values in each data type
nb_cats = min(int(nb_rows**0.5), 100)
shuffle_cols = False

# Generate Dataframe
nb_cols_int, nb_cols_date, nb_cols_str = 34, 33, 33

table_spec = dict(
    **{f"int{i}": "int" for i in range(nb_cols_int)},
    **{f"dttime{i}": "datetime" for i in range(nb_cols_date)},
    **{f"str{i}": "str" for i in range(nb_cols_str)},
)

# Generate first partition of data (partition=0) in Dafaframe, without array column
myrnd = random.Random(0)
np.random.seed(0)
myrnd.seed(0)
t0 = time()
print(
    f" --> Dataframe generation with {nb_rows:,d} rows x {len(table_spec)} cols and {'no ' if arr_length==0 else f'a {arr_length}-'}array col ... ",
    end="",
)
max_int = 10**6
date_min = pd.to_datetime("2018-01-01")
date_max = pd.to_datetime("2050-12-31")


# Create categorical values for each data type ie. decoration or attributes
chars = string.ascii_letters
cats = {
    # Generate a list of nb_cats random-sized strings built from random letters & digits
    "str": [
        "".join(myrnd.choice(chars) for _ in range(x))
        for x in np.random.randint(5, 20, size=nb_cats)
    ],
    # Generate a list of nb_cats random int64s
    "int": np.random.randint(-max_int, max_int, size=nb_cats, dtype=np.int64),
    # Generate a list of nb_cats random DateTimes
    "datetime": (
        np.random.randint(
            date_min.value // 10**9,
            date_max.value // 10**9,
            size=nb_cats,
            dtype=np.int64,
        )
    )
    * 10**9,
}

# Generate data
result = pd.DataFrame(
    {
        name: (
            np.random.choice(cats[typ], size=nb_rows)
            if typ in ["str", "int"]
            else (
                np.random.choice(cats[typ], size=nb_rows).view("M8[ns]")
                if typ == "datetime"
                else np.nan
            )
        )
        for name, typ in table_spec.items()
    }
).reset_index()

# Generate arrays column
if arr_length > 0:
    result["arrFloat"] = (np.random.rand(nb_rows, arr_length) * 1e6).tolist()

# Add a partition column
result["partition"] = 0
t1 = time()
print(f" --> done in {t1-t0:.2f} sec")
print(f" --> Memory used = {result.memory_usage(deep=True).sum()/1e6:,.1f} MBytes")
# Out:
#  --> Dataframe generation with 10,000 rows x 100 cols and a 1000-array col ...  --> done in 0.18 sec
#  --> Memory used = 108.7 MBytes

# %%
# Dataset duplication, each partition recursively duplicates
# already accumulated rows (with a maximum of 200000 rows)
for part in range(1, nb_part):
    duplicate = result.copy().tail(200000)
    duplicate["partition"] = part
    result = pd.concat([result, duplicate])

print(
    f" --> Duplicated dataset generated with {len(result.index):,d} rows x {len(table_spec)} cols and {'no ' if arr_length==0 else f'a {arr_length}-'}array col ... ",
)
# Out:
#  --> Duplicated dataset generated with 1,720,000 rows x 100 cols and a 1000-array col ...

# %%
result.head()
# Out:
#    index    int0    int1    int2    int3    int4    int5    int6    int7  \
# 0      0 -138909  475712 -990641 -207047 -658155 -467426 -161629  490474
# 1      1  373476  -99861 -604366 -518622 -625686  223907  213186  989562
# 2      2  129153  824443 -676286  259508 -701633 -975223 -975223  872245
# 3      3  490474  -99861  960319 -659078  531028 -497521 -134640  259689
# 4      4 -975223 -215760 -891517  373476  194775  545390 -621960  -63768
#
#      int8    int9   int10   int11   int12   int13   int14   int15   int16  \
# 0  420514  793119  145566  319472 -161629 -161629 -227342 -147059  403368
# 1  513123 -241085 -227342  -99861 -230387  914136 -898739  319472  -59186
# 2  132931 -593941  672802 -659160  545390  513123 -604366  513123  960319
# 3  793119  139504  666654  113146  308554   62830 -667018 -467426  403368
# 4  960319  513123  234801   62216 -138909  810688 -207047  917999  113146
#
#     int17   int18   int19   int20   int21   int22   int23   int24   int25  \
# 0 -891517 -621960  213186 -604366 -667018  -59186  666654  545390   38359
# 1 -467426  132931  194775 -891517 -701633  824443  319472  113146 -241085
# 2  319472  872245  917999 -467426  186660  517543 -891517  796107  545390
# 3  872245   62216  933619  113146  672802  186660  793119 -631085  697698
# 4  673660  697698 -181783  308554 -461888 -631085 -766862  403368  697698
#
#     int26   int27   int28   int29   int30   int31   int32   int33  \
# 0 -658155 -604366 -147059 -467426  234801 -467426  810688  -63768
# 1 -658155  672802 -147059  697698  914136  145566 -701633 -181783
# 2 -604366 -241085  475712 -207047  654621  129153 -782544 -658155
# 3  697698  673660  824443   62830  373476 -134640 -891517  960319
# 4  545390  145566 -658155  914136 -230387  259689  960319  475712
#
#               dttime0             dttime1             dttime2  \
# 0 2023-03-04 13:01:59 2047-02-27 23:49:30 2023-03-04 13:01:59
# 1 2027-08-31 07:00:40 2022-07-30 12:17:58 2038-11-07 15:41:32
# 2 2037-08-06 18:59:45 2025-01-07 19:09:09 2048-08-09 05:24:11
# 3 2032-06-24 20:03:07 2035-12-06 14:24:21 2045-02-24 04:02:53
# 4 2031-05-05 00:22:11 2039-10-20 06:28:29 2025-01-19 19:12:01
#
#               dttime3             dttime4             dttime5  \
# 0 2043-04-19 09:29:10 2032-06-24 20:03:07 2047-10-20 15:33:44
# 1 2041-08-30 09:08:48 2047-11-03 22:27:02 2037-12-11 20:54:07
# 2 2037-03-24 06:24:03 2020-08-12 02:22:49 2047-04-27 09:33:34
# 3 2046-01-18 11:21:33 2035-06-26 09:26:00 2047-05-30 02:57:35
# 4 2048-02-12 00:39:46 2035-06-26 09:26:00 2039-09-25 03:50:17
#
#               dttime6             dttime7             dttime8  \
# 0 2024-06-16 02:29:16 2038-05-05 02:46:21 2025-01-07 19:09:09
# 1 2032-06-24 20:03:07 2031-02-14 12:01:08 2027-08-31 07:00:40
# 2 2028-05-13 19:14:27 2025-01-19 19:12:01 2032-02-29 04:30:21
# 3 2031-07-21 14:32:43 2037-08-06 18:59:45 2030-05-15 07:25:45
# 4 2037-12-11 20:54:07 2025-10-20 08:11:00 2047-10-20 15:33:44
#
#               dttime9            dttime10            dttime11  \
# 0 2039-10-20 06:28:29 2033-09-23 11:56:03 2022-07-09 16:36:05
# 1 2048-05-12 10:45:08 2025-10-20 08:11:00 2037-03-24 06:24:03
# 2 2033-09-23 11:56:03 2043-04-19 09:29:10 2025-01-07 19:09:09
# 3 2026-08-09 14:24:29 2032-02-29 04:30:21 2033-09-23 11:56:03
# 4 2048-08-09 05:24:11 2027-11-01 15:52:34 2037-11-16 14:35:06
#
#              dttime12            dttime13            dttime14  \
# 0 2047-10-20 15:33:44 2037-11-19 14:02:07 2032-02-29 04:30:21
# 1 2039-10-20 06:28:29 2037-04-07 17:00:51 2025-01-07 19:09:09
# 2 2027-07-10 23:23:27 2031-08-23 07:20:00 2037-08-06 18:59:45
# 3 2031-07-21 14:32:43 2041-11-17 02:58:19 2040-01-10 02:56:57
# 4 2037-08-06 18:59:45 2042-07-04 14:39:57 2037-12-11 20:54:07
#
#              dttime15            dttime16            dttime17  \
# 0 2023-01-15 09:35:01 2024-07-28 03:03:39 2035-06-26 09:26:00
# 1 2026-09-07 09:45:49 2042-09-10 08:37:23 2043-04-19 09:29:10
# 2 2026-08-09 14:24:29 2030-05-28 14:24:37 2034-03-04 00:08:04
# 3 2020-08-12 02:22:49 2031-07-21 14:32:43 2019-05-30 01:12:30
# 4 2047-12-17 19:55:50 2030-01-15 14:57:20 2036-03-01 10:38:16
#
#              dttime18            dttime19            dttime20  \
# 0 2034-01-01 00:46:34 2044-03-15 19:08:09 2045-08-05 16:59:24
# 1 2047-10-20 15:33:44 2031-08-23 07:20:00 2035-12-06 14:24:21
# 2 2022-07-30 12:17:58 2045-08-05 16:59:24 2047-11-03 22:27:02
# 3 2030-01-15 14:57:20 2023-06-16 06:27:04 2039-10-20 06:28:29
# 4 2045-02-24 04:02:53 2037-11-16 14:35:06 2023-01-15 09:35:01
#
#              dttime21            dttime22            dttime23  \
# 0 2018-03-07 20:03:02 2040-02-12 13:37:06 2041-01-25 00:38:00
# 1 2045-08-05 16:59:24 2022-07-09 16:36:05 2018-03-07 20:03:02
# 2 2034-01-01 00:46:34 2022-07-09 16:36:05 2039-10-20 06:28:29
# 3 2030-05-28 14:24:37 2034-03-04 00:08:04 2038-05-05 02:46:21
# 4 2025-01-19 19:12:01 2030-05-15 07:25:45 2048-05-12 10:45:08
#
#              dttime24            dttime25            dttime26  \
# 0 2040-01-10 02:56:57 2037-11-19 14:02:07 2022-07-30 12:17:58
# 1 2023-02-11 02:05:28 2019-02-18 08:43:07 2049-05-17 20:36:35
# 2 2047-11-03 22:27:02 2019-02-18 08:43:07 2023-06-16 06:27:04
# 3 2049-02-09 07:44:03 2035-11-05 04:12:40 2037-12-11 20:54:07
# 4 2041-11-17 02:58:19 2039-10-20 06:28:29 2037-04-07 17:00:51
#
#              dttime27            dttime28            dttime29  \
# 0 2039-01-18 13:56:44 2030-01-15 14:57:20 2032-06-24 20:03:07
# 1 2044-03-15 19:08:09 2025-01-07 19:09:09 2049-11-08 07:15:47
# 2 2042-09-10 08:37:23 2026-08-09 14:24:29 2019-02-18 08:43:07
# 3 2046-01-18 11:21:33 2047-10-20 15:33:44 2037-03-24 06:24:03
# 4 2046-01-18 11:21:33 2020-08-12 02:22:49 2043-04-19 09:29:10
#
#              dttime30            dttime31            dttime32  \
# 0 2033-08-23 08:45:34 2041-01-25 00:38:00 2044-12-08 23:07:23
# 1 2047-02-27 23:49:30 2019-05-30 01:12:30 2045-02-10 04:09:04
# 2 2043-04-19 09:29:10 2042-09-10 08:37:23 2034-01-29 01:52:47
# 3 2023-03-04 13:01:59 2040-01-10 02:56:57 2034-11-08 02:59:35
# 4 2040-02-12 13:37:06 2040-01-10 02:56:57 2039-01-18 13:56:44
#
#                 str0           str1               str2            str3  \
# 0           RjkOKyZO          jtgUe  jFMTfRSjZwAcNDyDd  CffuGFgtJsThJv
# 1  rsCxKOikhShyzLDiJ   UuTemKopZjZI     tJAVjLBtOwfpCO           EzOfb
# 2           MPmtrSlg      BfgAegAXj       gSzmqwUEKkSR  KzORBHFRuFFOQm
# 3        LrCFQPSYwfu      gBDTvykvA           DxGyHGcK       TZEeZfHce
# 4       rhJMSjYSCzlX  lDhEwTqibnxvE    ehwSbwwlaoxeMjn        xOHdyAaA
#
#                   str4             str5          str6              str7  \
# 0  nRqJuxKcVSMPFTPDOBx  TVuucHjqMYjyLsT    nIgAOIzVXY     YOeccFqbHQKKn
# 1          UuCnxsEflYg     gSzmqwUEKkSR     ofXOXGSHA  xchNarOSsUojWKsm
# 2               NsRwLO       fMZyuKpslm   PRBjCTjHuin          DxGyHGcK
# 3    KOIMRebhOmMKhzfxh       nIgAOIzVXY  LXkBmwheSbHC     JMWacFutDdZZA
# 4        NhFLOvmpbUrhT           ssJOul      YxTfvXNc          DxGyHGcK
#
#               str8          str9               str10                str11  \
# 0  anQRUhVasxSbMoj      InZMJLsC            YxTfvXNc            TZEeZfHce
# 1          lcNQqEe     BfgAegAXj  czSKAXQTckCeqSkCHF            yYXXFhdNS
# 2        lCwYyBZFy  kyjiZouGppWl        nXdYRkkvHqhM  sWRmMfceYqtIvhHpWke
# 3     UuTemKopZjZI        LfgILt        nXdYRkkvHqhM         rhJMSjYSCzlX
# 4     UuTemKopZjZI       gEXjbcM         UuCnxsEflYg             xOHdyAaA
#
#             str12                str13                str14        str15  \
# 0  mJOfUiazRAuana         RzTHrHZpnRLA               ssJOul       GthjBK
# 1       TWaRHNgmh         rhJMSjYSCzlX             RjkOKyZO  UuCnxsEflYg
# 2    dkPipsUvdcEA  CQlaERAKGtPwyQqjJSa  yagzJHsCFYLTRnBfxoq   DNOvPhRTNs
# 3    kyjiZouGppWl    rsCxKOikhShyzLDiJ             YQOaNFvp     AssHiKHO
# 4         qtXAyZy      anQRUhVasxSbMoj    KOIMRebhOmMKhzfxh        CgVqw
#
#              str16              str17                str18       str19  \
# 0            WRmhF        LrCFQPSYwfu  sWRmMfceYqtIvhHpWke      UpdtlH
# 1        yYXXFhdNS           InZMJLsC             YxTfvXNc    DxGyHGcK
# 2    oxYkvBdgYjSoc           DxGyHGcK                CgVqw      LfgILt
# 3            WRmhF  rsCxKOikhShyzLDiJ            yYXXFhdNS  fMZyuKpslm
# 4  cMbmlThEnUZdRbI    PdCtjVFdNnbwEza         RzTHrHZpnRLA       INoav
#
#               str20                str21           str22         str23  \
# 0  WzrObhrQcaqzHLTz       sxAQciMbzeSeiA       gBDTvykvA         IlnyL
# 1        iWgNZqITZM            BfgAegAXj  KzORBHFRuFFOQm      MPmtrSlg
# 2          YxTfvXNc  yagzJHsCFYLTRnBfxoq        RjkOKyZO        ssJOul
# 3            LfgILt          ePtwBldGDcM          NsRwLO     HeRfRVQza
# 4          AssHiKHO          UuCnxsEflYg  tJAVjLBtOwfpCO  LXkBmwheSbHC
#
#          str24                str25            str26        str27  \
# 0  YmcYzCxWmDw            yYXXFhdNS  ehwSbwwlaoxeMjn     YxTfvXNc
# 1     DxGyHGcK          UuCnxsEflYg    YOeccFqbHQKKn  YmcYzCxWmDw
# 2      lcNQqEe  nRqJuxKcVSMPFTPDOBx           LfgILt        INoav
# 3    lCwYyBZFy             YQOaNFvp        lCwYyBZFy    TWaRHNgmh
# 4  ePtwBldGDcM         oictaWCvkZjP           BNgqeo       zqnPcZ
#
#              str28               str29           str30                str31  \
# 0  PdCtjVFdNnbwEza       oxYkvBdgYjSoc       gBDTvykvA               BNgqeo
# 1        lCwYyBZFy             EfRFWoI  nNjgmDyxIjgMFj           fMZyuKpslm
# 2       nIgAOIzVXY  gJEEvZZvhEhSFBctvV       yYXXFhdNS  CQlaERAKGtPwyQqjJSa
# 3   sxAQciMbzeSeiA       DVfvVcIripWEw        AssHiKHO    yWAcqGFzYtEwLnGis
# 4           LfgILt   KOIMRebhOmMKhzfxh      YiyZsVRZhH          LrCFQPSYwfu
#
#              str32                                           arrFloat  \
# 0  anQRUhVasxSbMoj  [626854.9420948013, 79977.70645339353, 396823....
# 1            jtgUe  [96260.4474961476, 985831.9856156815, 459644.8...
# 2            CgVqw  [792784.0747212492, 882513.4057647634, 723408....
# 3       iWgNZqITZM  [371241.94865894347, 837067.6999089712, 402934...
# 4   sxAQciMbzeSeiA  [579798.5940131244, 639977.9452908025, 53056.7...
#
#    partition
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
# Write dataframe to a CSV file
result.to_csv("dataset.csv", index=False)

# %%
# Write dataframe to a parquet file,
# using pyarrow to specify the array column as float[].

import pyarrow as pa

schema = pa.Table.from_pandas(result, preserve_index=False).schema
new_schema = pa.schema(
    [
        f if f.name != "arrFloat" else pa.field("arrFloat", pa.list_(pa.float32()))
        for f in schema
    ]
)
result.to_parquet(
    "dataset.parquet", index=False, schema=new_schema, row_group_size=10000
)
