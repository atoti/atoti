# %% [markdown]
# # Credit Card Data Processing
#
# Welcome to the data processing notebook for the Credit Card Analytics notebook! We will be downloading, processing, and uploading files from/to the following [S3 location](https://s3.console.aws.amazon.com/s3/buckets/data.atoti.io?region=eu-west-3&bucketType=general&prefix=notebooks/retail-banking/input/&showversions=false).
#
# **[Input](https://s3.console.aws.amazon.com/s3/buckets/data.atoti.io?region=eu-west-3&bucketType=general&prefix=notebooks/retail-banking/input/&showversions=false):**
#
# * `cards.csv`
# * `credit_card_transactions.csv.gz`
# * `loan_contracts.csv`
# * `retailers.csv`
# * `users.csv`
#
# **[Data](https://s3.console.aws.amazon.com/s3/buckets/data.atoti.io?region=eu-west-3&bucketType=general&prefix=notebooks/retail-banking/data/&showversions=false)**
#
# * `cards_processed.csv` <-- created from this notebook
# * `users_processed.csv` <-- created from this notebook
# * `credit_card_transactions_processed_5MM.csv.gz` <-- created from this notebook
# * `fico.csv`
# * `loans.csv`
# * `retailers.csv`

# %% [markdown]
# <div style="text-align: center;" ><a href="https://www.atoti.io/?utm_source=gallery&utm_content=cc-data-processing" target="_blank" rel="noopener noreferrer"><img src="https://data.atoti.io/notebooks/banners/Discover-Atoti-now.png" alt="Try atoti"></a></div>

# %% [markdown]
# ## Import Libraries

# %%
import atoti
import pandas as pd
import time
import os
import numpy as np

# Create output folder containing processed files,
# Files in this directory will be added to .gitignore
outdir = "data"
if not os.path.exists(outdir):
    os.mkdir(outdir)

# %% [markdown]
# ## Process Credit Card Info Data from S3
#
# 1. [Load credit card info data from S3.](#Load-Credit-Card-Info-Data-from-S3)
# 2. [Analyze user credit card data.](#Analyze-User-Credit-Card-Data)
# 3. [Load retailer data from S3.](#Load-Retailer-Data-from-S3)
# 4. [Assign Entity Relationships for Cards-to-Retailers.](#Assign-Entity-Relationships-for-Cards-to-Retailers)
# 5. [Format Credit Card Data.](#Format-Credit-Card-Data)
# 6. [Output Credit Card Data as CSV.](#Output-Credit-Card-Data-as-CSV)

# %% [markdown]
# ### Load Credit Card Info Data from S3

# %%
orders_tbl = pd.read_csv("s3://data.atoti.io/atoti-academy/data/Orders.csv")
orders_tbl.head()
# Out:
#    OrderId  OrderDate  QuantitySold  SellingPricePerUnit     ShipperName  \
# 0        1  18/2/2019           650                22.42  Freight United
# 1        2  18/2/2019           200                 6.11      Rapid Post
# 2        3  18/2/2019           830                27.05  United Package
# 3        4  18/2/2019            14                28.01  Speedy Express
# 4        5  18/2/2019           856                 8.45      Rapid Post
#
#    ProductId  EmployeeId CustomerId
# 0        994       18336      c4411
# 1       1488       63528      c4299
# 2       1137       18594      c4747
# 3        994       63528      c2171
# 4       1449       18508      c4691

# %%
# Use `read_csv` pandas function to read from S3 URI
cc_df = pd.read_csv("s3://data.atoti.io/notebooks/retail-banking/input/cards.csv")
cc_df
# Out:
#       User  CARD INDEX  Card Brand        Card Type       Card Number  \
# 0        0           0        Visa            Debit  4344676511950444
# 1        0           1        Visa            Debit  4956965974959986
# 2        0           2        Visa            Debit  4582313478255491
# 3        0           3        Visa           Credit  4879494103069057
# 4        0           4  Mastercard  Debit (Prepaid)  5722874738736011
# ...    ...         ...         ...              ...               ...
# 6141  1997           1        Amex           Credit   300609782832003
# 6142  1997           2        Visa           Credit  4718517475996018
# 6143  1998           0  Mastercard           Credit  5929512204765914
# 6144  1999           0  Mastercard            Debit  5589768928167462
# 6145  1999           1        Visa           Credit  4994011318343994
#
#       Expires  CVV Has Chip  Cards Issued Credit Limit Acct Open Date  \
# 0     12/2022  623      YES             2       $24295        09/2002
# 1     12/2020  393      YES             2       $21968        04/2014
# 2     02/2024  719      YES             2       $46414        07/2003
# 3     08/2024  693       NO             1       $12400        01/2003
# 4     03/2009   75      YES             1          $28        09/2008
# ...       ...  ...      ...           ...          ...            ...
# 6141  01/2024  663      YES             1        $6900        11/2000
# 6142  01/2021  492      YES             2        $5700        04/2012
# 6143  08/2020  237       NO             2        $9200        02/2012
# 6144  01/2020  630      YES             1       $28074        01/2020
# 6145  12/2020  120      YES             1       $14400        05/2017
#
#       Year PIN last Changed Card on Dark Web
# 0                      2008               No
# 1                      2014               No
# 2                      2004               No
# 3                      2012               No
# 4                      2009               No
# ...                     ...              ...
# 6141                   2013               No
# 6142                   2012               No
# 6143                   2012               No
# 6144                   2020               No
# 6145                   2017               No
#
# [6146 rows x 13 columns]

# %% [markdown]
# ### Analyze User Credit Card Data

# %%
# Find the distinct credit card brands
unique_values = cc_df["Card Brand"].unique()
print(sorted(unique_values))
# Out:
# ['Amex', 'Discover', 'Mastercard', 'Visa']

# %%
# Find the distinct credit card combinations, and their frequency counts overall
cc_combinations_df = cc_df.groupby(["Card Brand", "Card Type"], as_index=False).size()
cc_combinations_df
# Out:
#    Card Brand        Card Type  size
# 0        Amex           Credit   402
# 1    Discover           Credit   209
# 2  Mastercard           Credit   635
# 3  Mastercard            Debit  2191
# 4  Mastercard  Debit (Prepaid)   383
# 5        Visa           Credit   811
# 6        Visa            Debit  1320
# 7        Visa  Debit (Prepaid)   195

# %%
# Find the distinct credit card combinations for each user, and their frequency counts
cc_combinations_df = cc_df.groupby(
    ["User", "Card Brand", "Card Type"], as_index=False
).size()
cc_combinations_df
# Out:
#       User  Card Brand        Card Type  size
# 0        0  Mastercard  Debit (Prepaid)     1
# 1        0        Visa           Credit     1
# 2        0        Visa            Debit     3
# 3        1  Mastercard            Debit     1
# 4        1  Mastercard  Debit (Prepaid)     2
# ...    ...         ...              ...   ...
# 4646  1997  Mastercard            Debit     1
# 4647  1997        Visa           Credit     1
# 4648  1998  Mastercard           Credit     1
# 4649  1999  Mastercard            Debit     1
# 4650  1999        Visa           Credit     1
#
# [4651 rows x 4 columns]

# %%
# Find the max frequency count for all distinct credit card combinations at the user level
max_cc_combinations = cc_combinations_df.groupby(
    ["Card Brand", "Card Type"], as_index=False
)["size"].max()
max_cc_combinations
# Out:
#    Card Brand        Card Type  size
# 0        Amex           Credit     4
# 1    Discover           Credit     2
# 2  Mastercard           Credit     4
# 3  Mastercard            Debit     6
# 4  Mastercard  Debit (Prepaid)     3
# 5        Visa           Credit     4
# 6        Visa            Debit     5
# 7        Visa  Debit (Prepaid)     2

# %% [markdown]
# ### Load Retailer Data from S3

# %%
# Load retailer data
cc_info = pd.read_csv("s3://data.atoti.io/notebooks/retail-banking/input/retailers.csv")
cc_info
# Out:
#     Retailer ID                                      Retailer Name  \
# 0             1                               Cathay Pacific Elite
# 1             2                                      Hilton Honors
# 2             3                             Delta SkyMiles Reserve
# 3             4                           Marriot Bonvoy Brilliant
# 4             5                                  Discover it Miles
# 5             6                                Discover it Secured
# 6             7                                           Upromise
# 7             8                                               AARP
# 8             9                                    Banana Republic
# 9            10                                     Barnes & Noble
# 10           11                                 TransferWise Debit
# 11           12                                              Venmo
# 12           13                                      Walmart Money
# 13           14                                            Revolut
# 14           15                                      Credit Sesame
# 15           16                                        Branch Card
# 16           17                          PayPal Prepaid Mastercard
# 17           18                          H&R Block Emerald Prepaid
# 18           19                    Ready Credit Prepaid Mastercard
# 19           20              Holland America LineRewards Visa Card
# 20           21                                   Princess Rewards
# 21           22                             Wyndham Rewards Earner
# 22           23                               Costco Anywhere Visa
# 23           24                                        Wells Fargo
# 24           25                                            TD Bank
# 25           26                                           Barclays
# 26           27                                    Bank of America
# 27           28                                              Chase
# 28           29                   H&R Advantage Prepaid Visa Card
# 29           30  Digital Commerce Bank Reloadable Visa Prepaid ...
#
#     Card Brand        Card Type    Level 1           Level 2         Level 3  \
# 0         Amex           Credit  Bank Corp  Consumer Banking  Cards Business
# 1         Amex           Credit  Bank Corp  Consumer Banking  Cards Business
# 2         Amex           Credit  Bank Corp  Consumer Banking  Cards Business
# 3         Amex           Credit  Bank Corp  Consumer Banking  Cards Business
# 4     Discover           Credit  Bank Corp  Consumer Banking  Cards Business
# 5     Discover           Credit  Bank Corp  Consumer Banking  Cards Business
# 6   Mastercard           Credit  Bank Corp  Consumer Banking  Cards Business
# 7   Mastercard           Credit  Bank Corp  Consumer Banking  Cards Business
# 8   Mastercard           Credit  Bank Corp  Consumer Banking  Cards Business
# 9   Mastercard           Credit  Bank Corp  Consumer Banking  Cards Business
# 10  Mastercard            Debit  Bank Corp  Consumer Banking  Cards Business
# 11  Mastercard            Debit  Bank Corp  Consumer Banking  Cards Business
# 12  Mastercard            Debit  Bank Corp  Consumer Banking  Cards Business
# 13  Mastercard            Debit  Bank Corp  Consumer Banking  Cards Business
# 14  Mastercard            Debit  Bank Corp  Consumer Banking  Cards Business
# 15  Mastercard            Debit  Bank Corp  Consumer Banking  Cards Business
# 16  Mastercard  Debit (Prepaid)  Bank Corp  Consumer Banking  Cards Business
# 17  Mastercard  Debit (Prepaid)  Bank Corp  Consumer Banking  Cards Business
# 18  Mastercard  Debit (Prepaid)  Bank Corp  Consumer Banking  Cards Business
# 19        Visa           Credit  Bank Corp  Consumer Banking  Cards Business
# 20        Visa           Credit  Bank Corp  Consumer Banking  Cards Business
# 21        Visa           Credit  Bank Corp  Consumer Banking  Cards Business
# 22        Visa           Credit  Bank Corp  Consumer Banking  Cards Business
# 23        Visa            Debit  Bank Corp  Consumer Banking  Cards Business
# 24        Visa            Debit  Bank Corp  Consumer Banking  Cards Business
# 25        Visa            Debit  Bank Corp  Consumer Banking  Cards Business
# 26        Visa            Debit  Bank Corp  Consumer Banking  Cards Business
# 27        Visa            Debit  Bank Corp  Consumer Banking  Cards Business
# 28        Visa  Debit (Prepaid)  Bank Corp  Consumer Banking  Cards Business
# 29        Visa  Debit (Prepaid)  Bank Corp  Consumer Banking  Cards Business
#
#        Level 4                 Level 5          Industry
# 0       Travel                 Airline           Airline
# 1       Travel                   Hotel             Hotel
# 2       Travel                 Airline           Airline
# 3       Travel                   Hotel             Hotel
# 4   Financials         Cards & Banking   Cards & Banking
# 5   Financials         Cards & Banking   Cards & Banking
# 6    Nonprofit               Education         Education
# 7    Nonprofit             Health Care       Health Care
# 8       Retail  Consumer Discretionary           Fashion
# 9       Retail  Consumer Discretionary             Books
# 10  Financials         Cards & Banking   Cards & Banking
# 11  Financials         Cards & Banking   Cards & Banking
# 12      Retail        Consumer Staples  Consumer Staples
# 13  Financials         Cards & Banking   Cards & Banking
# 14  Financials         Cards & Banking   Cards & Banking
# 15  Financials         Cards & Banking   Cards & Banking
# 16  Financials         Cards & Banking   Cards & Banking
# 17  Financials         Cards & Banking   Cards & Banking
# 18  Financials         Cards & Banking   Cards & Banking
# 19      Travel                  Cruise            Cruise
# 20      Travel                  Cruise            Cruise
# 21      Travel                   Hotel             Hotel
# 22      Retail        Consumer Staples  Consumer Staples
# 23  Financials         Cards & Banking   Cards & Banking
# 24  Financials         Cards & Banking   Cards & Banking
# 25  Financials         Cards & Banking   Cards & Banking
# 26  Financials         Cards & Banking   Cards & Banking
# 27  Financials         Cards & Banking   Cards & Banking
# 28  Financials         Cards & Banking   Cards & Banking
# 29  Financials         Cards & Banking   Cards & Banking

# %% [markdown]
# ### Assign Entity Relationships for Cards-to-Retailers

# %%
# Assign Retailer IDs to Card Brand, Card Type combinations
cc_dict = {
    "Amex Credit": [1, 2, 3, 4],
    "Discover Credit": [5, 6],
    "Mastercard Credit": [7, 8, 9, 10],
    "Mastercard Debit": [11, 12, 13, 14, 15, 16],
    "Mastercard Debit (Prepaid)": [17, 18, 19],
    "Visa Credit": [20, 21, 22, 23],
    "Visa Debit": [24, 25, 26, 27, 28],
    "Visa Debit (Prepaid)": [29, 30],
}

# %%
# Add the new `Retailer ID` column with empty values
cc_df.insert(2, "Retailer ID", "")
cc_df
# Out:
#       User  CARD INDEX Retailer ID  Card Brand        Card Type  \
# 0        0           0                    Visa            Debit
# 1        0           1                    Visa            Debit
# 2        0           2                    Visa            Debit
# 3        0           3                    Visa           Credit
# 4        0           4              Mastercard  Debit (Prepaid)
# ...    ...         ...         ...         ...              ...
# 6141  1997           1                    Amex           Credit
# 6142  1997           2                    Visa           Credit
# 6143  1998           0              Mastercard           Credit
# 6144  1999           0              Mastercard            Debit
# 6145  1999           1                    Visa           Credit
#
#            Card Number  Expires  CVV Has Chip  Cards Issued Credit Limit  \
# 0     4344676511950444  12/2022  623      YES             2       $24295
# 1     4956965974959986  12/2020  393      YES             2       $21968
# 2     4582313478255491  02/2024  719      YES             2       $46414
# 3     4879494103069057  08/2024  693       NO             1       $12400
# 4     5722874738736011  03/2009   75      YES             1          $28
# ...                ...      ...  ...      ...           ...          ...
# 6141   300609782832003  01/2024  663      YES             1        $6900
# 6142  4718517475996018  01/2021  492      YES             2        $5700
# 6143  5929512204765914  08/2020  237       NO             2        $9200
# 6144  5589768928167462  01/2020  630      YES             1       $28074
# 6145  4994011318343994  12/2020  120      YES             1       $14400
#
#      Acct Open Date  Year PIN last Changed Card on Dark Web
# 0           09/2002                   2008               No
# 1           04/2014                   2014               No
# 2           07/2003                   2004               No
# 3           01/2003                   2012               No
# 4           09/2008                   2009               No
# ...             ...                    ...              ...
# 6141        11/2000                   2013               No
# 6142        04/2012                   2012               No
# 6143        02/2012                   2012               No
# 6144        01/2020                   2020               No
# 6145        05/2017                   2017               No
#
# [6146 rows x 14 columns]

# %%
# Get cards for each unique user and sort by Card Brand and Card Type
# Set the Retailer ID for each user credit card, while accounting for
# Users with multiple distinct credit cards of the same Card Brand and Card Type
# ----
# UNCOMMENT PRINT STATEMENTS TO SEE GRANULAR OPERATIONS
for user in cc_df["User"].unique():
    df = cc_df.loc[cc_df["User"] == user].sort_values(by=["Card Brand", "Card Type"])
    prev_row = None

    for index, row in df.iterrows():
        cc_input = row["Card Brand"] + " " + row["Card Type"]
        distinct_count = cc_combinations_df.loc[
            (cc_combinations_df["User"] == user)
            & (cc_combinations_df["Card Brand"] == row["Card Brand"])
            & (cc_combinations_df["Card Type"] == row["Card Type"])
        ]["size"].values[0]

        if prev_row is None:
            # print("FIRST ROW AND NEW CARD FOR USER")
            num_counter = 0
            # print(f"  User {user} has a {cc_input}, and has {distinct_count} distinct cards")
            assignment = cc_dict[cc_input][num_counter]
            # print(f"    Assigning to Retailer ID... {assignment}")
            cc_df.loc[index, "Retailer ID"] = assignment
            prev_row = row

        else:
            if str(prev_row["Card Brand"]) == str(row["Card Brand"]) and str(
                prev_row["Card Type"]
            ) == str(row["Card Type"]):
                # print("SAME CARD AS PREVIOUS ROW")
                num_counter += 1
                # print(f"  User {user} has a {cc_input}, which is same as above, and has {distinct_count} distinct cards")
                assignment = cc_dict[cc_input][num_counter]
                # print(f"    Assigning to Retailer ID... {assignment}")
                cc_df.loc[index, "Retailer ID"] = assignment
                prev_row = row

            else:
                # print("NEW CARD FOR SAME USER")
                num_counter = 0
                # print(f"  User {user} has a {cc_input}, and has {distinct_count} distinct cards")
                assignment = cc_dict[cc_input][num_counter]
                # print(f"    Assigning to Retailer ID... {assignment}")
                cc_df.loc[index, "Retailer ID"] = assignment
                prev_row = row

# %%
# Check Retailer ID values have been assigned
cc_df
# Out:
#       User  CARD INDEX Retailer ID  Card Brand        Card Type  \
# 0        0           0          24        Visa            Debit
# 1        0           1          25        Visa            Debit
# 2        0           2          26        Visa            Debit
# 3        0           3          20        Visa           Credit
# 4        0           4          17  Mastercard  Debit (Prepaid)
# ...    ...         ...         ...         ...              ...
# 6141  1997           1           1        Amex           Credit
# 6142  1997           2          20        Visa           Credit
# 6143  1998           0           7  Mastercard           Credit
# 6144  1999           0          11  Mastercard            Debit
# 6145  1999           1          20        Visa           Credit
#
#            Card Number  Expires  CVV Has Chip  Cards Issued Credit Limit  \
# 0     4344676511950444  12/2022  623      YES             2       $24295
# 1     4956965974959986  12/2020  393      YES             2       $21968
# 2     4582313478255491  02/2024  719      YES             2       $46414
# 3     4879494103069057  08/2024  693       NO             1       $12400
# 4     5722874738736011  03/2009   75      YES             1          $28
# ...                ...      ...  ...      ...           ...          ...
# 6141   300609782832003  01/2024  663      YES             1        $6900
# 6142  4718517475996018  01/2021  492      YES             2        $5700
# 6143  5929512204765914  08/2020  237       NO             2        $9200
# 6144  5589768928167462  01/2020  630      YES             1       $28074
# 6145  4994011318343994  12/2020  120      YES             1       $14400
#
#      Acct Open Date  Year PIN last Changed Card on Dark Web
# 0           09/2002                   2008               No
# 1           04/2014                   2014               No
# 2           07/2003                   2004               No
# 3           01/2003                   2012               No
# 4           09/2008                   2009               No
# ...             ...                    ...              ...
# 6141        11/2000                   2013               No
# 6142        04/2012                   2012               No
# 6143        02/2012                   2012               No
# 6144        01/2020                   2020               No
# 6145        05/2017                   2017               No
#
# [6146 rows x 14 columns]

# %% [markdown]
# ### Format Credit Card Data

# %%
# Remove the `Card Brand` and `Card Type` columns
cc_df.drop(columns=["Card Brand", "Card Type"], inplace=True)

# Rename `CARD INDEX` column to `Card` to match joined `Card` column from cc_sales_gzip_df
cc_df.rename(columns={"CARD INDEX": "Card"}, inplace=True)
cc_df.head()
# Out:
#    User  Card Retailer ID       Card Number  Expires  CVV Has Chip  \
# 0     0     0          24  4344676511950444  12/2022  623      YES
# 1     0     1          25  4956965974959986  12/2020  393      YES
# 2     0     2          26  4582313478255491  02/2024  719      YES
# 3     0     3          20  4879494103069057  08/2024  693       NO
# 4     0     4          17  5722874738736011  03/2009   75      YES
#
#    Cards Issued Credit Limit Acct Open Date  Year PIN last Changed  \
# 0             2       $24295        09/2002                   2008
# 1             2       $21968        04/2014                   2014
# 2             2       $46414        07/2003                   2004
# 3             1       $12400        01/2003                   2012
# 4             1          $28        09/2008                   2009
#
#   Card on Dark Web
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No

# %%
# Cast intended measures as numerical data types
cc_df["Credit Limit"] = cc_df["Credit Limit"].str.replace("$", "")
cc_df["Credit Limit"] = cc_df["Credit Limit"].astype(int)
cc_df["Credit Limit"] = cc_df["Credit Limit"] + 50000

# %% [markdown]
# ### Output Credit Card Data as CSV

# %%
# Output DataFrame to CSV file
cc_df.to_csv(f"{outdir}/cards_processed.csv", index=False)

# %% [markdown]
# ## Process Users Data from S3
#
# 1. [Load Users Data from S3.](#Load-Users-Data-from-S3)
# 2. [Load Contracts Data from S3.](#Load-Contracts-Data-from-S3)
# 3. [Join Credit Loss Attributes to Users Data.](#Join-Credit-Loss-Attributes-to-Users-Data)
# 4. [Format Users Data.](#Format-Users-Data)
# 5. [Output Users Data as CSV.](#Output-Users-Data-as-CSV)

# %% [markdown]
# ### Load Users Data from S3

# %%
# Load users data
users_df = pd.read_csv("s3://data.atoti.io/notebooks/retail-banking/input/users.csv")
users_df = users_df.rename_axis("User").reset_index()
users_df
# Out:
#       User             Person  Current Age  Retirement Age  Birth Year  \
# 0        0     Hazel Robinson           53              66        1966
# 1        1         Sasha Sadr           53              68        1966
# 2        2         Saanvi Lee           81              67        1938
# 3        3      Everlee Clark           63              63        1957
# 4        4      Kyle Peterson           43              70        1976
# ...    ...                ...          ...             ...         ...
# 1995  1995       Jose Faraday           32              70        1987
# 1996  1996  Ximena Richardson           62              65        1957
# 1997  1997     Annika Russell           47              67        1973
# 1998  1998        Juelz Roman           66              60        1954
# 1999  1999       Kenia Harris           21              60        1998
#
#       Birth Month  Gender                   Address  Apartment           City  \
# 0              11  Female             462 Rose Lane        NaN       La Verne
# 1              12  Female    3606 Federal Boulevard        NaN    Little Neck
# 2              11  Female           766 Third Drive        NaN    West Covina
# 3               1  Female          3 Madison Street        NaN       New York
# 4               9    Male  9620 Valley Stream Drive        NaN  San Francisco
# ...           ...     ...                       ...        ...            ...
# 1995            7    Male       6577 Lexington Lane        9.0       Freeport
# 1996           11  Female               2 Elm Drive      955.0   Independence
# 1997            1  Female       276 Fifth Boulevard        NaN      Elizabeth
# 1998            2    Male      259 Valley Boulevard        NaN      Camp Hill
# 1999           11  Female     472 Ocean View Street        NaN      Merrimack
#
#      State  Zipcode  Latitude  Longitude Per Capita Income - Zipcode  \
# 0       CA    91750     34.15    -117.76                      $29278
# 1       NY    11363     40.76     -73.74                      $37891
# 2       CA    91792     34.02    -117.89                      $22681
# 3       NY    10069     40.71     -73.99                     $163145
# 4       CA    94117     37.76    -122.44                      $53797
# ...    ...      ...       ...        ...                         ...
# 1995    NY    11520     40.65     -73.58                      $23550
# 1996    KY    41051     38.95     -84.54                      $24218
# 1997    NJ     7201     40.66     -74.19                      $15175
# 1998    PA    17011     40.24     -76.92                      $25336
# 1999    NH     3054     42.86     -71.48                      $32325
#
#      Yearly Income - Person Total Debt  FICO Score  Num Credit Cards
# 0                    $59696    $127613         787                 5
# 1                    $77254    $191349         701                 5
# 2                    $33483       $196         698                 5
# 3                   $249925    $202328         722                 4
# 4                   $109687    $183855         675                 1
# ...                     ...        ...         ...               ...
# 1995                 $48010     $87837         703                 3
# 1996                 $49378    $104480         740                 4
# 1997                 $30942     $71066         779                 3
# 1998                 $54654     $27241         618                 1
# 1999                 $65909    $181261         673                 2
#
# [2000 rows x 19 columns]

# %% [markdown]
# ### Load Contracts Data from S3

# %%
# Use `read_csv` pandas function to load contracts data from S3 URI
contracts_df = pd.read_csv(
    "s3://data.atoti.io/notebooks/retail-banking/input/loan_contracts.csv",
    low_memory=False,
)
contracts_df
# Out:
#        Reporting Date           EAD      PD12      PDLT       LGD  \
# 0            12/30/22  69795.693590  0.057123  0.024117  0.607348
# 1            12/30/22  24045.796250  0.056460  0.021793  0.613929
# 2            12/30/22   2019.251356  0.017708  0.017708  0.607348
# 3            12/30/22  20563.067570  0.034836  0.154493  0.613929
# 4            12/30/22   2666.804003  0.017043  0.017043  0.613929
# ...               ...           ...       ...       ...       ...
# 336393       12/30/22    460.992072  0.041017  0.041017  0.322573
# 336394       12/30/22    116.777909  0.041017  0.041017  0.322573
# 336395       12/30/22   2461.296310  0.013934  0.063931  0.497079
# 336396       12/30/22  41522.000000  0.019270  0.038064  0.607348
# 336397       12/30/22  41031.000000  0.020043  0.038103  0.613929
#
#        Maturity Date  Residual Maturity Bucketed Arrears  Reporting Index  \
# 0            11/5/32               3597                0                2
# 1            12/5/32               3598                0                0
# 2            8/10/23                460                0              113
# 3            8/15/31               3152                0               17
# 4            5/15/24                504                0               20
# ...              ...                ...              ...              ...
# 336393      10/15/23                290           91-180               50
# 336394       6/28/23                181                0               47
# 336395        4/9/26               1168                0               44
# 336396       1/15/25                746                0               11
# 336397       1/15/25                746                0               11
#
#         Is New Contract Client ID  FICO FICO Segment LTV Segment  \
# 0                 False  9XFALYXL   300      300-410     81%-90%
# 1                  True  KHAAK99A   300      300-410        >30%
# 2                 False  AZHHTHYX   300      300-410        >30%
# 3                 False  YZAZKX99   300      300-410        >30%
# 4                 False  AZLKF9YH   300      300-410     30%-50%
# ...                 ...       ...   ...          ...         ...
# 336393            False    BN9JJQ   850      741-850     71%-80%
# 336394            False     NSJJQ   850      741-850        >30%
# 336395            False    BJGBJ9   850      741-850     81%-90%
# 336396            False  122O9E2E   850      741-850     71%-80%
# 336397            False  12242K11   850      741-850        >30%
#
#        Macro Economic Scenario   Entity
# 0                         Base    Paris
# 1                         Base    Paris
# 2                         Base    Paris
# 3                         Base    Paris
# 4                         Base    Paris
# ...                        ...      ...
# 336393                    Base  NewYork
# 336394                    Base  NewYork
# 336395                    Base  NewYork
# 336396                    Base  NewYork
# 336397                    Base  NewYork
#
# [336398 rows x 16 columns]

# %% [markdown]
# ### Join Credit Loss Attributes to Users Data

# %%
# Group by FICO and calculate the average for EAD along with other numeric values
groupby_contracts_df = contracts_df.groupby(["FICO"]).mean(["EAD"])
groupby_contracts_df.reset_index()
# Out:
#      FICO          EAD      PD12      PDLT       LGD  Residual Maturity  \
# 0     300  8980.553229  0.104477  0.155930  0.604633        1787.578864
# 1     301  9349.136091  0.112370  0.163001  0.605998        1786.359551
# 2     302  8508.016229  0.100375  0.148074  0.602229        1739.838710
# 3     303  7804.911004  0.091073  0.137547  0.598811        1727.121685
# 4     304  8688.726128  0.103132  0.154085  0.604463        1741.822476
# ..    ...          ...       ...       ...       ...                ...
# 546   846  9125.236908  0.094646  0.143602  0.600449        1820.182566
# 547   847  8643.170678  0.103138  0.149518  0.605348        1697.993681
# 548   848  7772.732491  0.097820  0.148221  0.606113        1737.099130
# 549   849  7968.876954  0.104263  0.151679  0.607293        1769.934084
# 550   850  9627.143318  0.107191  0.156488  0.602894        1759.222910
#
#      Reporting Index  Is New Contract
# 0          26.446372         0.015773
# 1          26.280899         0.028892
# 2          27.416129         0.030645
# 3          26.806552         0.031201
# 4          28.037459         0.027687
# ..               ...              ...
# 546        27.258224         0.023026
# 547        27.949447         0.018957
# 548        27.521739         0.020870
# 549        26.741158         0.030547
# 550        26.934985         0.030960
#
# [551 rows x 8 columns]

# %%
# Join both DataFrames on FICO score to consolidate credit loss attributes
merge_df = pd.merge(
    users_df, groupby_contracts_df, left_on="FICO Score", right_on="FICO"
)
merge_df
# Out:
#       User             Person  Current Age  Retirement Age  Birth Year  \
# 0        0     Hazel Robinson           53              66        1966
# 1        1         Sasha Sadr           53              68        1966
# 2        2         Saanvi Lee           81              67        1938
# 3        3      Everlee Clark           63              63        1957
# 4        4      Kyle Peterson           43              70        1976
# ...    ...                ...          ...             ...         ...
# 1995  1995       Jose Faraday           32              70        1987
# 1996  1996  Ximena Richardson           62              65        1957
# 1997  1997     Annika Russell           47              67        1973
# 1998  1998        Juelz Roman           66              60        1954
# 1999  1999       Kenia Harris           21              60        1998
#
#       Birth Month  Gender                   Address  Apartment           City  \
# 0              11  Female             462 Rose Lane        NaN       La Verne
# 1              12  Female    3606 Federal Boulevard        NaN    Little Neck
# 2              11  Female           766 Third Drive        NaN    West Covina
# 3               1  Female          3 Madison Street        NaN       New York
# 4               9    Male  9620 Valley Stream Drive        NaN  San Francisco
# ...           ...     ...                       ...        ...            ...
# 1995            7    Male       6577 Lexington Lane        9.0       Freeport
# 1996           11  Female               2 Elm Drive      955.0   Independence
# 1997            1  Female       276 Fifth Boulevard        NaN      Elizabeth
# 1998            2    Male      259 Valley Boulevard        NaN      Camp Hill
# 1999           11  Female     472 Ocean View Street        NaN      Merrimack
#
#       ... Total Debt  FICO Score  Num Credit Cards          EAD      PD12  \
# 0     ...    $127613         787                 5  7543.452009  0.102502
# 1     ...    $191349         701                 5  8943.997200  0.105292
# 2     ...       $196         698                 5  8998.056704  0.103838
# 3     ...    $202328         722                 4  8580.720752  0.109644
# 4     ...    $183855         675                 1  8866.549442  0.091900
# ...   ...        ...         ...               ...          ...       ...
# 1995  ...     $87837         703                 3  8664.685686  0.092898
# 1996  ...    $104480         740                 4  8519.702350  0.108967
# 1997  ...     $71066         779                 3  8744.786414  0.123547
# 1998  ...     $27241         618                 1  9309.286014  0.087171
# 1999  ...    $181261         673                 2  8690.146224  0.103419
#
#           PDLT       LGD  Residual Maturity  Reporting Index  Is New Contract
# 0     0.148166  0.608904        1664.486322        28.908815         0.024316
# 1     0.150311  0.602701        1747.076299        26.618506         0.038961
# 2     0.150839  0.604945        1766.742718        27.241100         0.030744
# 3     0.156455  0.606316        1764.135000        25.775000         0.033333
# 4     0.139015  0.604885        1735.427817        26.315141         0.022887
# ...        ...       ...                ...              ...              ...
# 1995  0.145718  0.604708        1842.650083        26.761194         0.024876
# 1996  0.155948  0.608552        1722.160745        27.120135         0.020305
# 1997  0.167699  0.612679        1707.018900        28.878007         0.042955
# 1998  0.136933  0.603082        1820.146774        25.424194         0.037097
# 1999  0.149235  0.604812        1785.037441        24.890796         0.037441
#
# [2000 rows x 26 columns]

# %% [markdown]
# ### Format Users Data

# %%
# View columns of combined DataFrame
merge_df.columns
# Out:
# Index(['User', 'Person', 'Current Age', 'Retirement Age', 'Birth Year',
#        'Birth Month', 'Gender', 'Address', 'Apartment', 'City', 'State',
#        'Zipcode', 'Latitude', 'Longitude', 'Per Capita Income - Zipcode',
#        'Yearly Income - Person', 'Total Debt', 'FICO Score',
#        'Num Credit Cards', 'EAD', 'PD12', 'PDLT', 'LGD', 'Residual Maturity',
#        'Reporting Index', 'Is New Contract'],
#       dtype='object')

# %%
# Remove currency symbols
merge_df["Per Capita Income - Zipcode"] = merge_df[
    "Per Capita Income - Zipcode"
].str.replace("$", "")
merge_df["Yearly Income - Person"] = merge_df["Yearly Income - Person"].str.replace(
    "$", ""
)
merge_df["Total Debt"] = merge_df["Total Debt"].str.replace("$", "")
merge_df

# Cast intended measures and numeric columns
merge_df["Per Capita Income - Zipcode"] = merge_df[
    "Per Capita Income - Zipcode"
].astype(int)
merge_df["Yearly Income - Person"] = merge_df["Yearly Income - Person"].astype(int)
merge_df["Total Debt"] = merge_df["Total Debt"].astype(int)

# %%
# Create age range bins
merge_df["Age Range"] = pd.cut(
    merge_df["Current Age"],
    [0, 10, 20, 30, 40, 50, 60, np.inf],
    labels=["0-9", "10-19", "20-29", "30-39", "40-49", "50-59", "60+"],
    right=False,
)

# Create income range bins
merge_df["Income Range"] = pd.cut(
    merge_df["Yearly Income - Person"],
    [0, 20000, 50000, 80000, 100000, 150000, 200000, np.inf],
    labels=[
        "0K - 20K",
        "20K - 50K",
        "50K - 80K",
        "80K - 100K",
        "100K - 150K",
        "150K - 200K",
        "200K+",
    ],
    right=False,
)

# %%
merge_df
# Out:
#       User             Person  Current Age  Retirement Age  Birth Year  \
# 0        0     Hazel Robinson           53              66        1966
# 1        1         Sasha Sadr           53              68        1966
# 2        2         Saanvi Lee           81              67        1938
# 3        3      Everlee Clark           63              63        1957
# 4        4      Kyle Peterson           43              70        1976
# ...    ...                ...          ...             ...         ...
# 1995  1995       Jose Faraday           32              70        1987
# 1996  1996  Ximena Richardson           62              65        1957
# 1997  1997     Annika Russell           47              67        1973
# 1998  1998        Juelz Roman           66              60        1954
# 1999  1999       Kenia Harris           21              60        1998
#
#       Birth Month  Gender                   Address  Apartment           City  \
# 0              11  Female             462 Rose Lane        NaN       La Verne
# 1              12  Female    3606 Federal Boulevard        NaN    Little Neck
# 2              11  Female           766 Third Drive        NaN    West Covina
# 3               1  Female          3 Madison Street        NaN       New York
# 4               9    Male  9620 Valley Stream Drive        NaN  San Francisco
# ...           ...     ...                       ...        ...            ...
# 1995            7    Male       6577 Lexington Lane        9.0       Freeport
# 1996           11  Female               2 Elm Drive      955.0   Independence
# 1997            1  Female       276 Fifth Boulevard        NaN      Elizabeth
# 1998            2    Male      259 Valley Boulevard        NaN      Camp Hill
# 1999           11  Female     472 Ocean View Street        NaN      Merrimack
#
#       ... Num Credit Cards          EAD      PD12      PDLT       LGD  \
# 0     ...                5  7543.452009  0.102502  0.148166  0.608904
# 1     ...                5  8943.997200  0.105292  0.150311  0.602701
# 2     ...                5  8998.056704  0.103838  0.150839  0.604945
# 3     ...                4  8580.720752  0.109644  0.156455  0.606316
# 4     ...                1  8866.549442  0.091900  0.139015  0.604885
# ...   ...              ...          ...       ...       ...       ...
# 1995  ...                3  8664.685686  0.092898  0.145718  0.604708
# 1996  ...                4  8519.702350  0.108967  0.155948  0.608552
# 1997  ...                3  8744.786414  0.123547  0.167699  0.612679
# 1998  ...                1  9309.286014  0.087171  0.136933  0.603082
# 1999  ...                2  8690.146224  0.103419  0.149235  0.604812
#
#       Residual Maturity  Reporting Index  Is New Contract  Age Range  \
# 0           1664.486322        28.908815         0.024316      50-59
# 1           1747.076299        26.618506         0.038961      50-59
# 2           1766.742718        27.241100         0.030744        60+
# 3           1764.135000        25.775000         0.033333        60+
# 4           1735.427817        26.315141         0.022887      40-49
# ...                 ...              ...              ...        ...
# 1995        1842.650083        26.761194         0.024876      30-39
# 1996        1722.160745        27.120135         0.020305        60+
# 1997        1707.018900        28.878007         0.042955      40-49
# 1998        1820.146774        25.424194         0.037097        60+
# 1999        1785.037441        24.890796         0.037441      20-29
#
#       Income Range
# 0        50K - 80K
# 1        50K - 80K
# 2        20K - 50K
# 3            200K+
# 4      100K - 150K
# ...            ...
# 1995     20K - 50K
# 1996     20K - 50K
# 1997     20K - 50K
# 1998     50K - 80K
# 1999     50K - 80K
#
# [2000 rows x 28 columns]

# %%
# Drop extraneous columns
merge_df.drop(
    columns=["Residual Maturity", "Reporting Index", "Is New Contract"], inplace=True
)

# %% [markdown]
# ### Output Users Data as CSV

# %%
merge_df.to_csv(f"{outdir}/users_processed.csv", index=False)

# %% [markdown]
# ## Process Credit Card Transactions Data from S3
#
# * [Load Credit Card Transactions Data from S3](#Load-Credit-Card-Transactions-Data-from-S3)
# * [Modify Merchant Names to be MerchantN](#Modify-Merchant-Names-to-be-MerchantN-e.g.-(Merchant1,-Merchant2,-etc.))
# * [Join New Merchant Names to Credit Card Transactions Data](#Join-New-Merchant-Names-to-Credit-Card-Transactions-Data)
# * [Drop Extraneous Columns and Format Data](#Drop-Extraneous-Columns-and-Format-Data)
# * [Format Credit Card Transactions Data](#Format-Credit-Card-Transactions-Data)
# * [Downsize Original Data Volume to 5 Million](#Downsize-Original-Data-Volume-to-5-Million)
# * [Simulate Payments](#Simulate-Payments)
# * [Output Credit Card Transactions Data to CSV](#Output-Credit-Card-Transactions-Data-to-CSV)
# * [Compress CSV to GZIP](#Compress-CSV-to-GZIP)

# %% [markdown]
# ### Load Credit Card Transactions Data from S3

# %%
# Use `read_csv` pandas function to load contracts data from S3 URI
cc_sales_gzip_df = pd.read_csv(
    "s3://data.atoti.io/notebooks/retail-banking/input/credit_card_transactions.csv.gz",
    compression="gzip",
)
cc_sales_gzip_df
# Out:
#           User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0            0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1            0     0  2002      9    1  06:42   $38.48  Swipe Transaction
# 2            0     0  2002      9    2  06:22  $120.34  Swipe Transaction
# 3            0     0  2002      9    2  17:45  $128.95  Swipe Transaction
# 4            0     0  2002      9    3  06:23  $104.71  Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...      ...                ...
# 24386895  1999     1  2020      2   27  22:23  $-54.00   Chip Transaction
# 24386896  1999     1  2020      2   27  22:24   $54.00   Chip Transaction
# 24386897  1999     1  2020      2   28  07:43   $59.15   Chip Transaction
# 24386898  1999     1  2020      2   28  20:10   $43.12   Chip Transaction
# 24386899  1999     1  2020      2   28  23:10   $45.13   Chip Transaction
#
#                 Merchant Name  Merchant City Merchant State      Zip   MCC  \
# 0         3527213246127876953       La Verne             CA  91750.0  5300
# 1         -727612092139916043  Monterey Park             CA  91754.0  5411
# 2         -727612092139916043  Monterey Park             CA  91754.0  5411
# 3         3414527459579106770  Monterey Park             CA  91754.0  5651
# 4         5817218446178736267       La Verne             CA  91750.0  5912
# ...                       ...            ...            ...      ...   ...
# 24386895 -5162038175624867091      Merrimack             NH   3054.0  5541
# 24386896 -5162038175624867091      Merrimack             NH   3054.0  5541
# 24386897  2500998799892805156      Merrimack             NH   3054.0  4121
# 24386898  2500998799892805156      Merrimack             NH   3054.0  4121
# 24386899  4751695835751691036      Merrimack             NH   3054.0  5814
#
#          Errors? Is Fraud?
# 0            NaN        No
# 1            NaN        No
# 2            NaN        No
# 3            NaN        No
# 4            NaN        No
# ...          ...       ...
# 24386895     NaN        No
# 24386896     NaN        No
# 24386897     NaN        No
# 24386898     NaN        No
# 24386899     NaN        No
#
# [24386900 rows x 15 columns]

# %% [markdown]
# ### Modify Merchant Names to be MerchantN e.g. (Merchant1, Merchant2, etc.)

# %%
merchant_name_df = pd.DataFrame(
    cc_sales_gzip_df.groupby("Merchant Name").count().index.tolist(),
    columns=["Merchant Name"],
)
merchant_name_df
# Out:
#               Merchant Name
# 0      -9222899435637403521
# 1      -9222692221935167526
# 2      -9222439367252190791
# 3      -9222264855000293132
# 4      -9222232253446715869
# ...                     ...
# 100338  9222821118491815331
# 100339  9222874644865944349
# 100340  9222877122873253163
# 100341  9222957302638210593
# 100342  9223291803303717674
#
# [100343 rows x 1 columns]

# %%
merchant_name_df.insert(1, "Merchant Name (Revised)", "")
merchant_name_df
# Out:
#               Merchant Name Merchant Name (Revised)
# 0      -9222899435637403521
# 1      -9222692221935167526
# 2      -9222439367252190791
# 3      -9222264855000293132
# 4      -9222232253446715869
# ...                     ...                     ...
# 100338  9222821118491815331
# 100339  9222874644865944349
# 100340  9222877122873253163
# 100341  9222957302638210593
# 100342  9223291803303717674
#
# [100343 rows x 2 columns]

# %%
counter = 1

for index, row in merchant_name_df.iterrows():
    name = f"Merchant {counter}"
    merchant_name_df.loc[index, "Merchant Name (Revised)"] = name
    counter += 1

# %%
merchant_name_df
# Out:
#               Merchant Name Merchant Name (Revised)
# 0      -9222899435637403521              Merchant 1
# 1      -9222692221935167526              Merchant 2
# 2      -9222439367252190791              Merchant 3
# 3      -9222264855000293132              Merchant 4
# 4      -9222232253446715869              Merchant 5
# ...                     ...                     ...
# 100338  9222821118491815331         Merchant 100339
# 100339  9222874644865944349         Merchant 100340
# 100340  9222877122873253163         Merchant 100341
# 100341  9222957302638210593         Merchant 100342
# 100342  9223291803303717674         Merchant 100343
#
# [100343 rows x 2 columns]

# %% [markdown]
# ### Join New Merchant Names to Credit Card Transactions Data

# %%
merchant_name_merge_df = pd.merge(
    cc_sales_gzip_df,
    merchant_name_df,
    left_on="Merchant Name",
    right_on="Merchant Name",
)
merchant_name_merge_df
# Out:
#           User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0            0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1            0     0  2002      9    1  06:42   $38.48  Swipe Transaction
# 2            0     0  2002      9    2  06:22  $120.34  Swipe Transaction
# 3            0     0  2002      9    2  17:45  $128.95  Swipe Transaction
# 4            0     0  2002      9    3  06:23  $104.71  Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...      ...                ...
# 24386895  1999     1  2020      2   27  22:23  $-54.00   Chip Transaction
# 24386896  1999     1  2020      2   27  22:24   $54.00   Chip Transaction
# 24386897  1999     1  2020      2   28  07:43   $59.15   Chip Transaction
# 24386898  1999     1  2020      2   28  20:10   $43.12   Chip Transaction
# 24386899  1999     1  2020      2   28  23:10   $45.13   Chip Transaction
#
#                 Merchant Name  Merchant City Merchant State      Zip   MCC  \
# 0         3527213246127876953       La Verne             CA  91750.0  5300
# 1         -727612092139916043  Monterey Park             CA  91754.0  5411
# 2         -727612092139916043  Monterey Park             CA  91754.0  5411
# 3         3414527459579106770  Monterey Park             CA  91754.0  5651
# 4         5817218446178736267       La Verne             CA  91750.0  5912
# ...                       ...            ...            ...      ...   ...
# 24386895 -5162038175624867091      Merrimack             NH   3054.0  5541
# 24386896 -5162038175624867091      Merrimack             NH   3054.0  5541
# 24386897  2500998799892805156      Merrimack             NH   3054.0  4121
# 24386898  2500998799892805156      Merrimack             NH   3054.0  4121
# 24386899  4751695835751691036      Merrimack             NH   3054.0  5814
#
#          Errors? Is Fraud? Merchant Name (Revised)
# 0            NaN        No          Merchant 69375
# 1            NaN        No          Merchant 46285
# 2            NaN        No          Merchant 46285
# 3            NaN        No          Merchant 68752
# 4            NaN        No          Merchant 81834
# ...          ...       ...                     ...
# 24386895     NaN        No          Merchant 22205
# 24386896     NaN        No          Merchant 22205
# 24386897     NaN        No          Merchant 63764
# 24386898     NaN        No          Merchant 63764
# 24386899     NaN        No          Merchant 75937
#
# [24386900 rows x 16 columns]

# %% [markdown]
# ### Drop Extraneous Columns and Format Data

# %%
merchant_name_merge_df.pop("Merchant Name")
merchant_name_merge_df.rename(
    columns={"Merchant Name (Revised)": "Merchant Name"}, inplace=True
)

merchant_name_merge_df["Year"] = merchant_name_merge_df["Year"].astype(str)
merchant_name_merge_df["Month"] = merchant_name_merge_df["Month"].astype(str)
merchant_name_merge_df["Day"] = merchant_name_merge_df["Day"].astype(str)

# Create a `Datetime` column and combine values
# From Year, Month, Day, and Time columns to
# Create a proper Datetime data type column
merchant_name_merge_df.insert(2, "Datetime", "")
merchant_name_merge_df["Datetime"] = pd.to_datetime(
    merchant_name_merge_df["Year"]
    + " "
    + merchant_name_merge_df["Month"]
    + " "
    + merchant_name_merge_df["Day"]
    + " "
    + merchant_name_merge_df["Time"]
)
merchant_name_merge_df.drop(columns=["Year", "Month", "Day", "Time"], inplace=True)
merchant_name_merge_df
# Out:
#           User  Card            Datetime   Amount           Use Chip  \
# 0            0     0 2002-09-01 06:21:00  $134.09  Swipe Transaction
# 1            0     0 2002-09-01 06:42:00   $38.48  Swipe Transaction
# 2            0     0 2002-09-02 06:22:00  $120.34  Swipe Transaction
# 3            0     0 2002-09-02 17:45:00  $128.95  Swipe Transaction
# 4            0     0 2002-09-03 06:23:00  $104.71  Swipe Transaction
# ...        ...   ...                 ...      ...                ...
# 24386895  1999     1 2020-02-27 22:23:00  $-54.00   Chip Transaction
# 24386896  1999     1 2020-02-27 22:24:00   $54.00   Chip Transaction
# 24386897  1999     1 2020-02-28 07:43:00   $59.15   Chip Transaction
# 24386898  1999     1 2020-02-28 20:10:00   $43.12   Chip Transaction
# 24386899  1999     1 2020-02-28 23:10:00   $45.13   Chip Transaction
#
#           Merchant City Merchant State      Zip   MCC Errors? Is Fraud?  \
# 0              La Verne             CA  91750.0  5300     NaN        No
# 1         Monterey Park             CA  91754.0  5411     NaN        No
# 2         Monterey Park             CA  91754.0  5411     NaN        No
# 3         Monterey Park             CA  91754.0  5651     NaN        No
# 4              La Verne             CA  91750.0  5912     NaN        No
# ...                 ...            ...      ...   ...     ...       ...
# 24386895      Merrimack             NH   3054.0  5541     NaN        No
# 24386896      Merrimack             NH   3054.0  5541     NaN        No
# 24386897      Merrimack             NH   3054.0  4121     NaN        No
# 24386898      Merrimack             NH   3054.0  4121     NaN        No
# 24386899      Merrimack             NH   3054.0  5814     NaN        No
#
#            Merchant Name
# 0         Merchant 69375
# 1         Merchant 46285
# 2         Merchant 46285
# 3         Merchant 68752
# 4         Merchant 81834
# ...                  ...
# 24386895  Merchant 22205
# 24386896  Merchant 22205
# 24386897  Merchant 63764
# 24386898  Merchant 63764
# 24386899  Merchant 75937
#
# [24386900 rows x 12 columns]

# %%
merchant_name_merge_df_revised = merchant_name_merge_df[
    [
        "User",
        "Card",
        "Datetime",
        "Amount",
        "Use Chip",
        "Merchant Name",
        "Merchant City",
        "Merchant State",
        "Zip",
        "MCC",
        "Errors?",
        "Is Fraud?",
    ]
].copy()

# %%
merchant_name_merge_df_revised
# Out:
#           User  Card            Datetime   Amount           Use Chip  \
# 0            0     0 2002-09-01 06:21:00  $134.09  Swipe Transaction
# 1            0     0 2002-09-01 06:42:00   $38.48  Swipe Transaction
# 2            0     0 2002-09-02 06:22:00  $120.34  Swipe Transaction
# 3            0     0 2002-09-02 17:45:00  $128.95  Swipe Transaction
# 4            0     0 2002-09-03 06:23:00  $104.71  Swipe Transaction
# ...        ...   ...                 ...      ...                ...
# 24386895  1999     1 2020-02-27 22:23:00  $-54.00   Chip Transaction
# 24386896  1999     1 2020-02-27 22:24:00   $54.00   Chip Transaction
# 24386897  1999     1 2020-02-28 07:43:00   $59.15   Chip Transaction
# 24386898  1999     1 2020-02-28 20:10:00   $43.12   Chip Transaction
# 24386899  1999     1 2020-02-28 23:10:00   $45.13   Chip Transaction
#
#            Merchant Name  Merchant City Merchant State      Zip   MCC Errors?  \
# 0         Merchant 69375       La Verne             CA  91750.0  5300     NaN
# 1         Merchant 46285  Monterey Park             CA  91754.0  5411     NaN
# 2         Merchant 46285  Monterey Park             CA  91754.0  5411     NaN
# 3         Merchant 68752  Monterey Park             CA  91754.0  5651     NaN
# 4         Merchant 81834       La Verne             CA  91750.0  5912     NaN
# ...                  ...            ...            ...      ...   ...     ...
# 24386895  Merchant 22205      Merrimack             NH   3054.0  5541     NaN
# 24386896  Merchant 22205      Merrimack             NH   3054.0  5541     NaN
# 24386897  Merchant 63764      Merrimack             NH   3054.0  4121     NaN
# 24386898  Merchant 63764      Merrimack             NH   3054.0  4121     NaN
# 24386899  Merchant 75937      Merrimack             NH   3054.0  5814     NaN
#
#          Is Fraud?
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ...            ...
# 24386895        No
# 24386896        No
# 24386897        No
# 24386898        No
# 24386899        No
#
# [24386900 rows x 12 columns]

# %% [markdown]
# ### Format Credit Card Transactions Data

# %%
# Cast intended measures as numerical data types
merchant_name_merge_df_revised["Amount"] = merchant_name_merge_df_revised[
    "Amount"
].str.replace("$", "")
merchant_name_merge_df_revised["Amount"] = merchant_name_merge_df_revised[
    "Amount"
].astype(float)
merchant_name_merge_df_revised["Amount"] = (
    merchant_name_merge_df_revised["Amount"] * 0.20
)

# %% [markdown]
# ### Downsize Original Data Volume to 5 Million

# %%
merchant_name_merge_df_5MM = merchant_name_merge_df_revised[19386900:]

# %% [markdown]
# ### Simulate Payments

# %%
dfupdate = merchant_name_merge_df_5MM.sample(1000000)
dfupdate.Amount *= -1
merchant_name_merge_df_5MM.update(dfupdate)
merchant_name_merge_df_5MM.head(20)
# Out:
#           User  Card            Datetime  Amount           Use Chip  \
# 19386900  1572     3 2003-01-22 20:36:00  10.974  Swipe Transaction
# 19386901  1572     3 2003-01-23 10:56:00   6.604  Swipe Transaction
# 19386902  1572     3 2003-01-23 21:01:00  12.192  Swipe Transaction
# 19386903  1572     3 2003-01-24 15:51:00  17.804  Swipe Transaction
# 19386904  1572     3 2003-01-25 11:34:00   0.814  Swipe Transaction
# 19386905  1572     3 2003-01-26 04:25:00  24.866  Swipe Transaction
# 19386906  1572     3 2003-01-29 13:35:00  20.000  Swipe Transaction
# 19386907  1572     3 2003-01-30 20:39:00  12.812  Swipe Transaction
# 19386908  1572     3 2003-01-31 20:37:00  11.714  Swipe Transaction
# 19386909  1572     3 2003-02-01 08:19:00 -24.244  Swipe Transaction
# 19386910  1572     3 2003-02-01 13:31:00   8.320  Swipe Transaction
# 19386911  1572     3 2003-02-01 13:37:00  11.400  Swipe Transaction
# 19386912  1572     3 2003-02-01 13:38:00 -11.400  Swipe Transaction
# 19386913  1572     3 2003-02-03 11:06:00  16.560  Swipe Transaction
# 19386914  1572     3 2003-02-03 13:08:00  -5.686  Swipe Transaction
# 19386915  1572     3 2003-02-03 13:45:00 -16.000  Swipe Transaction
# 19386916  1572     3 2003-02-03 21:11:00  11.916  Swipe Transaction
# 19386917  1572     3 2003-02-06 11:12:00  15.540  Swipe Transaction
# 19386918  1572     3 2003-02-07 07:34:00   0.566  Swipe Transaction
# 19386919  1572     3 2003-02-11 13:42:00 -20.000  Swipe Transaction
#
#            Merchant Name  Merchant City Merchant State      Zip   MCC Errors?  \
# 19386900  Merchant 44920      Charlotte             TN  37036.0  5814     NaN
# 19386901  Merchant 75367      Charlotte             TN  37036.0  5813     NaN
# 19386902  Merchant 22034      Charlotte             TN  37036.0  5812     NaN
# 19386903  Merchant 31884  Atlantic City             NJ   8401.0  7995     NaN
# 19386904  Merchant 99137      Charlotte             TN  37036.0  5912     NaN
# 19386905  Merchant 54851    Clarksville             TN  37042.0  4814     NaN
# 19386906  Merchant 27093       Gallatin             TN  37066.0  4829     NaN
# 19386907  Merchant 44920      Charlotte             TN  37036.0  5814     NaN
# 19386908  Merchant 22034      Charlotte             TN  37036.0  5812     NaN
# 19386909  Merchant 45681      Charlotte             TN  37036.0  8021     NaN
# 19386910  Merchant 22205     Christiana             TN  37037.0  5541     NaN
# 19386911  Merchant 22205     Christiana             TN  37037.0  5541     NaN
# 19386912  Merchant 22205     Christiana             TN  37037.0  5541     NaN
# 19386913   Merchant 1869      Charlotte             TN  37036.0  7230     NaN
# 19386914  Merchant 19965    Clarksville             TN  37040.0  5311     NaN
# 19386915  Merchant 27093       Gallatin             TN  37066.0  4829     NaN
# 19386916  Merchant 92884     Christiana             TN  37037.0  5812     NaN
# 19386917   Merchant 1869      Charlotte             TN  37036.0  7230     NaN
# 19386918  Merchant 98375    Clarksville             TN  37041.0  5411     NaN
# 19386919  Merchant 27093       Gallatin             TN  37066.0  4829     NaN
#
#          Is Fraud?
# 19386900        No
# 19386901        No
# 19386902        No
# 19386903        No
# 19386904        No
# 19386905        No
# 19386906        No
# 19386907        No
# 19386908        No
# 19386909        No
# 19386910        No
# 19386911        No
# 19386912        No
# 19386913        No
# 19386914        No
# 19386915        No
# 19386916        No
# 19386917        No
# 19386918        No
# 19386919        No

# %% [markdown]
# ### Output Credit Card Transactions Data to CSV

# %%
merchant_name_merge_df_5MM.to_csv(
    f"{outdir}/credit_card_transactions_processed_5MM.csv", index=False
)

# %% [markdown]
# ### Compress CSV to GZIP

# %%
# !gzip -f data/credit_card_transactions_processed_5MM.csv

# %% [markdown]
# ## Notes for Improvement
#
# * We can refactor the entity relationship assignment for Cards-to-Retailers.
# * We should adjust `Amount` values depending on the category of the purchase (e.g. Airline purchases should probably be over $100 at minimum).
# * We shoud make sure that no single user is over `100%` credit card utilization.
# * We should make sure that no single user is under `0%` credit card utilization.

# %% [markdown]
# <div style="text-align: center;" ><a href="https://www.atoti.io/?utm_source=gallery&utm_content=cc-data-processing" target="_blank" rel="noopener noreferrer"><img src="https://data.atoti.io/notebooks/banners/Your-turn-to-try-Atoti.jpg" alt="Try atoti"></a></div>
