# %% [markdown]
# # Credit Card Data Generator
#
# Welcome to the data generator for the Credit Card Analytics notebook! We will be downloading, processing, and uploading files from/to the following [S3 location](https://s3.console.aws.amazon.com/s3/buckets/data.atoti.io?region=eu-west-3&bucketType=general&prefix=notebooks/retail-banking/input/&showversions=false).
#
# **[Input](https://s3.console.aws.amazon.com/s3/buckets/data.atoti.io?region=eu-west-3&bucketType=general&prefix=notebooks/retail-banking/input/&showversions=false):**
#
# * `cards.csv`
# * `users.csv`
# * `credit_card_transactions.csv.gz`
#
# **[Output](https://s3.console.aws.amazon.com/s3/buckets/data.atoti.io?region=eu-west-3&bucketType=general&prefix=notebooks/retail-banking/data/&showversions=false)**
#
# * `cards_processed.csv` <-- created from this notebook
# * `users_processed.csv` <-- created from this notebook
# * `credit_card_transactions_processed_5MM.csv.gz` <-- created from this notebook

# %% [markdown]
# <div style="text-align: center;" ><a href="https://www.atoti.io/?utm_source=gallery&utm_content=cc-data-generator" target="_blank" rel="noopener noreferrer"><img src="https://data.atoti.io/notebooks/banners/Discover-Atoti-now.png" alt="Try atoti"></a></div>

# %% [markdown]
# ## Import Libraries

# %%
import atoti
import pandas as pd
import time
import os
import numpy as np
from datetime import datetime

# Set max rows and columns for DataFrame
pd.options.display.max_rows = 10000
pd.options.display.max_columns = 10000

# Create output folder containing processed files,
# Files in this directory will be added to .gitignore
outdir = "data"
if not os.path.exists(outdir):
    os.mkdir(outdir)

# %% [markdown]
# ## Process Credit Card Data from S3
#
# 1. [Load credit card info data from S3.](#Load-Credit-Card-Info-Data-from-S3)
# 2. [Format Credit Card Data.](#Format-Credit-Card-Data)
# 3. [Assign Entity Relationships for Cards-to-Retailers.](#Assign-Entity-Relationships-for-Cards-to-Retailers)
# 4. [Output Credit Card Data as CSV.](#Output-Credit-Card-Data-as-CSV)

# %% [markdown]
# ### Load Credit Card Info Data from S3

# %%
# Use `read_csv` pandas function to read from S3 URI
cc_df = pd.read_csv("s3://data.atoti.io/notebooks/retail-banking/input/cards.csv")
cc_df.head()
# Out:
#    User  CARD INDEX  Card Brand        Card Type       Card Number  Expires  \
# 0     0           0        Visa            Debit  4344676511950444  12/2022
# 1     0           1        Visa            Debit  4956965974959986  12/2020
# 2     0           2        Visa            Debit  4582313478255491  02/2024
# 3     0           3        Visa           Credit  4879494103069057  08/2024
# 4     0           4  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
#
#    CVV Has Chip  Cards Issued Credit Limit Acct Open Date  \
# 0  623      YES             2       $24295        09/2002
# 1  393      YES             2       $21968        04/2014
# 2  719      YES             2       $46414        07/2003
# 3  693       NO             1       $12400        01/2003
# 4   75      YES             1          $28        09/2008
#
#    Year PIN last Changed Card on Dark Web
# 0                   2008               No
# 1                   2014               No
# 2                   2004               No
# 3                   2012               No
# 4                   2009               No

# %% [markdown]
# ### Assign Entity Relationships for Cards-to-Retailers

# %%
# Find the distinct credit card brands
unique_values = cc_df["Card Brand"].unique()
print(sorted(unique_values))
# Out:
# ['Amex', 'Discover', 'Mastercard', 'Visa']

# %%
# Find the distinct credit card combinations, and their frequency counts overall
cc_combinations_df = cc_df.groupby(["Card Brand", "Card Type"], as_index=False).size()
cc_combinations_df
# Out:
#    Card Brand        Card Type  size
# 0        Amex           Credit   402
# 1    Discover           Credit   209
# 2  Mastercard           Credit   635
# 3  Mastercard            Debit  2191
# 4  Mastercard  Debit (Prepaid)   383
# 5        Visa           Credit   811
# 6        Visa            Debit  1320
# 7        Visa  Debit (Prepaid)   195

# %%
# Find the distinct credit card combinations for each user, and their frequency counts
cc_combinations_df = cc_df.groupby(
    ["User", "Card Brand", "Card Type"], as_index=False
).size()
cc_combinations_df
# Out:
#       User  Card Brand        Card Type  size
# 0        0  Mastercard  Debit (Prepaid)     1
# 1        0        Visa           Credit     1
# 2        0        Visa            Debit     3
# 3        1  Mastercard            Debit     1
# 4        1  Mastercard  Debit (Prepaid)     2
# ...    ...         ...              ...   ...
# 4646  1997  Mastercard            Debit     1
# 4647  1997        Visa           Credit     1
# 4648  1998  Mastercard           Credit     1
# 4649  1999  Mastercard            Debit     1
# 4650  1999        Visa           Credit     1
#
# [4651 rows x 4 columns]

# %%
# Find the max frequency count for all distinct credit card combinations at the user level
max_cc_combinations = cc_combinations_df.groupby(
    ["Card Brand", "Card Type"], as_index=False
)["size"].max()
max_cc_combinations
# Out:
#    Card Brand        Card Type  size
# 0        Amex           Credit     4
# 1    Discover           Credit     2
# 2  Mastercard           Credit     4
# 3  Mastercard            Debit     6
# 4  Mastercard  Debit (Prepaid)     3
# 5        Visa           Credit     4
# 6        Visa            Debit     5
# 7        Visa  Debit (Prepaid)     2

# %%
# Load retailer data
cc_info = pd.read_csv("s3://data.atoti.io/notebooks/retail-banking/input/retailers.csv")
cc_info.head()
# Out:
#    Retailer ID             Retailer Name Card Brand Card Type    Level 1  \
# 0            1      Cathay Pacific Elite       Amex    Credit  Bank Corp
# 1            2             Hilton Honors       Amex    Credit  Bank Corp
# 2            3    Delta SkyMiles Reserve       Amex    Credit  Bank Corp
# 3            4  Marriot Bonvoy Brilliant       Amex    Credit  Bank Corp
# 4            5         Discover it Miles   Discover    Credit  Bank Corp
#
#             Level 2         Level 3     Level 4          Level 5  \
# 0  Consumer Banking  Cards Business      Travel          Airline
# 1  Consumer Banking  Cards Business      Travel            Hotel
# 2  Consumer Banking  Cards Business      Travel          Airline
# 3  Consumer Banking  Cards Business      Travel            Hotel
# 4  Consumer Banking  Cards Business  Financials  Cards & Banking
#
#           Industry
# 0          Airline
# 1            Hotel
# 2          Airline
# 3            Hotel
# 4  Cards & Banking

# %%
from utils.assign_retailers import assign_retailers

# Add the new `Retailer ID` column with empty values
cc_df.insert(2, "Retailer ID", "")

# Assign Retailer ID values and check
cc_df = assign_retailers(cc_df, cc_combinations_df)
cc_df
# Out:
#       User  CARD INDEX Retailer ID  Card Brand        Card Type  \
# 0        0           0          24        Visa            Debit
# 1        0           1          25        Visa            Debit
# 2        0           2          26        Visa            Debit
# 3        0           3          20        Visa           Credit
# 4        0           4          17  Mastercard  Debit (Prepaid)
# ...    ...         ...         ...         ...              ...
# 6141  1997           1           1        Amex           Credit
# 6142  1997           2          20        Visa           Credit
# 6143  1998           0           7  Mastercard           Credit
# 6144  1999           0          11  Mastercard            Debit
# 6145  1999           1          20        Visa           Credit
#
#            Card Number  Expires  CVV Has Chip  Cards Issued Credit Limit  \
# 0     4344676511950444  12/2022  623      YES             2       $24295
# 1     4956965974959986  12/2020  393      YES             2       $21968
# 2     4582313478255491  02/2024  719      YES             2       $46414
# 3     4879494103069057  08/2024  693       NO             1       $12400
# 4     5722874738736011  03/2009   75      YES             1          $28
# ...                ...      ...  ...      ...           ...          ...
# 6141   300609782832003  01/2024  663      YES             1        $6900
# 6142  4718517475996018  01/2021  492      YES             2        $5700
# 6143  5929512204765914  08/2020  237       NO             2        $9200
# 6144  5589768928167462  01/2020  630      YES             1       $28074
# 6145  4994011318343994  12/2020  120      YES             1       $14400
#
#      Acct Open Date  Year PIN last Changed Card on Dark Web
# 0           09/2002                   2008               No
# 1           04/2014                   2014               No
# 2           07/2003                   2004               No
# 3           01/2003                   2012               No
# 4           09/2008                   2009               No
# ...             ...                    ...              ...
# 6141        11/2000                   2013               No
# 6142        04/2012                   2012               No
# 6143        02/2012                   2012               No
# 6144        01/2020                   2020               No
# 6145        05/2017                   2017               No
#
# [6146 rows x 14 columns]

# %% [markdown]
# ### Format Credit Card Data

# %%
# Remove the `Card Brand` and `Card Type` columns
cc_df.drop(columns=["Card Brand", "Card Type"], inplace=True)

# Rename `CARD INDEX` column to `Card` to match joined `Card` column from cc_sales_gzip_df
cc_df.rename(columns={"CARD INDEX": "Card"}, inplace=True)

# Cast `Acct Open Date` as Datetime
cc_df["Acct Open Date"] = pd.to_datetime(cc_df["Acct Open Date"], format="%m/%Y")

# Insert `Age of Account` (in Years)
cc_df.insert(11, "Age of Account", "")
current_datetime = datetime.now()
cc_df["Age of Account"] = (current_datetime - cc_df["Acct Open Date"]).dt.days // 365

# Cast intended measures as numerical data types
cc_df["Credit Limit"] = cc_df["Credit Limit"].str.replace("$", "")
cc_df["Credit Limit"] = cc_df["Credit Limit"].astype(int)
cc_df["Credit Limit"] = cc_df["Credit Limit"] + 50000

cc_df.head()
# Out:
#    User  Card Retailer ID       Card Number  Expires  CVV Has Chip  \
# 0     0     0          24  4344676511950444  12/2022  623      YES
# 1     0     1          25  4956965974959986  12/2020  393      YES
# 2     0     2          26  4582313478255491  02/2024  719      YES
# 3     0     3          20  4879494103069057  08/2024  693       NO
# 4     0     4          17  5722874738736011  03/2009   75      YES
#
#    Cards Issued  Credit Limit Acct Open Date  Year PIN last Changed  \
# 0             2         74295     2002-09-01                   2008
# 1             2         71968     2014-04-01                   2014
# 2             2         96414     2003-07-01                   2004
# 3             1         62400     2003-01-01                   2012
# 4             1         50028     2008-09-01                   2009
#
#    Age of Account Card on Dark Web
# 0              21               No
# 1              10               No
# 2              21               No
# 3              21               No
# 4              15               No

# %%
import numpy as np

# Define the simulation parameters
np.random.seed(42)  # For reproducibility

# Generate payment data
payment_data = []

for index, row in cc_df.iterrows():
    account_age_years = row["Age of Account"]
    credit_limit = row["Credit Limit"]
    acct_open_date = row["Acct Open Date"]

    # Determine the number of payments (one per month for each year)
    num_payments = account_age_years * 12

    # Generate random dates for payments
    payment_dates = pd.date_range(start=acct_open_date, periods=num_payments, freq="M")

    # Generate random payment amounts (some delinquent, some default)
    for date in payment_dates:
        if np.random.rand() < 0.1:  # 10% chance of delinquent payment
            payment_amount = np.random.uniform(0.01, 0.5) * credit_limit
            status = "Delinquent"
        elif np.random.rand() < 0.05:  # 5% chance of default
            payment_amount = 0
            status = "Default"
        else:
            payment_amount = np.random.uniform(0.5, 1.0) * credit_limit
            status = "On Time"

        payment_data.append(
            {
                "User": row["User"],
                "Card": row["Card"],
                "Payment Date": date,
                "Payment Amount": payment_amount,
                "Payment Status": status,
            }
        )

# Create a dataframe for the payment data
payment_df = pd.DataFrame(payment_data)

# import ace_tools as tools; tools.display_dataframe_to_user(name="Simulated Payments Data", dataframe=payment_df)

# Display the first few rows of the payment data
payment_df.head(n=10000)
# Out:
#       User  Card Payment Date  Payment Amount Payment Status
# 0        0     0   2002-09-30    64339.244953        On Time
# 1        0     0   2002-10-31    42942.306444        On Time
# 2        0     0   2002-11-30    32275.702808     Delinquent
# 3        0     0   2002-12-31    37912.162502        On Time
# 4        0     0   2003-01-31    45035.367114        On Time
# 5        0     0   2003-02-28    48449.338720        On Time
# 6        0     0   2003-03-31    47965.934486        On Time
# 7        0     0   2003-04-30    47999.943331        On Time
# 8        0     0   2003-05-31    66314.824026        On Time
# 9        0     0   2003-06-30    59154.220197        On Time
# 10       0     0   2003-07-31    22860.346938     Delinquent
# 11       0     0   2003-08-31    72396.225495        On Time
# 12       0     0   2003-09-30    48463.139990        On Time
# 13       0     0   2003-10-31    25652.145425     Delinquent
# 14       0     0   2003-11-30    55542.084268        On Time
# 15       0     0   2003-12-31    33846.350043     Delinquent
# 16       0     0   2004-01-31    48726.787199        On Time
# 17       0     0   2004-02-29    44014.380887        On Time
# 18       0     0   2004-03-31    72047.536932        On Time
# 19       0     0   2004-04-30    71392.823146        On Time
# 20       0     0   2004-05-31     7877.617914     Delinquent
# 21       0     0   2004-06-30    12586.454293     Delinquent
# 22       0     0   2004-07-31    67933.026621        On Time
# 23       0     0   2004-08-31    57307.302749        On Time
# 24       0     0   2004-09-30    39916.870036        On Time
# 25       0     0   2004-10-31    44529.290780        On Time
# 26       0     0   2004-11-30    30429.456345     Delinquent
# 27       0     0   2004-12-31    65798.265204        On Time
# 28       0     0   2005-01-31    13792.733538     Delinquent
# 29       0     0   2005-02-28    60301.467166        On Time
# 30       0     0   2005-03-31    48699.715796        On Time
# 31       0     0   2005-04-30    60831.166167        On Time
# 32       0     0   2005-05-31    41590.127251        On Time
# 33       0     0   2005-06-30    57997.544697        On Time
# 34       0     0   2005-07-31    56565.717779        On Time
# 35       0     0   2005-08-31        0.000000        Default
# 36       0     0   2005-09-30        0.000000        Default
# 37       0     0   2005-10-31    56039.629750        On Time
# 38       0     0   2005-11-30    52392.199633        On Time
# 39       0     0   2005-12-31    40007.111200        On Time
# 40       0     0   2006-01-31    71683.443540        On Time
# 41       0     0   2006-02-28    69520.082274        On Time
# 42       0     0   2006-03-31    70303.835396        On Time
# 43       0     0   2006-04-30    70435.051564        On Time
# 44       0     0   2006-05-31    45614.721451        On Time
# 45       0     0   2006-06-30    69121.489342        On Time
# 46       0     0   2006-07-31    19336.475714     Delinquent
# 47       0     0   2006-08-31    41600.198733        On Time
# 48       0     0   2006-09-30    49153.680917        On Time
# 49       0     0   2006-10-31    50655.430654        On Time
# 50       0     0   2006-11-30    46500.582834        On Time
# 51       0     0   2006-12-31    47728.612265        On Time
# 52       0     0   2007-01-31    22933.865275     Delinquent
# 53       0     0   2007-02-28    47498.519530        On Time
# 54       0     0   2007-03-31    42529.982261        On Time
# 55       0     0   2007-04-30    46139.248198        On Time
# 56       0     0   2007-05-31    45975.140665        On Time
# 57       0     0   2007-06-30    60636.080842        On Time
# 58       0     0   2007-07-31    40501.539233        On Time
# 59       0     0   2007-08-31    44076.196365        On Time
# 60       0     0   2007-09-30    22254.141695     Delinquent
# 61       0     0   2007-10-31        0.000000        Default
# 62       0     0   2007-11-30    61114.056232        On Time
# 63       0     0   2007-12-31    51513.751277        On Time
# 64       0     0   2008-01-31    49817.262276        On Time
# 65       0     0   2008-02-29    69738.463630        On Time
# 66       0     0   2008-03-31    67505.261682        On Time
# 67       0     0   2008-04-30    46131.707976        On Time
# 68       0     0   2008-05-31    33405.685921     Delinquent
# 69       0     0   2008-06-30    49741.609163        On Time
# 70       0     0   2008-07-31    70472.903382        On Time
# 71       0     0   2008-08-31    60997.370576        On Time
# 72       0     0   2008-09-30     6626.970604     Delinquent
# 73       0     0   2008-10-31    37489.147475        On Time
# 74       0     0   2008-11-30    37335.525186        On Time
# 75       0     0   2008-12-31    62849.676856        On Time
# 76       0     0   2009-01-31    63603.177625        On Time
# 77       0     0   2009-02-28    64877.789472        On Time
# 78       0     0   2009-03-31    61576.174917        On Time
# 79       0     0   2009-04-30    50807.222794        On Time
# 80       0     0   2009-05-31    73292.409583        On Time
# 81       0     0   2009-06-30    60592.722109        On Time
# 82       0     0   2009-07-31    58578.037054        On Time
# 83       0     0   2009-08-31    63984.789952        On Time
# 84       0     0   2009-09-30        0.000000        Default
# 85       0     0   2009-10-31    72083.185262        On Time
# 86       0     0   2009-11-30    50897.970318        On Time
# 87       0     0   2009-12-31    34537.969528     Delinquent
# 88       0     0   2010-01-31    72943.573099        On Time
# 89       0     0   2010-02-28    51452.917873        On Time
# 90       0     0   2010-03-31    43443.731808        On Time
# 91       0     0   2010-04-30    63003.266872        On Time
# 92       0     0   2010-05-31    59993.480954        On Time
# 93       0     0   2010-06-30    56402.150761        On Time
# 94       0     0   2010-07-31    63039.892239        On Time
# 95       0     0   2010-08-31    48053.703035        On Time
# 96       0     0   2010-09-30    69357.068954        On Time
# 97       0     0   2010-10-31    55777.576557        On Time
# 98       0     0   2010-11-30    63223.814573        On Time
# 99       0     0   2010-12-31    49703.175089        On Time
# 100      0     0   2011-01-31    58629.161538        On Time
# 101      0     0   2011-02-28    17692.836331     Delinquent
# 102      0     0   2011-03-31    59095.478547        On Time
# 103      0     0   2011-04-30     2102.594005     Delinquent
# 104      0     0   2011-05-31    41867.480394        On Time
# 105      0     0   2011-06-30    45164.711619        On Time
# 106      0     0   2011-07-31    39067.346737        On Time
# 107      0     0   2011-08-31    60826.427266        On Time
# 108      0     0   2011-09-30    56326.767189        On Time
# 109      0     0   2011-10-31    47208.241054        On Time
# 110      0     0   2011-11-30    38089.216741        On Time
# 111      0     0   2011-12-31    63001.201821        On Time
# 112      0     0   2012-01-31    42958.745043        On Time
# 113      0     0   2012-02-29    63692.952039        On Time
# 114      0     0   2012-03-31    72618.358013        On Time
# 115      0     0   2012-04-30    59871.396421        On Time
# 116      0     0   2012-05-31    50370.995080        On Time
# 117      0     0   2012-06-30        0.000000        Default
# 118      0     0   2012-07-31        0.000000        Default
# 119      0     0   2012-08-31    31885.607604     Delinquent
# 120      0     0   2012-09-30    40781.794483        On Time
# 121      0     0   2012-10-31    43581.516462        On Time
# 122      0     0   2012-11-30    60024.791517        On Time
# 123      0     0   2012-12-31        0.000000        Default
# 124      0     0   2013-01-31    55837.754166        On Time
# 125      0     0   2013-02-28    43200.106630        On Time
# 126      0     0   2013-03-31    24129.934734     Delinquent
# 127      0     0   2013-04-30    22067.846437     Delinquent
# 128      0     0   2013-05-31    51567.042334        On Time
# 129      0     0   2013-06-30    57415.799681        On Time
# 130      0     0   2013-07-31    72853.326470        On Time
# 131      0     0   2013-08-31    39724.098924        On Time
# 132      0     0   2013-09-30        0.000000        Default
# 133      0     0   2013-10-31    25607.504233     Delinquent
# 134      0     0   2013-11-30    12355.114282     Delinquent
# 135      0     0   2013-12-31        0.000000        Default
# 136      0     0   2014-01-31    41537.027934        On Time
# 137      0     0   2014-02-28    69743.391622        On Time
# 138      0     0   2014-03-31    47624.379285        On Time
# 139      0     0   2014-04-30    67119.393477        On Time
# 140      0     0   2014-05-31    50967.041842        On Time
# 141      0     0   2014-06-30    71722.807753        On Time
# 142      0     0   2014-07-31    65040.482991        On Time
# 143      0     0   2014-08-31    70675.084101        On Time
# 144      0     0   2014-09-30    49036.542554        On Time
# 145      0     0   2014-10-31    37550.091658        On Time
# 146      0     0   2014-11-30    49009.203352        On Time
# 147      0     0   2014-12-31    58449.283949        On Time
# 148      0     0   2015-01-31    48039.547142        On Time
# 149      0     0   2015-02-28    65096.332832        On Time
# 150      0     0   2015-03-31    40535.578713        On Time
# 151      0     0   2015-04-30    57561.124156        On Time
# 152      0     0   2015-05-31    50183.115429        On Time
# 153      0     0   2015-06-30    65435.716192        On Time
# 154      0     0   2015-07-31    40271.857580        On Time
# 155      0     0   2015-08-31    67677.546552        On Time
# 156      0     0   2015-09-30    40299.008984        On Time
# 157      0     0   2015-10-31    50915.929158        On Time
# 158      0     0   2015-11-30    73774.974518        On Time
# 159      0     0   2015-12-31    40249.342874        On Time
# 160      0     0   2016-01-31    52906.287089        On Time
# 161      0     0   2016-02-29    55447.291062        On Time
# 162      0     0   2016-03-31    17804.329775     Delinquent
# 163      0     0   2016-04-30     5068.462774     Delinquent
# 164      0     0   2016-05-31    64861.202153        On Time
# 165      0     0   2016-06-30    51073.004853        On Time
# 166      0     0   2016-07-31    45453.526411        On Time
# 167      0     0   2016-08-31        0.000000        Default
# 168      0     0   2016-09-30        0.000000        Default
# 169      0     0   2016-10-31    74033.659764        On Time
# 170      0     0   2016-11-30    20905.765989     Delinquent
# 171      0     0   2016-12-31    60528.085910        On Time
# 172      0     0   2017-01-31    60459.713780        On Time
# 173      0     0   2017-02-28    38835.719414        On Time
# 174      0     0   2017-03-31    70218.573912        On Time
# 175      0     0   2017-04-30    47451.517495        On Time
# 176      0     0   2017-05-31    50273.651891        On Time
# 177      0     0   2017-06-30    73343.831118        On Time
# 178      0     0   2017-07-31    57062.139769        On Time
# 179      0     0   2017-08-31    62583.551232        On Time
# 180      0     0   2017-09-30    67702.702231        On Time
# 181      0     0   2017-10-31    59934.340991        On Time
# 182      0     0   2017-11-30    69319.608335        On Time
# 183      0     0   2017-12-31     1702.827841     Delinquent
# 184      0     0   2018-01-31    73822.340014        On Time
# 185      0     0   2018-02-28    51296.643097        On Time
# 186      0     0   2018-03-31    68289.315558        On Time
# 187      0     0   2018-04-30    47303.889205        On Time
# 188      0     0   2018-05-31    32222.778982     Delinquent
# 189      0     0   2018-06-30    74170.066905        On Time
# 190      0     0   2018-07-31    72243.184951        On Time
# 191      0     0   2018-08-31    53884.088266        On Time
# 192      0     0   2018-09-30    59665.372233        On Time
# 193      0     0   2018-10-31    60109.418812        On Time
# 194      0     0   2018-11-30    62094.765283        On Time
# 195      0     0   2018-12-31    56470.273658        On Time
# 196      0     0   2019-01-31    57984.943298        On Time
# 197      0     0   2019-02-28    42125.830699        On Time
# 198      0     0   2019-03-31    28233.381981     Delinquent
# 199      0     0   2019-04-30    45058.586190        On Time
# 200      0     0   2019-05-31        0.000000        Default
# 201      0     0   2019-06-30    51718.385665        On Time
# 202      0     0   2019-07-31    50084.319961        On Time
# 203      0     0   2019-08-31    51878.073006        On Time
# 204      0     0   2019-09-30    72419.817367        On Time
# 205      0     0   2019-10-31    55428.389997        On Time
# 206      0     0   2019-11-30    73553.260090        On Time
# 207      0     0   2019-12-31    60676.758236        On Time
# 208      0     0   2020-01-31    41935.059470        On Time
# 209      0     0   2020-02-29    42304.582396        On Time
# 210      0     0   2020-03-31    49988.175407        On Time
# 211      0     0   2020-04-30    61945.601092        On Time
# 212      0     0   2020-05-31    38665.666923        On Time
# 213      0     0   2020-06-30    43722.996965        On Time
# 214      0     0   2020-07-31     5134.644601     Delinquent
# 215      0     0   2020-08-31    50679.214663        On Time
# 216      0     0   2020-09-30    38607.847715        On Time
# 217      0     0   2020-10-31    40184.643639        On Time
# 218      0     0   2020-11-30    39416.393514        On Time
# 219      0     0   2020-12-31    64943.476849        On Time
# 220      0     0   2021-01-31    50909.612438        On Time
# 221      0     0   2021-02-28    50851.719426        On Time
# 222      0     0   2021-03-31    38510.189279        On Time
# 223      0     0   2021-04-30    70402.196003        On Time
# 224      0     0   2021-05-31    41128.672291        On Time
# 225      0     0   2021-06-30    46154.673034        On Time
# 226      0     0   2021-07-31    37893.094819        On Time
# 227      0     0   2021-08-31    49313.207890        On Time
# 228      0     0   2021-09-30    59197.975668        On Time
# 229      0     0   2021-10-31    55663.381585        On Time
# 230      0     0   2021-11-30    20296.071957     Delinquent
# 231      0     0   2021-12-31    53182.572994        On Time
# 232      0     0   2022-01-31    50635.099605        On Time
# 233      0     0   2022-02-28    50375.603125        On Time
# 234      0     0   2022-03-31    45959.882246        On Time
# 235      0     0   2022-04-30    46284.214715        On Time
# 236      0     0   2022-05-31    47738.072779        On Time
# 237      0     0   2022-06-30    40127.983067        On Time
# 238      0     0   2022-07-31    73640.409672        On Time
# 239      0     0   2022-08-31    73160.902920        On Time
# 240      0     0   2022-09-30    46727.945268        On Time
# 241      0     0   2022-10-31    71671.494556        On Time
# 242      0     0   2022-11-30    47548.023382        On Time
# 243      0     0   2022-12-31    49171.374434        On Time
# 244      0     0   2023-01-31    46152.415535        On Time
# 245      0     0   2023-02-28    47869.403476        On Time
# 246      0     0   2023-03-31    55020.651934        On Time
# 247      0     0   2023-04-30    49651.507424        On Time
# 248      0     0   2023-05-31    73922.047733        On Time
# 249      0     0   2023-06-30    46606.763723        On Time
# 250      0     0   2023-07-31    59273.990117        On Time
# 251      0     0   2023-08-31    50107.083931        On Time
# 252      0     1   2014-04-30    70709.528353        On Time
# 253      0     1   2014-05-31    69749.242998        On Time
# 254      0     1   2014-06-30    62652.485444        On Time
# 255      0     1   2014-07-31    41013.569201        On Time
# 256      0     1   2014-08-31    41872.995448        On Time
# 257      0     1   2014-09-30    59920.456790        On Time
# 258      0     1   2014-10-31    67549.184261        On Time
# 259      0     1   2014-11-30    51785.830550        On Time
# 260      0     1   2014-12-31    46828.781424        On Time
# 261      0     1   2015-01-31    44339.941622        On Time
# 262      0     1   2015-02-28    55543.206154        On Time
# 263      0     1   2015-03-31    40190.459097        On Time
# 264      0     1   2015-04-30    48035.243638        On Time
# 265      0     1   2015-05-31    58296.698049        On Time
# 266      0     1   2015-06-30    64360.882049        On Time
# 267      0     1   2015-07-31    44925.633207        On Time
# 268      0     1   2015-08-31        0.000000        Default
# 269      0     1   2015-09-30    67533.534673        On Time
# 270      0     1   2015-10-31    39964.972423        On Time
# 271      0     1   2015-11-30    50279.985864        On Time
# 272      0     1   2015-12-31    44233.382206        On Time
# 273      0     1   2016-01-31    59055.056422        On Time
# 274      0     1   2016-02-29    45044.737336        On Time
# 275      0     1   2016-03-31    68673.684999        On Time
# 276      0     1   2016-04-30    52608.816838        On Time
# 277      0     1   2016-05-31    57078.894275        On Time
# 278      0     1   2016-06-30    36635.676855        On Time
# 279      0     1   2016-07-31    56319.752478        On Time
# 280      0     1   2016-08-31    61433.275017        On Time
# 281      0     1   2016-09-30    57816.034229        On Time
# 282      0     1   2016-10-31    69606.262659        On Time
# 283      0     1   2016-11-30    40058.757842        On Time
# 284      0     1   2016-12-31    40469.861920        On Time
# 285      0     1   2017-01-31    54653.868648        On Time
# 286      0     1   2017-02-28    37954.542811        On Time
# 287      0     1   2017-03-31    36150.678716        On Time
# 288      0     1   2017-04-30    55321.643376        On Time
# 289      0     1   2017-05-31    48468.764017        On Time
# 290      0     1   2017-06-30    44066.179949        On Time
# 291      0     1   2017-07-31    42331.109322        On Time
# 292      0     1   2017-08-31    68903.814904        On Time
# 293      0     1   2017-09-30    58735.398136        On Time
# 294      0     1   2017-10-31    24118.874219     Delinquent
# 295      0     1   2017-11-30    41333.479595        On Time
# 296      0     1   2017-12-31    71855.523078        On Time
# 297      0     1   2018-01-31    38397.679962        On Time
# 298      0     1   2018-02-28    68299.585551        On Time
# 299      0     1   2018-03-31    37299.203248        On Time
# 300      0     1   2018-04-30    38348.459681        On Time
# 301      0     1   2018-05-31    54853.659451        On Time
# 302      0     1   2018-06-30    56122.097682        On Time
# 303      0     1   2018-07-31    66994.493787        On Time
# 304      0     1   2018-08-31    45726.476318        On Time
# 305      0     1   2018-09-30    36897.502622        On Time
# 306      0     1   2018-10-31    59694.719126        On Time
# 307      0     1   2018-11-30     8547.377349     Delinquent
# 308      0     1   2018-12-31    36693.263991        On Time
# 309      0     1   2019-01-31    42408.751119        On Time
# 310      0     1   2019-02-28    39562.299077        On Time
# 311      0     1   2019-03-31    66775.381708        On Time
# 312      0     1   2019-04-30    60024.375554        On Time
# 313      0     1   2019-05-31    68237.748094        On Time
# 314      0     1   2019-06-30     3735.080195     Delinquent
# 315      0     1   2019-07-31        0.000000        Default
# 316      0     1   2019-08-31    51148.541029        On Time
# 317      0     1   2019-09-30    48283.955583        On Time
# 318      0     1   2019-10-31    57225.173211        On Time
# 319      0     1   2019-11-30    50716.268892        On Time
# 320      0     1   2019-12-31    46580.055891        On Time
# 321      0     1   2020-01-31    41025.832517        On Time
# 322      0     1   2020-02-29    68173.567333        On Time
# 323      0     1   2020-03-31    36792.535591        On Time
# 324      0     1   2020-04-30    58779.080262        On Time
# 325      0     1   2020-05-31    66028.129641        On Time
# 326      0     1   2020-06-30    42161.707422        On Time
# 327      0     1   2020-07-31        0.000000        Default
# 328      0     1   2020-08-31    56729.368855        On Time
# 329      0     1   2020-09-30    59424.711254        On Time
# 330      0     1   2020-10-31    36379.673898        On Time
# 331      0     1   2020-11-30    67430.060551        On Time
# 332      0     1   2020-12-31    59914.679697        On Time
# 333      0     1   2021-01-31    51053.038568        On Time
# 334      0     1   2021-02-28    37674.023348        On Time
# 335      0     1   2021-03-31    38963.427267        On Time
# 336      0     1   2021-04-30    49992.413376        On Time
# 337      0     1   2021-05-31    61858.147852        On Time
# 338      0     1   2021-06-30    53114.197673        On Time
# 339      0     1   2021-07-31    62344.874346        On Time
# 340      0     1   2021-08-31        0.000000        Default
# 341      0     1   2021-09-30    37834.506472        On Time
# 342      0     1   2021-10-31    48011.432167        On Time
# 343      0     1   2021-11-30    38687.757938        On Time
# 344      0     1   2021-12-31    60755.471833        On Time
# 345      0     1   2022-01-31    65458.577799        On Time
# 346      0     1   2022-02-28    45776.870618        On Time
# 347      0     1   2022-03-31    39279.489327        On Time
# 348      0     1   2022-04-30    70177.340940        On Time
# 349      0     1   2022-05-31    55483.763690        On Time
# 350      0     1   2022-06-30    65007.296345        On Time
# 351      0     1   2022-07-31    66541.456326        On Time
# 352      0     1   2022-08-31    43944.000554        On Time
# 353      0     1   2022-09-30    37402.734380        On Time
# 354      0     1   2022-10-31    42481.823219        On Time
# 355      0     1   2022-11-30    37205.512093        On Time
# 356      0     1   2022-12-31    69247.472694        On Time
# 357      0     1   2023-01-31    53048.124372        On Time
# 358      0     1   2023-02-28    47466.511429        On Time
# 359      0     1   2023-03-31        0.000000        Default
# 360      0     1   2023-04-30    40322.478818        On Time
# 361      0     1   2023-05-31    25273.830205     Delinquent
# 362      0     1   2023-06-30    38335.782567        On Time
# 363      0     1   2023-07-31    64437.382364        On Time
# 364      0     1   2023-08-31    67865.023293        On Time
# 365      0     1   2023-09-30    36862.037724        On Time
# 366      0     1   2023-10-31        0.000000        Default
# 367      0     1   2023-11-30    69775.412063        On Time
# 368      0     1   2023-12-31    48604.013967        On Time
# 369      0     1   2024-01-31    53251.844321        On Time
# 370      0     1   2024-02-29    71395.259556        On Time
# 371      0     1   2024-03-31    51146.110370        On Time
# 372      0     2   2003-07-31    53532.625572        On Time
# 373      0     2   2003-08-31    62491.125563        On Time
# 374      0     2   2003-09-30        0.000000        Default
# 375      0     2   2003-10-31    47626.970577     Delinquent
# 376      0     2   2003-11-30    80970.756557        On Time
# 377      0     2   2003-12-31    86114.334110        On Time
# 378      0     2   2004-01-31    20691.850129     Delinquent
# 379      0     2   2004-02-29    70739.024653        On Time
# 380      0     2   2004-03-31    95988.265960        On Time
# 381      0     2   2004-04-30    79524.516008        On Time
# 382      0     2   2004-05-31    59326.899613        On Time
# 383      0     2   2004-06-30    57194.629303        On Time
# 384      0     2   2004-07-31    50995.421909        On Time
# 385      0     2   2004-08-31    92931.154316        On Time
# 386      0     2   2004-09-30    67308.639005        On Time
# 387      0     2   2004-10-31    55625.859957        On Time
# 388      0     2   2004-11-30    58996.575758        On Time
# 389      0     2   2004-12-31    76171.215821        On Time
# 390      0     2   2005-01-31    42417.900689     Delinquent
# 391      0     2   2005-02-28    91050.878686        On Time
# 392      0     2   2005-03-31    87231.341414        On Time
# 393      0     2   2005-04-30    52400.370735        On Time
# 394      0     2   2005-05-31    60728.950654        On Time
# 395      0     2   2005-06-30    52113.994930        On Time
# 396      0     2   2005-07-31    51877.040343        On Time
# 397      0     2   2005-08-31    71374.637133        On Time
# 398      0     2   2005-09-30    64973.838485        On Time
# 399      0     2   2005-10-31    61079.631820        On Time
# 400      0     2   2005-11-30    79948.987593        On Time
# 401      0     2   2005-12-31    82355.054019        On Time
# 402      0     2   2006-01-31    80994.546184        On Time
# 403      0     2   2006-02-28    55852.876311        On Time
# 404      0     2   2006-03-31    49616.923773        On Time
# 405      0     2   2006-04-30    64362.074607        On Time
# 406      0     2   2006-05-31    87638.736332        On Time
# 407      0     2   2006-06-30    48514.843718        On Time
# 408      0     2   2006-07-31    95507.042084        On Time
# 409      0     2   2006-08-31    78770.512929        On Time
# 410      0     2   2006-09-30    53364.215656        On Time
# 411      0     2   2006-10-31    94629.955530        On Time
# 412      0     2   2006-11-30    93137.278882        On Time
# 413      0     2   2006-12-31    81367.907015        On Time
# 414      0     2   2007-01-31    15182.519658     Delinquent
# 415      0     2   2007-02-28    76271.691374        On Time
# 416      0     2   2007-03-31    50412.086224        On Time
# 417      0     2   2007-04-30    94913.694770        On Time
# 418      0     2   2007-05-31    84760.593886        On Time
# 419      0     2   2007-06-30     2009.319848     Delinquent
# 420      0     2   2007-07-31    85346.030390        On Time
# 421      0     2   2007-08-31    61397.720701        On Time
# 422      0     2   2007-09-30    69967.014282        On Time
# 423      0     2   2007-10-31    81647.339058        On Time
# 424      0     2   2007-11-30    81011.829855        On Time
# 425      0     2   2007-12-31    94045.279745        On Time
# 426      0     2   2008-01-31    93695.892664        On Time
# 427      0     2   2008-02-29    67373.833143        On Time
# 428      0     2   2008-03-31    67939.764442        On Time
# 429      0     2   2008-04-30    58480.138467        On Time
# 430      0     2   2008-05-31    31750.744598     Delinquent
# 431      0     2   2008-06-30    71019.029972        On Time
# 432      0     2   2008-07-31    90080.717058        On Time
# 433      0     2   2008-08-31    88931.465078        On Time
# 434      0     2   2008-09-30    54533.921818        On Time
# 435      0     2   2008-10-31    44467.625956     Delinquent
# 436      0     2   2008-11-30    71419.747999        On Time
# 437      0     2   2008-12-31    81256.045801        On Time
# 438      0     2   2009-01-31    71905.298315        On Time
# 439      0     2   2009-02-28    28458.133465     Delinquent
# 440      0     2   2009-03-31    63168.618954        On Time
# 441      0     2   2009-04-30        0.000000        Default
# 442      0     2   2009-05-31    19506.658136     Delinquent
# 443      0     2   2009-06-30    62267.177932        On Time
# 444      0     2   2009-07-31    85801.276622        On Time
# 445      0     2   2009-08-31    23664.662438     Delinquent
# 446      0     2   2009-09-30    95771.043634        On Time
# 447      0     2   2009-10-31    78006.433484        On Time
# 448      0     2   2009-11-30    48678.023242        On Time
# 449      0     2   2009-12-31    52442.780324        On Time
# 450      0     2   2010-01-31        0.000000        Default
# 451      0     2   2010-02-28    19715.930768     Delinquent
# 452      0     2   2010-03-31    81444.037767        On Time
# 453      0     2   2010-04-30    56280.832843        On Time
# 454      0     2   2010-05-31    82264.075347        On Time
# 455      0     2   2010-06-30    45193.484080     Delinquent
# 456      0     2   2010-07-31    26536.526987     Delinquent
# 457      0     2   2010-08-31    82630.988737        On Time
# 458      0     2   2010-09-30    87487.274258        On Time
# 459      0     2   2010-10-31    43237.838008     Delinquent
# 460      0     2   2010-11-30    70011.907542        On Time
# 461      0     2   2010-12-31    83474.736075        On Time
# 462      0     2   2011-01-31     3815.345055     Delinquent
# 463      0     2   2011-02-28    90233.070395        On Time
# 464      0     2   2011-03-31    64447.735434        On Time
# 465      0     2   2011-04-30    79961.325734        On Time
# 466      0     2   2011-05-31    82877.560125        On Time
# 467      0     2   2011-06-30    95198.853968        On Time
# 468      0     2   2011-07-31    80998.762883        On Time
# 469      0     2   2011-08-31     2412.251870     Delinquent
# 470      0     2   2011-09-30    90063.812668        On Time
# 471      0     2   2011-10-31    68718.757174        On Time
# 472      0     2   2011-11-30    95818.622519        On Time
# 473      0     2   2011-12-31    41925.187587     Delinquent
# 474      0     2   2012-01-31    83169.496036        On Time
# 475      0     2   2012-02-29    91627.134758        On Time
# 476      0     2   2012-03-31    76762.432291        On Time
# 477      0     2   2012-04-30    78238.350094        On Time
# 478      0     2   2012-05-31    54549.483397        On Time
# 479      0     2   2012-06-30    56868.983629        On Time
# 480      0     2   2012-07-31    56931.355959        On Time
# 481      0     2   2012-08-31    60125.268404        On Time
# 482      0     2   2012-09-30    73024.800181        On Time
# 483      0     2   2012-10-31    56089.995326        On Time
# 484      0     2   2012-11-30    60650.838390        On Time
# 485      0     2   2012-12-31    85493.818970        On Time
# 486      0     2   2013-01-31    70082.832421        On Time
# 487      0     2   2013-02-28    56390.519331        On Time
# 488      0     2   2013-03-31    88164.980419        On Time
# 489      0     2   2013-04-30    77957.708369        On Time
# 490      0     2   2013-05-31    56287.419560        On Time
# 491      0     2   2013-06-30    35753.877301     Delinquent
# 492      0     2   2013-07-31    88901.924833        On Time
# 493      0     2   2013-08-31    90063.753620        On Time
# 494      0     2   2013-09-30    61210.819522        On Time
# 495      0     2   2013-10-31    26058.107648     Delinquent
# 496      0     2   2013-11-30        0.000000        Default
# 497      0     2   2013-12-31    93226.312970        On Time
# 498      0     2   2014-01-31    50211.102816        On Time
# 499      0     2   2014-02-28    94732.476999        On Time
# 500      0     2   2014-03-31    45930.450925     Delinquent
# 501      0     2   2014-04-30    70128.644221        On Time
# 502      0     2   2014-05-31    80354.525264        On Time
# 503      0     2   2014-06-30        0.000000        Default
# 504      0     2   2014-07-31    57937.749366        On Time
# 505      0     2   2014-08-31    52733.671806        On Time
# 506      0     2   2014-09-30    90057.533657        On Time
# 507      0     2   2014-10-31    88610.023768        On Time
# 508      0     2   2014-11-30    72174.303849        On Time
# 509      0     2   2014-12-31    75714.384056        On Time
# 510      0     2   2015-01-31    44944.818889     Delinquent
# 511      0     2   2015-02-28    58604.052072        On Time
# 512      0     2   2015-03-31    79600.988124        On Time
# 513      0     2   2015-04-30    96385.737478        On Time
# 514      0     2   2015-05-31    47128.643181     Delinquent
# 515      0     2   2015-06-30    85923.457030        On Time
# 516      0     2   2015-07-31    90557.599664        On Time
# 517      0     2   2015-08-31    80389.674338        On Time
# 518      0     2   2015-09-30    86667.202571        On Time
# 519      0     2   2015-10-31    54001.917932        On Time
# 520      0     2   2015-11-30        0.000000        Default
# 521      0     2   2015-12-31    67305.296944        On Time
# 522      0     2   2016-01-31    69837.173466        On Time
# 523      0     2   2016-02-29    59162.986921        On Time
# 524      0     2   2016-03-31    29472.777414     Delinquent
# 525      0     2   2016-04-30    70550.657369        On Time
# 526      0     2   2016-05-31    73230.375616        On Time
# 527      0     2   2016-06-30        0.000000        Default
# 528      0     2   2016-07-31    67433.049799        On Time
# 529      0     2   2016-08-31    77512.280808        On Time
# 530      0     2   2016-09-30    82825.559136        On Time
# 531      0     2   2016-10-31        0.000000        Default
# 532      0     2   2016-11-30        0.000000        Default
# 533      0     2   2016-12-31    59944.551071        On Time
# 534      0     2   2017-01-31    93253.357544        On Time
# 535      0     2   2017-02-28    71629.419895        On Time
# 536      0     2   2017-03-31    63020.527339        On Time
# 537      0     2   2017-04-30    63214.210253        On Time
# 538      0     2   2017-05-31    61349.385203        On Time
# 539      0     2   2017-06-30    56939.666693        On Time
# 540      0     2   2017-07-31    73523.551236        On Time
# 541      0     2   2017-08-31    75555.420172        On Time
# 542      0     2   2017-09-30    71517.284991        On Time
# 543      0     2   2017-10-31    50299.787971        On Time
# 544      0     2   2017-11-30    77208.901014        On Time
# 545      0     2   2017-12-31    59202.041566        On Time
# 546      0     2   2018-01-31    68021.449444        On Time
# 547      0     2   2018-02-28    65244.384432        On Time
# 548      0     2   2018-03-31    61454.574556        On Time
# 549      0     2   2018-04-30    80387.577995        On Time
# 550      0     2   2018-05-31    30437.038735     Delinquent
# 551      0     2   2018-06-30    56306.460913        On Time
# 552      0     2   2018-07-31    58655.375543        On Time
# 553      0     2   2018-08-31     2080.894411     Delinquent
# 554      0     2   2018-09-30    74561.642175        On Time
# 555      0     2   2018-10-31    76864.920690        On Time
# 556      0     2   2018-11-30    54784.351152        On Time
# 557      0     2   2018-12-31    68849.218837        On Time
# 558      0     2   2019-01-31    95992.477688        On Time
# 559      0     2   2019-02-28    83125.201357        On Time
# 560      0     2   2019-03-31    52035.569521        On Time
# 561      0     2   2019-04-30    43208.274305     Delinquent
# 562      0     2   2019-05-31    59133.425182        On Time
# 563      0     2   2019-06-30    73229.315340        On Time
# 564      0     2   2019-07-31    38775.270449     Delinquent
# 565      0     2   2019-08-31    90632.972574        On Time
# 566      0     2   2019-09-30    63842.157236        On Time
# 567      0     2   2019-10-31    96131.476186        On Time
# 568      0     2   2019-11-30    83429.469147        On Time
# 569      0     2   2019-12-31    75313.642603        On Time
# 570      0     2   2020-01-31    81470.065772        On Time
# 571      0     2   2020-02-29    52867.481608        On Time
# 572      0     2   2020-03-31    64962.380469        On Time
# 573      0     2   2020-04-30    92903.461144        On Time
# 574      0     2   2020-05-31    55554.518755        On Time
# 575      0     2   2020-06-30    74236.713379        On Time
# 576      0     2   2020-07-31    78268.195262        On Time
# 577      0     2   2020-08-31    36645.274738     Delinquent
# 578      0     2   2020-09-30    85906.228022        On Time
# 579      0     2   2020-10-31        0.000000        Default
# 580      0     2   2020-11-30    65568.095795        On Time
# 581      0     2   2020-12-31    45228.707259     Delinquent
# 582      0     2   2021-01-31    67344.287994        On Time
# 583      0     2   2021-02-28    73066.358171        On Time
# 584      0     2   2021-03-31    96035.961421        On Time
# 585      0     2   2021-04-30    93068.203512        On Time
# 586      0     2   2021-05-31    66555.707109        On Time
# 587      0     2   2021-06-30    87058.245763        On Time
# 588      0     2   2021-07-31    52107.875878        On Time
# 589      0     2   2021-08-31    81708.507143        On Time
# 590      0     2   2021-09-30    79106.340933        On Time
# 591      0     2   2021-10-31    89762.132147        On Time
# 592      0     2   2021-11-30    77432.635370        On Time
# 593      0     2   2021-12-31    72434.202848        On Time
# 594      0     2   2022-01-31    65924.731895        On Time
# 595      0     2   2022-02-28     2183.568306     Delinquent
# 596      0     2   2022-03-31    74698.170337        On Time
# 597      0     2   2022-04-30    63238.720328        On Time
# 598      0     2   2022-05-31    53300.777434        On Time
# 599      0     2   2022-06-30    78075.476542        On Time
# 600      0     2   2022-07-31    51164.481474        On Time
# 601      0     2   2022-08-31    51010.902090        On Time
# 602      0     2   2022-09-30    81712.563278        On Time
# 603      0     2   2022-10-31    55064.415316        On Time
# 604      0     2   2022-11-30    53078.115411        On Time
# 605      0     2   2022-12-31    72764.712532        On Time
# 606      0     2   2023-01-31    77864.883459        On Time
# 607      0     2   2023-02-28    73614.087851        On Time
# 608      0     2   2023-03-31    90947.529404        On Time
# 609      0     2   2023-04-30    65935.575028        On Time
# 610      0     2   2023-05-31    83572.348444        On Time
# 611      0     2   2023-06-30        0.000000        Default
# 612      0     2   2023-07-31    49132.202089        On Time
# 613      0     2   2023-08-31    54816.647584        On Time
# 614      0     2   2023-09-30    48791.306183        On Time
# 615      0     2   2023-10-31    86846.699553        On Time
# 616      0     2   2023-11-30    53497.052930        On Time
# 617      0     2   2023-12-31    88910.921888        On Time
# 618      0     2   2024-01-31    24030.047683     Delinquent
# 619      0     2   2024-02-29    83752.772630        On Time
# 620      0     2   2024-03-31    67223.517961        On Time
# 621      0     2   2024-04-30    91211.726600        On Time
# 622      0     2   2024-05-31    63411.820223        On Time
# 623      0     2   2024-06-30    60483.906677        On Time
# 624      0     3   2003-01-31        0.000000        Default
# 625      0     3   2003-02-28    51080.686076        On Time
# 626      0     3   2003-03-31    51064.094084        On Time
# 627      0     3   2003-04-30    47374.330285        On Time
# 628      0     3   2003-05-31    47181.323929        On Time
# 629      0     3   2003-06-30        0.000000        Default
# 630      0     3   2003-07-31    22526.303913     Delinquent
# 631      0     3   2003-08-31     2802.745708     Delinquent
# 632      0     3   2003-09-30    29869.986754     Delinquent
# 633      0     3   2003-10-31    40451.910136        On Time
# 634      0     3   2003-11-30    51834.763065        On Time
# 635      0     3   2003-12-31    34269.944271        On Time
# 636      0     3   2004-01-31    39469.448564        On Time
# 637      0     3   2004-02-29     3136.480905     Delinquent
# 638      0     3   2004-03-31    55199.762213        On Time
# 639      0     3   2004-04-30    37617.442581        On Time
# 640      0     3   2004-05-31    55368.573956        On Time
# 641      0     3   2004-06-30    32508.878171        On Time
# 642      0     3   2004-07-31    40336.047545        On Time
# 643      0     3   2004-08-31    49371.586936        On Time
# 644      0     3   2004-09-30    51682.132549        On Time
# 645      0     3   2004-10-31    60156.209578        On Time
# 646      0     3   2004-11-30    44680.798748        On Time
# 647      0     3   2004-12-31    60623.966138        On Time
# 648      0     3   2005-01-31    37361.079284        On Time
# 649      0     3   2005-02-28    40120.291824        On Time
# 650      0     3   2005-03-31    57611.247367        On Time
# 651      0     3   2005-04-30    54757.308177        On Time
# 652      0     3   2005-05-31    53928.909127        On Time
# 653      0     3   2005-06-30    36735.777607        On Time
# 654      0     3   2005-07-31    60446.507675        On Time
# 655      0     3   2005-08-31     5663.377806     Delinquent
# 656      0     3   2005-09-30    56714.902292        On Time
# 657      0     3   2005-10-31    57429.934474        On Time
# 658      0     3   2005-11-30    49618.847942        On Time
# 659      0     3   2005-12-31    48828.686177        On Time
# 660      0     3   2006-01-31    51052.290244        On Time
# 661      0     3   2006-02-28    45600.593202        On Time
# 662      0     3   2006-03-31     8166.452962     Delinquent
# 663      0     3   2006-04-30    34294.356707        On Time
# 664      0     3   2006-05-31    37565.911800        On Time
# 665      0     3   2006-06-30    50418.746048        On Time
# 666      0     3   2006-07-31    55654.303676        On Time
# 667      0     3   2006-08-31        0.000000        Default
# 668      0     3   2006-09-30        0.000000        Default
# 669      0     3   2006-10-31    61091.892580        On Time
# 670      0     3   2006-11-30    35845.307170        On Time
# 671      0     3   2006-12-31    62285.631334        On Time
# 672      0     3   2007-01-31    53728.613272        On Time
# 673      0     3   2007-02-28    43415.601783        On Time
# 674      0     3   2007-03-31    31300.409824        On Time
# 675      0     3   2007-04-30    55978.956736        On Time
# 676      0     3   2007-05-31    18608.872514     Delinquent
# 677      0     3   2007-06-30    33223.432148        On Time
# 678      0     3   2007-07-31    48692.594946        On Time
# 679      0     3   2007-08-31    56315.656790        On Time
# 680      0     3   2007-09-30    46745.577287        On Time
# 681      0     3   2007-10-31     2414.253213     Delinquent
# 682      0     3   2007-11-30    53279.645164        On Time
# 683      0     3   2007-12-31    44934.208736        On Time
# 684      0     3   2008-01-31    44741.404225        On Time
# 685      0     3   2008-02-29     7369.431066     Delinquent
# 686      0     3   2008-03-31    62348.442355        On Time
# 687      0     3   2008-04-30    44342.939263        On Time
# 688      0     3   2008-05-31    34892.089157        On Time
# 689      0     3   2008-06-30    43175.588100        On Time
# 690      0     3   2008-07-31    36955.659098        On Time
# 691      0     3   2008-08-31    32017.337306        On Time
# 692      0     3   2008-09-30    26053.968807     Delinquent
# 693      0     3   2008-10-31    40520.237896        On Time
# 694      0     3   2008-11-30    44605.292557        On Time
# 695      0     3   2008-12-31    37006.364237        On Time
# 696      0     3   2009-01-31    46268.628809        On Time
# 697      0     3   2009-02-28    53911.706378        On Time
# 698      0     3   2009-03-31    53960.656734        On Time
# 699      0     3   2009-04-30    50239.024664        On Time
# 700      0     3   2009-05-31    51697.000876        On Time
# 701      0     3   2009-06-30    32980.107300        On Time
# 702      0     3   2009-07-31    38905.738531        On Time
# 703      0     3   2009-08-31    39684.831455        On Time
# 704      0     3   2009-09-30    55433.369377        On Time
# 705      0     3   2009-10-31    15531.976818     Delinquent
# 706      0     3   2009-11-30     2539.684349     Delinquent
# 707      0     3   2009-12-31    47811.525287        On Time
# 708      0     3   2010-01-31    59274.800385        On Time
# 709      0     3   2010-02-28    20920.033445     Delinquent
# 710      0     3   2010-03-31    60428.860815        On Time
# 711      0     3   2010-04-30    13429.024524     Delinquent
# 712      0     3   2010-05-31    61816.469224        On Time
# 713      0     3   2010-06-30    37380.646142        On Time
# 714      0     3   2010-07-31    61526.566285        On Time
# 715      0     3   2010-08-31    34759.788489        On Time
# 716      0     3   2010-09-30    39030.159834        On Time
# 717      0     3   2010-10-31    47529.796435        On Time
# 718      0     3   2010-11-30    53751.806260        On Time
# 719      0     3   2010-12-31    22266.765933     Delinquent
# 720      0     3   2011-01-31    45498.980016        On Time
# 721      0     3   2011-02-28    60705.782186        On Time
# 722      0     3   2011-03-31    45623.621503        On Time
# 723      0     3   2011-04-30    48217.474325        On Time
# 724      0     3   2011-05-31    16294.280989     Delinquent
# 725      0     3   2011-06-30    32821.045220        On Time
# 726      0     3   2011-07-31    39268.970049        On Time
# 727      0     3   2011-08-31    54810.646977        On Time
# 728      0     3   2011-09-30    58588.298438        On Time
# 729      0     3   2011-10-31    38650.441795        On Time
# 730      0     3   2011-11-30    55286.789261        On Time
# 731      0     3   2011-12-31     2617.695582     Delinquent
# 732      0     3   2012-01-31    48007.496096        On Time
# 733      0     3   2012-02-29    51691.539267        On Time
# 734      0     3   2012-03-31    55399.089749        On Time
# 735      0     3   2012-04-30    47527.884493        On Time
# 736      0     3   2012-05-31    49220.913015        On Time
# 737      0     3   2012-06-30    43554.278747        On Time
# 738      0     3   2012-07-31    36128.190472        On Time
# 739      0     3   2012-08-31    41082.964325        On Time
# 740      0     3   2012-09-30    39839.420006        On Time
# 741      0     3   2012-10-31    37502.888854        On Time
# 742      0     3   2012-11-30    51613.927633        On Time
# 743      0     3   2012-12-31    50397.298382        On Time
# 744      0     3   2013-01-31    27604.762880     Delinquent
# 745      0     3   2013-02-28    61374.350396        On Time
# 746      0     3   2013-03-31    52039.103963        On Time
# 747      0     3   2013-04-30    58716.146059        On Time
# 748      0     3   2013-05-31    31593.354623        On Time
# 749      0     3   2013-06-30    53643.833018        On Time
# 750      0     3   2013-07-31    54022.690499        On Time
# 751      0     3   2013-08-31    56754.781632        On Time
# 752      0     3   2013-09-30    41007.723531        On Time
# 753      0     3   2013-10-31    45529.074152        On Time
# 754      0     3   2013-11-30    57041.376676        On Time
# 755      0     3   2013-12-31    53414.837434        On Time
# 756      0     3   2014-01-31    38684.072318        On Time
# 757      0     3   2014-02-28    45250.950542        On Time
# 758      0     3   2014-03-31    50572.971305        On Time
# 759      0     3   2014-04-30    45904.159623        On Time
# 760      0     3   2014-05-31    35139.459937        On Time
# 761      0     3   2014-06-30    52613.408537        On Time
# 762      0     3   2014-07-31     5971.174823     Delinquent
# 763      0     3   2014-08-31    57315.683108        On Time
# 764      0     3   2014-09-30    52857.497894        On Time
# 765      0     3   2014-10-31    37834.504543        On Time
# 766      0     3   2014-11-30     9917.465164     Delinquent
# 767      0     3   2014-12-31    58381.579847        On Time
# 768      0     3   2015-01-31    51947.528988        On Time
# 769      0     3   2015-02-28    52126.848131        On Time
# 770      0     3   2015-03-31    45148.132967        On Time
# 771      0     3   2015-04-30    48255.424470        On Time
# 772      0     3   2015-05-31    34654.482512        On Time
# 773      0     3   2015-06-30        0.000000        Default
# 774      0     3   2015-07-31    39937.164682        On Time
# 775      0     3   2015-08-31    59616.029043        On Time
# 776      0     3   2015-09-30    31761.804535        On Time
# 777      0     3   2015-10-31    40708.234176        On Time
# 778      0     3   2015-11-30    58429.919794        On Time
# 779      0     3   2015-12-31    48069.792471        On Time
# 780      0     3   2016-01-31     8020.145693     Delinquent
# 781      0     3   2016-02-29    14957.049312     Delinquent
# 782      0     3   2016-03-31    40473.819601        On Time
# 783      0     3   2016-04-30    32702.056483        On Time
# 784      0     3   2016-05-31    52035.506117        On Time
# ...
# 9738    18     0   2022-07-31    43466.041935        On Time
# 9739    18     0   2022-08-31     2707.130058     Delinquent
# 9740    18     0   2022-09-30    47206.460231        On Time
# 9741    18     0   2022-10-31    45551.223322        On Time
# 9742    18     0   2022-11-30    51860.143677        On Time
# 9743    18     0   2022-12-31    21580.438069     Delinquent
# 9744    18     0   2023-01-31    63134.209156        On Time
# 9745    18     0   2023-02-28    34762.895477        On Time
# 9746    18     0   2023-03-31    49244.971480        On Time
# 9747    18     0   2023-04-30    39418.674019        On Time
# 9748    18     0   2023-05-31    22926.428206     Delinquent
# 9749    18     0   2023-06-30    54011.745599        On Time
# 9750    18     0   2023-07-31    35775.787910        On Time
# 9751    18     0   2023-08-31    40685.683981        On Time
# 9752    18     0   2023-09-30    43483.663842        On Time
# 9753    18     0   2023-10-31    33547.918873        On Time
# 9754    18     0   2023-11-30    61269.800695        On Time
# 9755    18     0   2023-12-31    56932.761657        On Time
# 9756    18     1   2020-02-29    45764.078472        On Time
# 9757    18     1   2020-03-31    44129.396080        On Time
# 9758    18     1   2020-04-30    44433.764630        On Time
# 9759    18     1   2020-05-31    35439.487688        On Time
# 9760    18     1   2020-06-30     5269.356807     Delinquent
# 9761    18     1   2020-07-31     7059.807473     Delinquent
# 9762    18     1   2020-08-31    51117.344149        On Time
# 9763    18     1   2020-09-30        0.000000        Default
# 9764    18     1   2020-10-31    30829.263057        On Time
# 9765    18     1   2020-11-30    36975.176020        On Time
# 9766    18     1   2020-12-31    46169.433959        On Time
# 9767    18     1   2021-01-31     4580.747430     Delinquent
# 9768    18     1   2021-02-28    44813.588846        On Time
# 9769    18     1   2021-03-31    48435.404598        On Time
# 9770    18     1   2021-04-30    49001.550935        On Time
# 9771    18     1   2021-05-31    30599.344530        On Time
# 9772    18     1   2021-06-30    49241.262381        On Time
# 9773    18     1   2021-07-31    28016.847536        On Time
# 9774    18     1   2021-08-31    40571.699510        On Time
# 9775    18     1   2021-09-30    41474.180112        On Time
# 9776    18     1   2021-10-31    50840.058829        On Time
# 9777    18     1   2021-11-30    41343.011008        On Time
# 9778    18     1   2021-12-31    33482.774641        On Time
# 9779    18     1   2022-01-31    48773.938339        On Time
# 9780    18     1   2022-02-28    29197.983674        On Time
# 9781    18     1   2022-03-31    40943.946730        On Time
# 9782    18     1   2022-04-30    28931.505216        On Time
# 9783    18     1   2022-05-31    30154.024619        On Time
# 9784    18     1   2022-06-30    44631.635956        On Time
# 9785    18     1   2022-07-31    47694.439208        On Time
# 9786    18     1   2022-08-31    31472.751922        On Time
# 9787    18     1   2022-09-30    35762.108469        On Time
# 9788    18     1   2022-10-31    48969.707554        On Time
# 9789    18     1   2022-11-30    44326.049093        On Time
# 9790    18     1   2022-12-31    42851.063513        On Time
# 9791    18     1   2023-01-31    30941.631679        On Time
# 9792    18     1   2023-02-28    50527.720396        On Time
# 9793    18     1   2023-03-31    33206.054732        On Time
# 9794    18     1   2023-04-30    52708.660957        On Time
# 9795    18     1   2023-05-31    32418.607225        On Time
# 9796    18     1   2023-06-30    35608.101546        On Time
# 9797    18     1   2023-07-31    29298.188137        On Time
# 9798    18     1   2023-08-31    32093.497153        On Time
# 9799    18     1   2023-09-30    38085.343476        On Time
# 9800    18     1   2023-10-31    24862.944023     Delinquent
# 9801    18     1   2023-11-30    40873.364445        On Time
# 9802    18     1   2023-12-31     9625.286527     Delinquent
# 9803    18     1   2024-01-31    32990.696279        On Time
# 9804    18     2   2020-01-31    55235.330310        On Time
# 9805    18     2   2020-02-29    42202.636152        On Time
# 9806    18     2   2020-03-31    35513.299792        On Time
# 9807    18     2   2020-04-30    16835.821542     Delinquent
# 9808    18     2   2020-05-31    49216.302773        On Time
# 9809    18     2   2020-06-30    53429.327911        On Time
# 9810    18     2   2020-07-31    67166.599096        On Time
# 9811    18     2   2020-08-31    66597.937229        On Time
# 9812    18     2   2020-09-30    68223.655043        On Time
# 9813    18     2   2020-10-31    62624.378847        On Time
# 9814    18     2   2020-11-30    53961.738771        On Time
# 9815    18     2   2020-12-31    50923.106058        On Time
# 9816    18     2   2021-01-31    55059.118666        On Time
# 9817    18     2   2021-02-28    64921.012439        On Time
# 9818    18     2   2021-03-31    44836.364442        On Time
# 9819    18     2   2021-04-30     4464.368959     Delinquent
# 9820    18     2   2021-05-31    57812.388449        On Time
# 9821    18     2   2021-06-30    51548.418603        On Time
# 9822    18     2   2021-07-31    46132.212739        On Time
# 9823    18     2   2021-08-31    58349.573981        On Time
# 9824    18     2   2021-09-30    65767.319246        On Time
# 9825    18     2   2021-10-31    61067.051137        On Time
# 9826    18     2   2021-11-30    50483.228124        On Time
# 9827    18     2   2021-12-31    51743.928867        On Time
# 9828    18     2   2022-01-31    43457.910829        On Time
# 9829    18     2   2022-02-28    66850.209646        On Time
# 9830    18     2   2022-03-31    51877.204272        On Time
# 9831    18     2   2022-04-30    24588.663427     Delinquent
# 9832    18     2   2022-05-31    56153.954023        On Time
# 9833    18     2   2022-06-30    35758.964770        On Time
# 9834    18     2   2022-07-31    59896.976245        On Time
# 9835    18     2   2022-08-31        0.000000        Default
# 9836    18     2   2022-09-30    40786.173035        On Time
# 9837    18     2   2022-10-31    51542.079644        On Time
# 9838    18     2   2022-11-30    60134.053194        On Time
# 9839    18     2   2022-12-31    63778.674366        On Time
# 9840    18     2   2023-01-31    25040.178688     Delinquent
# 9841    18     2   2023-02-28    54020.614556        On Time
# 9842    18     2   2023-03-31    36449.212038        On Time
# 9843    18     2   2023-04-30    18543.638311     Delinquent
# 9844    18     2   2023-05-31    44011.162452        On Time
# 9845    18     2   2023-06-30    52391.423661        On Time
# 9846    18     2   2023-07-31    37377.872678        On Time
# 9847    18     2   2023-08-31    69511.325218        On Time
# 9848    18     2   2023-09-30    44887.861313        On Time
# 9849    18     2   2023-10-31    62395.188804        On Time
# 9850    18     2   2023-11-30    64322.738154        On Time
# 9851    18     2   2023-12-31    42239.487540        On Time
# 9852    19     0   2000-02-29    28940.493929        On Time
# 9853    19     0   2000-03-31    30596.498262        On Time
# 9854    19     0   2000-04-30    28555.627855        On Time
# 9855    19     0   2000-05-31    43426.229219        On Time
# 9856    19     0   2000-06-30    35964.765180        On Time
# 9857    19     0   2000-07-31    25798.261255        On Time
# 9858    19     0   2000-08-31    42088.635816        On Time
# 9859    19     0   2000-09-30    34979.668425        On Time
# 9860    19     0   2000-10-31    42113.316255        On Time
# 9861    19     0   2000-11-30    46193.562100        On Time
# 9862    19     0   2000-12-31    40047.851122        On Time
# 9863    19     0   2001-01-31        0.000000        Default
# 9864    19     0   2001-02-28    37803.975990        On Time
# 9865    19     0   2001-03-31    36988.045904        On Time
# 9866    19     0   2001-04-30    29601.385762        On Time
# 9867    19     0   2001-05-31    27679.080961        On Time
# 9868    19     0   2001-06-30     1062.139677     Delinquent
# 9869    19     0   2001-07-31    29681.907409        On Time
# 9870    19     0   2001-08-31    47952.838894        On Time
# 9871    19     0   2001-09-30        0.000000        Default
# 9872    19     0   2001-10-31    36302.298075        On Time
# 9873    19     0   2001-11-30    37196.232846        On Time
# 9874    19     0   2001-12-31    43197.361536        On Time
# 9875    19     0   2002-01-31    37540.419032        On Time
# 9876    19     0   2002-02-28    31957.380046        On Time
# 9877    19     0   2002-03-31    40477.200352        On Time
# 9878    19     0   2002-04-30    26584.137101        On Time
# 9879    19     0   2002-05-31    48802.163225        On Time
# 9880    19     0   2002-06-30    41803.420136        On Time
# 9881    19     0   2002-07-31    29735.366201        On Time
# 9882    19     0   2002-08-31    10608.546092     Delinquent
# 9883    19     0   2002-09-30    28234.740812        On Time
# 9884    19     0   2002-10-31    44580.606425        On Time
# 9885    19     0   2002-11-30    39856.402619        On Time
# 9886    19     0   2002-12-31    12220.575264     Delinquent
# 9887    19     0   2003-01-31    38036.619445        On Time
# 9888    19     0   2003-02-28    39402.913386        On Time
# 9889    19     0   2003-03-31    34794.411147        On Time
# 9890    19     0   2003-04-30        0.000000        Default
# 9891    19     0   2003-05-31    45480.179859        On Time
# 9892    19     0   2003-06-30        0.000000        Default
# 9893    19     0   2003-07-31    33043.203894        On Time
# 9894    19     0   2003-08-31    32806.395360        On Time
# 9895    19     0   2003-09-30    13050.496356     Delinquent
# 9896    19     0   2003-10-31    28560.743361        On Time
# 9897    19     0   2003-11-30    26588.761456        On Time
# 9898    19     0   2003-12-31    31054.268546        On Time
# 9899    19     0   2004-01-31    40827.015710        On Time
# 9900    19     0   2004-02-29    30286.122725        On Time
# 9901    19     0   2004-03-31    33305.899161        On Time
# 9902    19     0   2004-04-30    49444.500948        On Time
# 9903    19     0   2004-05-31    34255.695131        On Time
# 9904    19     0   2004-06-30    34418.220097        On Time
# 9905    19     0   2004-07-31    49711.197411        On Time
# 9906    19     0   2004-08-31    38444.031957        On Time
# 9907    19     0   2004-09-30    49803.900900        On Time
# 9908    19     0   2004-10-31    30414.090805        On Time
# 9909    19     0   2004-11-30    33437.450744        On Time
# 9910    19     0   2004-12-31    33216.642862        On Time
# 9911    19     0   2005-01-31    22330.456637     Delinquent
# 9912    19     0   2005-02-28    33788.053345        On Time
# 9913    19     0   2005-03-31    42472.951884        On Time
# 9914    19     0   2005-04-30    31100.782036        On Time
# 9915    19     0   2005-05-31    41055.848292        On Time
# 9916    19     0   2005-06-30    15716.272725     Delinquent
# 9917    19     0   2005-07-31    41287.783154        On Time
# 9918    19     0   2005-08-31    33884.002414        On Time
# 9919    19     0   2005-09-30    49011.689824        On Time
# 9920    19     0   2005-10-31    45638.089078        On Time
# 9921    19     0   2005-11-30    31975.186753        On Time
# 9922    19     0   2005-12-31    38857.736008        On Time
# 9923    19     0   2006-01-31    34622.044409        On Time
# 9924    19     0   2006-02-28    42170.343974        On Time
# 9925    19     0   2006-03-31    30884.782501        On Time
# 9926    19     0   2006-04-30    35302.003868        On Time
# 9927    19     0   2006-05-31    17552.148489     Delinquent
# 9928    19     0   2006-06-30        0.000000        Default
# 9929    19     0   2006-07-31    34518.020557        On Time
# 9930    19     0   2006-08-31    41980.601117        On Time
# 9931    19     0   2006-09-30    40221.158857        On Time
# 9932    19     0   2006-10-31    34553.097647        On Time
# 9933    19     0   2006-11-30    24741.364651     Delinquent
# 9934    19     0   2006-12-31    27635.966839        On Time
# 9935    19     0   2007-01-31    45954.749985        On Time
# 9936    19     0   2007-02-28    29708.466568        On Time
# 9937    19     0   2007-03-31    37714.390850        On Time
# 9938    19     0   2007-04-30    35110.386307        On Time
# 9939    19     0   2007-05-31    15471.059421     Delinquent
# 9940    19     0   2007-06-30    41104.582642        On Time
# 9941    19     0   2007-07-31    47701.666466        On Time
# 9942    19     0   2007-08-31     8521.779107     Delinquent
# 9943    19     0   2007-09-30    38373.921028        On Time
# 9944    19     0   2007-10-31    30148.929831        On Time
# 9945    19     0   2007-11-30    28996.008970        On Time
# 9946    19     0   2007-12-31    41005.709356        On Time
# 9947    19     0   2008-01-31    25184.654455        On Time
# 9948    19     0   2008-02-29    36995.193674        On Time
# 9949    19     0   2008-03-31    11650.639366     Delinquent
# 9950    19     0   2008-04-30    30604.156432        On Time
# 9951    19     0   2008-05-31    32767.164725        On Time
# 9952    19     0   2008-06-30    39420.222107        On Time
# 9953    19     0   2008-07-31    33947.984550        On Time
# 9954    19     0   2008-08-31    40274.369839        On Time
# 9955    19     0   2008-09-30    30187.664287        On Time
# 9956    19     0   2008-10-31    31169.947176        On Time
# 9957    19     0   2008-11-30    22109.599344     Delinquent
# 9958    19     0   2008-12-31    27214.360182        On Time
# 9959    19     0   2009-01-31    28667.355002        On Time
# 9960    19     0   2009-02-28    11254.853200     Delinquent
# 9961    19     0   2009-03-31    32610.594369        On Time
# 9962    19     0   2009-04-30    47953.199192        On Time
# 9963    19     0   2009-05-31     6256.089491     Delinquent
# 9964    19     0   2009-06-30    27829.448734        On Time
# 9965    19     0   2009-07-31    31861.276046        On Time
# 9966    19     0   2009-08-31    28792.532058        On Time
# 9967    19     0   2009-09-30    45715.890265        On Time
# 9968    19     0   2009-10-31    36753.599553        On Time
# 9969    19     0   2009-11-30    33218.415802        On Time
# 9970    19     0   2009-12-31    42972.644854        On Time
# 9971    19     0   2010-01-31    35703.561701        On Time
# 9972    19     0   2010-02-28    49206.639933        On Time
# 9973    19     0   2010-03-31    35528.759617        On Time
# 9974    19     0   2010-04-30    46103.413493        On Time
# 9975    19     0   2010-05-31    48796.878129        On Time
# 9976    19     0   2010-06-30    48107.728063        On Time
# 9977    19     0   2010-07-31    34475.757642        On Time
# 9978    19     0   2010-08-31    29955.462486        On Time
# 9979    19     0   2010-09-30    27190.094353        On Time
# 9980    19     0   2010-10-31    15381.130973     Delinquent
# 9981    19     0   2010-11-30    35194.073153        On Time
# 9982    19     0   2010-12-31      588.235172     Delinquent
# 9983    19     0   2011-01-31    35704.026680        On Time
# 9984    19     0   2011-02-28    27738.710858        On Time
# 9985    19     0   2011-03-31    42521.810962        On Time
# 9986    19     0   2011-04-30    29440.994420        On Time
# 9987    19     0   2011-05-31    40273.515776        On Time
# 9988    19     0   2011-06-30     2094.387984     Delinquent
# 9989    19     0   2011-07-31    32408.809480        On Time
# 9990    19     0   2011-08-31    29579.744799        On Time
# 9991    19     0   2011-09-30    36372.191213        On Time
# 9992    19     0   2011-10-31    41593.942641        On Time
# 9993    19     0   2011-11-30    43588.377543        On Time
# 9994    19     0   2011-12-31    28878.026182        On Time
# 9995    19     0   2012-01-31    41936.412804        On Time
# 9996    19     0   2012-02-29    30689.047255        On Time
# 9997    19     0   2012-03-31    29282.000808        On Time
# 9998    19     0   2012-04-30    20076.329962     Delinquent
# 9999    19     0   2012-05-31    48836.896094        On Time

# %% [markdown]
# ### Output Credit Card Data as CSV

# %%
# Output DataFrame to CSV file
cc_df.to_csv(f"{outdir}/cards_processed.csv", index=False)

# %% [markdown]
# ## Process Users Data from S3
#
# 1. [Load Users Data from S3.](#Load-Users-Data-from-S3)
# 2. [Load Contracts Data from S3.](#Load-Contracts-Data-from-S3)
# 3. [Join Credit Loss Attributes to Users Data.](#Join-Credit-Loss-Attributes-to-Users-Data)
# 4. [Format Users Data.](#Format-Users-Data)
# 5. [Output Users Data as CSV.](#Output-Users-Data-as-CSV)

# %% [markdown]
# ### Load Users Data from S3

# %%
# Load users data
users_df = pd.read_csv("s3://data.atoti.io/notebooks/retail-banking/input/users.csv")
users_df = users_df.rename_axis("User").reset_index()
users_df
# Out:
#       User             Person  Current Age  Retirement Age  Birth Year  \
# 0        0     Hazel Robinson           53              66        1966
# 1        1         Sasha Sadr           53              68        1966
# 2        2         Saanvi Lee           81              67        1938
# 3        3      Everlee Clark           63              63        1957
# 4        4      Kyle Peterson           43              70        1976
# ...    ...                ...          ...             ...         ...
# 1995  1995       Jose Faraday           32              70        1987
# 1996  1996  Ximena Richardson           62              65        1957
# 1997  1997     Annika Russell           47              67        1973
# 1998  1998        Juelz Roman           66              60        1954
# 1999  1999       Kenia Harris           21              60        1998
#
#       Birth Month  Gender                   Address  Apartment           City  \
# 0              11  Female             462 Rose Lane        NaN       La Verne
# 1              12  Female    3606 Federal Boulevard        NaN    Little Neck
# 2              11  Female           766 Third Drive        NaN    West Covina
# 3               1  Female          3 Madison Street        NaN       New York
# 4               9    Male  9620 Valley Stream Drive        NaN  San Francisco
# ...           ...     ...                       ...        ...            ...
# 1995            7    Male       6577 Lexington Lane        9.0       Freeport
# 1996           11  Female               2 Elm Drive      955.0   Independence
# 1997            1  Female       276 Fifth Boulevard        NaN      Elizabeth
# 1998            2    Male      259 Valley Boulevard        NaN      Camp Hill
# 1999           11  Female     472 Ocean View Street        NaN      Merrimack
#
#      State  Zipcode  Latitude  Longitude Per Capita Income - Zipcode  \
# 0       CA    91750     34.15    -117.76                      $29278
# 1       NY    11363     40.76     -73.74                      $37891
# 2       CA    91792     34.02    -117.89                      $22681
# 3       NY    10069     40.71     -73.99                     $163145
# 4       CA    94117     37.76    -122.44                      $53797
# ...    ...      ...       ...        ...                         ...
# 1995    NY    11520     40.65     -73.58                      $23550
# 1996    KY    41051     38.95     -84.54                      $24218
# 1997    NJ     7201     40.66     -74.19                      $15175
# 1998    PA    17011     40.24     -76.92                      $25336
# 1999    NH     3054     42.86     -71.48                      $32325
#
#      Yearly Income - Person Total Debt  FICO Score  Num Credit Cards
# 0                    $59696    $127613         787                 5
# 1                    $77254    $191349         701                 5
# 2                    $33483       $196         698                 5
# 3                   $249925    $202328         722                 4
# 4                   $109687    $183855         675                 1
# ...                     ...        ...         ...               ...
# 1995                 $48010     $87837         703                 3
# 1996                 $49378    $104480         740                 4
# 1997                 $30942     $71066         779                 3
# 1998                 $54654     $27241         618                 1
# 1999                 $65909    $181261         673                 2
#
# [2000 rows x 19 columns]

# %% [markdown]
# ### Load Contracts Data from S3

# %%
# Use `read_csv` pandas function to load contracts data from S3 URI
contracts_df = pd.read_csv(
    "s3://data.atoti.io/notebooks/retail-banking/input/loan_contracts.csv",
    low_memory=False,
)
contracts_df
# Out:
#        Reporting Date           EAD      PD12      PDLT       LGD  \
# 0            12/30/22  69795.693590  0.057123  0.024117  0.607348
# 1            12/30/22  24045.796250  0.056460  0.021793  0.613929
# 2            12/30/22   2019.251356  0.017708  0.017708  0.607348
# 3            12/30/22  20563.067570  0.034836  0.154493  0.613929
# 4            12/30/22   2666.804003  0.017043  0.017043  0.613929
# ...               ...           ...       ...       ...       ...
# 336393       12/30/22    460.992072  0.041017  0.041017  0.322573
# 336394       12/30/22    116.777909  0.041017  0.041017  0.322573
# 336395       12/30/22   2461.296310  0.013934  0.063931  0.497079
# 336396       12/30/22  41522.000000  0.019270  0.038064  0.607348
# 336397       12/30/22  41031.000000  0.020043  0.038103  0.613929
#
#        Maturity Date  Residual Maturity Bucketed Arrears  Reporting Index  \
# 0            11/5/32               3597                0                2
# 1            12/5/32               3598                0                0
# 2            8/10/23                460                0              113
# 3            8/15/31               3152                0               17
# 4            5/15/24                504                0               20
# ...              ...                ...              ...              ...
# 336393      10/15/23                290           91-180               50
# 336394       6/28/23                181                0               47
# 336395        4/9/26               1168                0               44
# 336396       1/15/25                746                0               11
# 336397       1/15/25                746                0               11
#
#         Is New Contract Client ID  FICO FICO Segment LTV Segment  \
# 0                 False  9XFALYXL   300      300-410     81%-90%
# 1                  True  KHAAK99A   300      300-410        >30%
# 2                 False  AZHHTHYX   300      300-410        >30%
# 3                 False  YZAZKX99   300      300-410        >30%
# 4                 False  AZLKF9YH   300      300-410     30%-50%
# ...                 ...       ...   ...          ...         ...
# 336393            False    BN9JJQ   850      741-850     71%-80%
# 336394            False     NSJJQ   850      741-850        >30%
# 336395            False    BJGBJ9   850      741-850     81%-90%
# 336396            False  122O9E2E   850      741-850     71%-80%
# 336397            False  12242K11   850      741-850        >30%
#
#        Macro Economic Scenario   Entity
# 0                         Base    Paris
# 1                         Base    Paris
# 2                         Base    Paris
# 3                         Base    Paris
# 4                         Base    Paris
# ...                        ...      ...
# 336393                    Base  NewYork
# 336394                    Base  NewYork
# 336395                    Base  NewYork
# 336396                    Base  NewYork
# 336397                    Base  NewYork
#
# [336398 rows x 16 columns]

# %% [markdown]
# ### Join Credit Loss Attributes to Users Data

# %%
# Group by FICO and calculate the average for EAD along with other numeric values
groupby_contracts_df = contracts_df.groupby(["FICO"]).mean(["EAD"])
groupby_contracts_df.reset_index()
# Out:
#      FICO          EAD      PD12      PDLT       LGD  Residual Maturity  \
# 0     300  8980.553229  0.104477  0.155930  0.604633        1787.578864
# 1     301  9349.136091  0.112370  0.163001  0.605998        1786.359551
# 2     302  8508.016229  0.100375  0.148074  0.602229        1739.838710
# 3     303  7804.911004  0.091073  0.137547  0.598811        1727.121685
# 4     304  8688.726128  0.103132  0.154085  0.604463        1741.822476
# ..    ...          ...       ...       ...       ...                ...
# 546   846  9125.236908  0.094646  0.143602  0.600449        1820.182566
# 547   847  8643.170678  0.103138  0.149518  0.605348        1697.993681
# 548   848  7772.732491  0.097820  0.148221  0.606113        1737.099130
# 549   849  7968.876954  0.104263  0.151679  0.607293        1769.934084
# 550   850  9627.143318  0.107191  0.156488  0.602894        1759.222910
#
#      Reporting Index  Is New Contract
# 0          26.446372         0.015773
# 1          26.280899         0.028892
# 2          27.416129         0.030645
# 3          26.806552         0.031201
# 4          28.037459         0.027687
# ..               ...              ...
# 546        27.258224         0.023026
# 547        27.949447         0.018957
# 548        27.521739         0.020870
# 549        26.741158         0.030547
# 550        26.934985         0.030960
#
# [551 rows x 8 columns]

# %%
# Join both DataFrames on FICO score to consolidate credit loss attributes
merge_df = pd.merge(
    users_df, groupby_contracts_df, left_on="FICO Score", right_on="FICO"
)
merge_df
# Out:
#       User            Person  Current Age  Retirement Age  Birth Year  \
# 0        0    Hazel Robinson           53              66        1966
# 1      955    Nickolas Lopez           21              67        1999
# 2     1134  Kallie Rodriguez           39              71        1980
# 3     1479   Rylan Rodriguez           33              69        1986
# 4        1        Sasha Sadr           53              68        1966
# ...    ...               ...          ...             ...         ...
# 1995  1796  Alessandro Davis           37              66        1982
# 1996  1817     Darren Turner           31              63        1988
# 1997  1874      August Braun           42              72        1977
# 1998  1888    Kyng El-Mafouk           51              68        1968
# 1999  1905  Janelle Campbell           30              64        1989
#
#       Birth Month  Gender                      Address  Apartment  \
# 0              11  Female                462 Rose Lane        NaN
# 1               2    Male            92196 Tenth Drive        NaN
# 2               7  Female        135 Littlewood Avenue        6.0
# 3              10  Female           928 Bayview Street        NaN
# 4              12  Female       3606 Federal Boulevard        NaN
# ...           ...     ...                          ...        ...
# 1995           12    Male            550 Forest Street        NaN
# 1996            5    Male             6692 Lake Street        NaN
# 1997            8    Male                 331 Oak Lane        NaN
# 1998           10    Male        207 Ocean View Street        NaN
# 1999            8  Female  847 Martin Luther King Lane       97.0
#
#                   City  ... Total Debt  FICO Score  Num Credit Cards  \
# 0             La Verne  ...    $127613         787                 5
# 1             Leesburg  ...     $85204         787                 2
# 2            Oceanside  ...     $91549         787                 1
# 3              Portage  ...         $0         787                 3
# 4          Little Neck  ...    $191349         701                 5
# ...                ...  ...        ...         ...               ...
# 1995            Helena  ...     $71180         580                 1
# 1996      Taylorsville  ...     $53853         514                 1
# 1997           Antioch  ...     $99235         563                 2
# 1998  Berkeley Heights  ...    $242379         505                 1
# 1999          Ray City  ...     $33332         501                 2
#
#               EAD      PD12      PDLT       LGD  Residual Maturity  \
# 0     7543.452009  0.102502  0.148166  0.608904        1664.486322
# 1     7543.452009  0.102502  0.148166  0.608904        1664.486322
# 2     7543.452009  0.102502  0.148166  0.608904        1664.486322
# 3     7543.452009  0.102502  0.148166  0.608904        1664.486322
# 4     8943.997200  0.105292  0.150311  0.602701        1747.076299
# ...           ...       ...       ...       ...                ...
# 1995  8195.670961  0.103159  0.150773  0.607600        1747.212670
# 1996  8681.589080  0.123131  0.171764  0.611464        1825.388976
# 1997  9434.481972  0.097110  0.143415  0.605630        1780.612245
# 1998  8936.491473  0.101380  0.149277  0.602884        1747.658249
# 1999  8529.125961  0.097007  0.142145  0.607841        1749.551938
#
#       Reporting Index  Is New Contract
# 0           28.908815         0.024316
# 1           28.908815         0.024316
# 2           28.908815         0.024316
# 3           28.908815         0.024316
# 4           26.618506         0.038961
# ...               ...              ...
# 1995        26.556561         0.024133
# 1996        27.366929         0.020472
# 1997        26.211931         0.032967
# 1998        26.885522         0.040404
# 1999        25.522481         0.035659
#
# [2000 rows x 26 columns]

# %% [markdown]
# ### Format Users Data

# %%
# View columns of combined DataFrame
merge_df.columns
# Out:
# Index(['User', 'Person', 'Current Age', 'Retirement Age', 'Birth Year',
#        'Birth Month', 'Gender', 'Address', 'Apartment', 'City', 'State',
#        'Zipcode', 'Latitude', 'Longitude', 'Per Capita Income - Zipcode',
#        'Yearly Income - Person', 'Total Debt', 'FICO Score',
#        'Num Credit Cards', 'EAD', 'PD12', 'PDLT', 'LGD', 'Residual Maturity',
#        'Reporting Index', 'Is New Contract'],
#       dtype='object')

# %%
# Remove currency symbols
merge_df["Per Capita Income - Zipcode"] = merge_df[
    "Per Capita Income - Zipcode"
].str.replace("$", "")
merge_df["Yearly Income - Person"] = merge_df["Yearly Income - Person"].str.replace(
    "$", ""
)
merge_df["Total Debt"] = merge_df["Total Debt"].str.replace("$", "")
merge_df

# Cast intended measures and numeric columns
merge_df["Per Capita Income - Zipcode"] = merge_df[
    "Per Capita Income - Zipcode"
].astype(int)
merge_df["Yearly Income - Person"] = merge_df["Yearly Income - Person"].astype(int)
merge_df["Total Debt"] = merge_df["Total Debt"].astype(int)

# %%
# Create age range bins
merge_df["Age Range"] = pd.cut(
    merge_df["Current Age"],
    [0, 10, 20, 30, 40, 50, 60, np.inf],
    labels=["0-9", "10-19", "20-29", "30-39", "40-49", "50-59", "60+"],
    right=False,
)

# Create income range bins
merge_df["Income Range"] = pd.cut(
    merge_df["Yearly Income - Person"],
    [0, 20000, 50000, 80000, 100000, 150000, 200000, np.inf],
    labels=[
        "0K - 20K",
        "20K - 50K",
        "50K - 80K",
        "80K - 100K",
        "100K - 150K",
        "150K - 200K",
        "200K+",
    ],
    right=False,
)

# %%
merge_df
# Out:
#       User            Person  Current Age  Retirement Age  Birth Year  \
# 0        0    Hazel Robinson           53              66        1966
# 1      955    Nickolas Lopez           21              67        1999
# 2     1134  Kallie Rodriguez           39              71        1980
# 3     1479   Rylan Rodriguez           33              69        1986
# 4        1        Sasha Sadr           53              68        1966
# ...    ...               ...          ...             ...         ...
# 1995  1796  Alessandro Davis           37              66        1982
# 1996  1817     Darren Turner           31              63        1988
# 1997  1874      August Braun           42              72        1977
# 1998  1888    Kyng El-Mafouk           51              68        1968
# 1999  1905  Janelle Campbell           30              64        1989
#
#       Birth Month  Gender                      Address  Apartment  \
# 0              11  Female                462 Rose Lane        NaN
# 1               2    Male            92196 Tenth Drive        NaN
# 2               7  Female        135 Littlewood Avenue        6.0
# 3              10  Female           928 Bayview Street        NaN
# 4              12  Female       3606 Federal Boulevard        NaN
# ...           ...     ...                          ...        ...
# 1995           12    Male            550 Forest Street        NaN
# 1996            5    Male             6692 Lake Street        NaN
# 1997            8    Male                 331 Oak Lane        NaN
# 1998           10    Male        207 Ocean View Street        NaN
# 1999            8  Female  847 Martin Luther King Lane       97.0
#
#                   City  ... Num Credit Cards          EAD      PD12      PDLT  \
# 0             La Verne  ...                5  7543.452009  0.102502  0.148166
# 1             Leesburg  ...                2  7543.452009  0.102502  0.148166
# 2            Oceanside  ...                1  7543.452009  0.102502  0.148166
# 3              Portage  ...                3  7543.452009  0.102502  0.148166
# 4          Little Neck  ...                5  8943.997200  0.105292  0.150311
# ...                ...  ...              ...          ...       ...       ...
# 1995            Helena  ...                1  8195.670961  0.103159  0.150773
# 1996      Taylorsville  ...                1  8681.589080  0.123131  0.171764
# 1997           Antioch  ...                2  9434.481972  0.097110  0.143415
# 1998  Berkeley Heights  ...                1  8936.491473  0.101380  0.149277
# 1999          Ray City  ...                2  8529.125961  0.097007  0.142145
#
#            LGD  Residual Maturity  Reporting Index  Is New Contract  \
# 0     0.608904        1664.486322        28.908815         0.024316
# 1     0.608904        1664.486322        28.908815         0.024316
# 2     0.608904        1664.486322        28.908815         0.024316
# 3     0.608904        1664.486322        28.908815         0.024316
# 4     0.602701        1747.076299        26.618506         0.038961
# ...        ...                ...              ...              ...
# 1995  0.607600        1747.212670        26.556561         0.024133
# 1996  0.611464        1825.388976        27.366929         0.020472
# 1997  0.605630        1780.612245        26.211931         0.032967
# 1998  0.602884        1747.658249        26.885522         0.040404
# 1999  0.607841        1749.551938        25.522481         0.035659
#
#       Age Range  Income Range
# 0         50-59     50K - 80K
# 1         20-29    80K - 100K
# 2         30-39     20K - 50K
# 3         30-39     20K - 50K
# 4         50-59     50K - 80K
# ...         ...           ...
# 1995      30-39     20K - 50K
# 1996      30-39     20K - 50K
# 1997      40-49     50K - 80K
# 1998      50-59   100K - 150K
# 1999      30-39     20K - 50K
#
# [2000 rows x 28 columns]

# %%
# Drop extraneous columns
merge_df.drop(
    columns=["Residual Maturity", "Reporting Index", "Is New Contract"], inplace=True
)

# %% [markdown]
# ### Output Users Data as CSV

# %%
merge_df.to_csv(f"{outdir}/users_processed.csv", index=False)

# %% [markdown]
# ## Process Credit Card Transactions Data from S3
#
# * [Load Credit Card Transactions Data from S3](#Load-Credit-Card-Transactions-Data-from-S3)
# * [Modify Merchant Names to be MerchantN](#Modify-Merchant-Names-to-be-MerchantN-e.g.-(Merchant1,-Merchant2,-etc.))
# * [Join New Merchant Names to Credit Card Transactions Data](#Join-New-Merchant-Names-to-Credit-Card-Transactions-Data)
# * [Drop Extraneous Columns and Format Data](#Drop-Extraneous-Columns-and-Format-Data)
# * [Format Credit Card Transactions Data](#Format-Credit-Card-Transactions-Data)
# * [Downsize Original Data Volume to 5 Million](#Downsize-Original-Data-Volume-to-5-Million)
# * [Simulate Payments](#Simulate-Payments)
# * [Output Credit Card Transactions Data to CSV](#Output-Credit-Card-Transactions-Data-to-CSV)
# * [Compress CSV to GZIP](#Compress-CSV-to-GZIP)

# %% [markdown]
# ### Load Credit Card Transactions Data from S3

# %%
# Use `read_csv` pandas function to load contracts data from S3 URI
cc_sales_gzip_df = pd.read_csv(
    "s3://data.atoti.io/notebooks/retail-banking/input/credit_card_transactions.csv.gz",
    compression="gzip",
)
cc_sales_gzip_df
# Out:
#           User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0            0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1            0     0  2002      9    1  06:42   $38.48  Swipe Transaction
# 2            0     0  2002      9    2  06:22  $120.34  Swipe Transaction
# 3            0     0  2002      9    2  17:45  $128.95  Swipe Transaction
# 4            0     0  2002      9    3  06:23  $104.71  Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...      ...                ...
# 24386895  1999     1  2020      2   27  22:23  $-54.00   Chip Transaction
# 24386896  1999     1  2020      2   27  22:24   $54.00   Chip Transaction
# 24386897  1999     1  2020      2   28  07:43   $59.15   Chip Transaction
# 24386898  1999     1  2020      2   28  20:10   $43.12   Chip Transaction
# 24386899  1999     1  2020      2   28  23:10   $45.13   Chip Transaction
#
#                 Merchant Name  Merchant City Merchant State      Zip   MCC  \
# 0         3527213246127876953       La Verne             CA  91750.0  5300
# 1         -727612092139916043  Monterey Park             CA  91754.0  5411
# 2         -727612092139916043  Monterey Park             CA  91754.0  5411
# 3         3414527459579106770  Monterey Park             CA  91754.0  5651
# 4         5817218446178736267       La Verne             CA  91750.0  5912
# ...                       ...            ...            ...      ...   ...
# 24386895 -5162038175624867091      Merrimack             NH   3054.0  5541
# 24386896 -5162038175624867091      Merrimack             NH   3054.0  5541
# 24386897  2500998799892805156      Merrimack             NH   3054.0  4121
# 24386898  2500998799892805156      Merrimack             NH   3054.0  4121
# 24386899  4751695835751691036      Merrimack             NH   3054.0  5814
#
#          Errors? Is Fraud?
# 0            NaN        No
# 1            NaN        No
# 2            NaN        No
# 3            NaN        No
# 4            NaN        No
# ...          ...       ...
# 24386895     NaN        No
# 24386896     NaN        No
# 24386897     NaN        No
# 24386898     NaN        No
# 24386899     NaN        No
#
# [24386900 rows x 15 columns]

# %% [markdown]
# ### Modify Merchant Names to be MerchantN e.g. (Merchant1, Merchant2, etc.)

# %%
merchant_name_df = pd.DataFrame(
    cc_sales_gzip_df.groupby("Merchant Name").count().index.tolist(),
    columns=["Merchant Name"],
)
merchant_name_df
# Out:
#               Merchant Name
# 0      -9222899435637403521
# 1      -9222692221935167526
# 2      -9222439367252190791
# 3      -9222264855000293132
# 4      -9222232253446715869
# ...                     ...
# 100338  9222821118491815331
# 100339  9222874644865944349
# 100340  9222877122873253163
# 100341  9222957302638210593
# 100342  9223291803303717674
#
# [100343 rows x 1 columns]

# %%
merchant_name_df.insert(1, "Merchant Name (Revised)", "")
merchant_name_df
# Out:
#               Merchant Name Merchant Name (Revised)
# 0      -9222899435637403521
# 1      -9222692221935167526
# 2      -9222439367252190791
# 3      -9222264855000293132
# 4      -9222232253446715869
# ...                     ...                     ...
# 100338  9222821118491815331
# 100339  9222874644865944349
# 100340  9222877122873253163
# 100341  9222957302638210593
# 100342  9223291803303717674
#
# [100343 rows x 2 columns]

# %%
counter = 1

for index, row in merchant_name_df.iterrows():
    name = f"Merchant {counter}"
    merchant_name_df.loc[index, "Merchant Name (Revised)"] = name
    counter += 1

# %%
merchant_name_df
# Out:
#               Merchant Name Merchant Name (Revised)
# 0      -9222899435637403521              Merchant 1
# 1      -9222692221935167526              Merchant 2
# 2      -9222439367252190791              Merchant 3
# 3      -9222264855000293132              Merchant 4
# 4      -9222232253446715869              Merchant 5
# ...                     ...                     ...
# 100338  9222821118491815331         Merchant 100339
# 100339  9222874644865944349         Merchant 100340
# 100340  9222877122873253163         Merchant 100341
# 100341  9222957302638210593         Merchant 100342
# 100342  9223291803303717674         Merchant 100343
#
# [100343 rows x 2 columns]

# %% [markdown]
# ### Join New Merchant Names to Credit Card Transactions Data

# %%
merchant_name_merge_df = pd.merge(
    cc_sales_gzip_df,
    merchant_name_df,
    left_on="Merchant Name",
    right_on="Merchant Name",
)
merchant_name_merge_df
# Out:
#           User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0            0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1            0     0  2002      9   10  06:22  $102.18  Swipe Transaction
# 2            0     0  2002      9   16  06:00  $115.34  Swipe Transaction
# 3            0     0  2002      9   18  06:19  $128.85  Swipe Transaction
# 4            0     0  2002      9   23  06:01  $134.89  Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...      ...                ...
# 24386895  1999     1  2019     12   21  07:59   $42.80   Chip Transaction
# 24386896  1999     1  2019     12   22  08:15   $46.72   Chip Transaction
# 24386897  1999     1  2019     12   22  20:25   $46.30   Chip Transaction
# 24386898  1999     1  2019     12   23  19:48   $49.00   Chip Transaction
# 24386899  1999     1  2019     12   24  07:50   $48.02   Chip Transaction
#
#                 Merchant Name Merchant City Merchant State      Zip   MCC  \
# 0         3527213246127876953      La Verne             CA  91750.0  5300
# 1         3527213246127876953      La Verne             CA  91750.0  5300
# 2         3527213246127876953      La Verne             CA  91750.0  5300
# 3         3527213246127876953      La Verne             CA  91750.0  5300
# 4         3527213246127876953      La Verne             CA  91750.0  5300
# ...                       ...           ...            ...      ...   ...
# 24386895 -3533580464561517260  Russellville             AL  35653.0  4121
# 24386896 -3533580464561517260  Russellville             AL  35653.0  4121
# 24386897 -3533580464561517260  Russellville             AL  35653.0  4121
# 24386898 -3533580464561517260  Russellville             AL  35653.0  4121
# 24386899 -3533580464561517260  Russellville             AL  35653.0  4121
#
#          Errors? Is Fraud? Merchant Name (Revised)
# 0            NaN        No          Merchant 69375
# 1            NaN        No          Merchant 69375
# 2            NaN        No          Merchant 69375
# 3            NaN        No          Merchant 69375
# 4            NaN        No          Merchant 69375
# ...          ...       ...                     ...
# 24386895     NaN        No          Merchant 31143
# 24386896     NaN        No          Merchant 31143
# 24386897     NaN        No          Merchant 31143
# 24386898     NaN        No          Merchant 31143
# 24386899     NaN        No          Merchant 31143
#
# [24386900 rows x 16 columns]

# %% [markdown]
# ### Drop Extraneous Columns and Format Data

# %%
merchant_name_merge_df.pop("Merchant Name")
merchant_name_merge_df.rename(
    columns={"Merchant Name (Revised)": "Merchant Name"}, inplace=True
)

merchant_name_merge_df["Year"] = merchant_name_merge_df["Year"].astype(str)
merchant_name_merge_df["Month"] = merchant_name_merge_df["Month"].astype(str)
merchant_name_merge_df["Day"] = merchant_name_merge_df["Day"].astype(str)

# Create a `Datetime` column and combine values
# From Year, Month, Day, and Time columns to
# Create a proper Datetime data type column
merchant_name_merge_df.insert(2, "Datetime", "")
merchant_name_merge_df["Datetime"] = pd.to_datetime(
    merchant_name_merge_df["Year"]
    + " "
    + merchant_name_merge_df["Month"]
    + " "
    + merchant_name_merge_df["Day"]
    + " "
    + merchant_name_merge_df["Time"]
)
merchant_name_merge_df.drop(columns=["Year", "Month", "Day", "Time"], inplace=True)
merchant_name_merge_df
# Out:
#           User  Card            Datetime   Amount           Use Chip  \
# 0            0     0 2002-09-01 06:21:00  $134.09  Swipe Transaction
# 1            0     0 2002-09-10 06:22:00  $102.18  Swipe Transaction
# 2            0     0 2002-09-16 06:00:00  $115.34  Swipe Transaction
# 3            0     0 2002-09-18 06:19:00  $128.85  Swipe Transaction
# 4            0     0 2002-09-23 06:01:00  $134.89  Swipe Transaction
# ...        ...   ...                 ...      ...                ...
# 24386895  1999     1 2019-12-21 07:59:00   $42.80   Chip Transaction
# 24386896  1999     1 2019-12-22 08:15:00   $46.72   Chip Transaction
# 24386897  1999     1 2019-12-22 20:25:00   $46.30   Chip Transaction
# 24386898  1999     1 2019-12-23 19:48:00   $49.00   Chip Transaction
# 24386899  1999     1 2019-12-24 07:50:00   $48.02   Chip Transaction
#
#          Merchant City Merchant State      Zip   MCC Errors? Is Fraud?  \
# 0             La Verne             CA  91750.0  5300     NaN        No
# 1             La Verne             CA  91750.0  5300     NaN        No
# 2             La Verne             CA  91750.0  5300     NaN        No
# 3             La Verne             CA  91750.0  5300     NaN        No
# 4             La Verne             CA  91750.0  5300     NaN        No
# ...                ...            ...      ...   ...     ...       ...
# 24386895  Russellville             AL  35653.0  4121     NaN        No
# 24386896  Russellville             AL  35653.0  4121     NaN        No
# 24386897  Russellville             AL  35653.0  4121     NaN        No
# 24386898  Russellville             AL  35653.0  4121     NaN        No
# 24386899  Russellville             AL  35653.0  4121     NaN        No
#
#            Merchant Name
# 0         Merchant 69375
# 1         Merchant 69375
# 2         Merchant 69375
# 3         Merchant 69375
# 4         Merchant 69375
# ...                  ...
# 24386895  Merchant 31143
# 24386896  Merchant 31143
# 24386897  Merchant 31143
# 24386898  Merchant 31143
# 24386899  Merchant 31143
#
# [24386900 rows x 12 columns]

# %%
merchant_name_merge_df_revised = merchant_name_merge_df[
    [
        "User",
        "Card",
        "Datetime",
        "Amount",
        "Use Chip",
        "Merchant Name",
        "Merchant City",
        "Merchant State",
        "Zip",
        "MCC",
        "Errors?",
        "Is Fraud?",
    ]
].copy()

# %%
merchant_name_merge_df_revised
# Out:
#           User  Card            Datetime   Amount           Use Chip  \
# 0            0     0 2002-09-01 06:21:00  $134.09  Swipe Transaction
# 1            0     0 2002-09-10 06:22:00  $102.18  Swipe Transaction
# 2            0     0 2002-09-16 06:00:00  $115.34  Swipe Transaction
# 3            0     0 2002-09-18 06:19:00  $128.85  Swipe Transaction
# 4            0     0 2002-09-23 06:01:00  $134.89  Swipe Transaction
# ...        ...   ...                 ...      ...                ...
# 24386895  1999     1 2019-12-21 07:59:00   $42.80   Chip Transaction
# 24386896  1999     1 2019-12-22 08:15:00   $46.72   Chip Transaction
# 24386897  1999     1 2019-12-22 20:25:00   $46.30   Chip Transaction
# 24386898  1999     1 2019-12-23 19:48:00   $49.00   Chip Transaction
# 24386899  1999     1 2019-12-24 07:50:00   $48.02   Chip Transaction
#
#            Merchant Name Merchant City Merchant State      Zip   MCC Errors?  \
# 0         Merchant 69375      La Verne             CA  91750.0  5300     NaN
# 1         Merchant 69375      La Verne             CA  91750.0  5300     NaN
# 2         Merchant 69375      La Verne             CA  91750.0  5300     NaN
# 3         Merchant 69375      La Verne             CA  91750.0  5300     NaN
# 4         Merchant 69375      La Verne             CA  91750.0  5300     NaN
# ...                  ...           ...            ...      ...   ...     ...
# 24386895  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386896  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386897  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386898  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386899  Merchant 31143  Russellville             AL  35653.0  4121     NaN
#
#          Is Fraud?
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ...            ...
# 24386895        No
# 24386896        No
# 24386897        No
# 24386898        No
# 24386899        No
#
# [24386900 rows x 12 columns]

# %% [markdown]
# ### Format Credit Card Transactions Data

# %%
# Cast intended measures as numerical data types
merchant_name_merge_df_revised["Amount"] = merchant_name_merge_df_revised[
    "Amount"
].str.replace("$", "")
merchant_name_merge_df_revised["Amount"] = merchant_name_merge_df_revised[
    "Amount"
].astype(float)
merchant_name_merge_df_revised["Amount"] = (
    merchant_name_merge_df_revised["Amount"] * 0.20
)

# %% [markdown]
# ### Downsize Original Data Volume to 5 Million

# %%
merchant_name_merge_df_5MM = merchant_name_merge_df_revised[19386900:]

# %% [markdown]
# ### Simulate Payments

# %%
dfupdate = merchant_name_merge_df_5MM.sample(1000000)
dfupdate.Amount *= -1
merchant_name_merge_df_5MM.update(dfupdate)
merchant_name_merge_df_5MM.head(20)
# Out:
#           User  Card            Datetime  Amount           Use Chip  \
# 19386900    50     0 2019-07-04 23:37:00   4.432   Chip Transaction
# 19386901    50     1 2019-06-28 23:33:00   3.436   Chip Transaction
# 19386902   792     1 2015-11-28 16:08:00   1.672   Chip Transaction
# 19386903  1210     1 2007-03-07 22:52:00   4.076  Swipe Transaction
# 19386904  1575     0 2016-05-23 07:07:00   2.462  Swipe Transaction
# 19386905    50     0 2019-12-17 23:56:00   3.818   Chip Transaction
# 19386906    50     3 2017-01-07 23:46:00  -1.750   Chip Transaction
# 19386907   598     1 2019-09-18 15:09:00   3.660   Chip Transaction
# 19386908   598     1 2019-09-18 15:51:00  -4.084   Chip Transaction
# 19386909   598     1 2019-09-20 15:10:00   3.144   Chip Transaction
# 19386910   598     1 2019-09-21 15:27:00   3.434   Chip Transaction
# 19386911   598     2 2019-09-12 15:15:00   3.090   Chip Transaction
# 19386912   598     2 2019-09-13 15:05:00  -4.496   Chip Transaction
# 19386913   598     2 2019-09-17 14:56:00  -3.672   Chip Transaction
# 19386914   598     2 2019-09-19 16:02:00   3.448   Chip Transaction
# 19386915   598     3 2019-10-03 15:11:00   3.888   Chip Transaction
# 19386916   598     3 2019-10-08 15:24:00   3.964   Chip Transaction
# 19386917    50     0 2019-12-24 02:53:00   5.778   Chip Transaction
# 19386918    50     0 2019-12-25 02:35:00   4.002   Chip Transaction
# 19386919    50     1 2019-12-25 03:19:00   4.874   Chip Transaction
#
#            Merchant Name Merchant City Merchant State      Zip   MCC Errors?  \
# 19386900  Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 19386901  Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 19386902  Merchant 47076       Yonkers             NY  10703.0  5921     NaN
# 19386903  Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 19386904  Merchant 47076    Shreveport             LA  71107.0  5921     NaN
# 19386905  Merchant 48650     Whittaker             MI  48190.0  5921     NaN
# 19386906  Merchant 48650     Whittaker             MI  48190.0  5921     NaN
# 19386907  Merchant 48650     Whittaker             MI  48190.0  5921     NaN
# 19386908  Merchant 48650     Whittaker             MI  48190.0  5921     NaN
# 19386909  Merchant 48650     Whittaker             MI  48190.0  5921     NaN
# 19386910  Merchant 48650     Whittaker             MI  48190.0  5921     NaN
# 19386911  Merchant 48650     Whittaker             MI  48190.0  5921     NaN
# 19386912  Merchant 48650     Whittaker             MI  48190.0  5921     NaN
# 19386913  Merchant 48650     Whittaker             MI  48190.0  5921     NaN
# 19386914  Merchant 48650     Whittaker             MI  48190.0  5921     NaN
# 19386915  Merchant 48650     Whittaker             MI  48190.0  5921     NaN
# 19386916  Merchant 48650     Whittaker             MI  48190.0  5921     NaN
# 19386917  Merchant 95246       Waltham             MA   2451.0  5813     NaN
# 19386918  Merchant 95246       Waltham             MA   2451.0  5813     NaN
# 19386919  Merchant 95246       Waltham             MA   2451.0  5813     NaN
#
#          Is Fraud?
# 19386900        No
# 19386901        No
# 19386902        No
# 19386903        No
# 19386904        No
# 19386905        No
# 19386906        No
# 19386907        No
# 19386908        No
# 19386909        No
# 19386910        No
# 19386911        No
# 19386912        No
# 19386913        No
# 19386914        No
# 19386915        No
# 19386916        No
# 19386917        No
# 19386918        No
# 19386919        No

# %% [markdown]
# ### Output Credit Card Transactions Data to CSV

# %%
merchant_name_merge_df_5MM.to_csv(
    f"{outdir}/credit_card_transactions_processed_5MM.csv", index=False
)

# %% [markdown]
# ### Compress CSV to GZIP

# %%
# !gzip -f data/credit_card_transactions_processed_5MM.csv

# %% [markdown]
# ## Notes for Improvement
#
# * We can refactor the entity relationship assignment for Cards-to-Retailers.
# * We should adjust `Amount` values depending on the category of the purchase (e.g. Airline purchases should probably be over $100 at minimum).
# * We shoud make sure that no single user is over `100%` credit card utilization.
# * We should make sure that no single user is under `0%` credit card utilization.

# %% [markdown]
# <div style="text-align: center;" ><a href="https://www.atoti.io/?utm_source=gallery&utm_content=cc-data-generator" target="_blank" rel="noopener noreferrer"><img src="https://data.atoti.io/notebooks/banners/Your-turn-to-try-Atoti.jpg" alt="Try atoti"></a></div>
