# %% [markdown]
# ## Import Dependencies

# %%
import atoti
import pandas as pd
import time

# %% [markdown]
# ## Load Data from S3

# %%
# Load credit card info data
cc_df = pd.read_csv('s3://data.atoti.io/notebooks/retail-banking/sd254_cards.csv')
cc_df
# Out:
#       User  CARD INDEX  Card Brand        Card Type       Card Number  \
# 0        0           0        Visa            Debit  4344676511950444
# 1        0           1        Visa            Debit  4956965974959986
# 2        0           2        Visa            Debit  4582313478255491
# 3        0           3        Visa           Credit  4879494103069057
# 4        0           4  Mastercard  Debit (Prepaid)  5722874738736011
# ...    ...         ...         ...              ...               ...
# 6141  1997           1        Amex           Credit   300609782832003
# 6142  1997           2        Visa           Credit  4718517475996018
# 6143  1998           0  Mastercard           Credit  5929512204765914
# 6144  1999           0  Mastercard            Debit  5589768928167462
# 6145  1999           1        Visa           Credit  4994011318343994
#
#       Expires  CVV Has Chip  Cards Issued Credit Limit Acct Open Date  \
# 0     12/2022  623      YES             2       $24295        09/2002
# 1     12/2020  393      YES             2       $21968        04/2014
# 2     02/2024  719      YES             2       $46414        07/2003
# 3     08/2024  693       NO             1       $12400        01/2003
# 4     03/2009   75      YES             1          $28        09/2008
# ...       ...  ...      ...           ...          ...            ...
# 6141  01/2024  663      YES             1        $6900        11/2000
# 6142  01/2021  492      YES             2        $5700        04/2012
# 6143  08/2020  237       NO             2        $9200        02/2012
# 6144  01/2020  630      YES             1       $28074        01/2020
# 6145  12/2020  120      YES             1       $14400        05/2017
#
#       Year PIN last Changed Card on Dark Web
# 0                      2008               No
# 1                      2014               No
# 2                      2004               No
# 3                      2012               No
# 4                      2009               No
# ...                     ...              ...
# 6141                   2013               No
# 6142                   2012               No
# 6143                   2012               No
# 6144                   2020               No
# 6145                   2017               No
#
# [6146 rows x 13 columns]

# %% [markdown]
# ## Analyze User Credit Card Data

# %%
# Find the distinct credit card brands
unique_values = cc_df['Card Brand'].unique()
print(sorted(unique_values))
# Out:
# ['Amex', 'Discover', 'Mastercard', 'Visa']

# %%
# Find the distinct credit card combinations, and their frequency counts overall
cc_combinations_df = cc_df.groupby(['Card Brand', 'Card Type'], as_index = False).size()
cc_combinations_df
# Out:
#    Card Brand        Card Type  size
# 0        Amex           Credit   402
# 1    Discover           Credit   209
# 2  Mastercard           Credit   635
# 3  Mastercard            Debit  2191
# 4  Mastercard  Debit (Prepaid)   383
# 5        Visa           Credit   811
# 6        Visa            Debit  1320
# 7        Visa  Debit (Prepaid)   195

# %%
# Find the distinct credit card combinations for each user, and their frequency counts
cc_combinations_df = cc_df.groupby(['User', 'Card Brand', 'Card Type'], as_index = False).size()
cc_combinations_df
# Out:
#       User  Card Brand        Card Type  size
# 0        0  Mastercard  Debit (Prepaid)     1
# 1        0        Visa           Credit     1
# 2        0        Visa            Debit     3
# 3        1  Mastercard            Debit     1
# 4        1  Mastercard  Debit (Prepaid)     2
# ...    ...         ...              ...   ...
# 4646  1997  Mastercard            Debit     1
# 4647  1997        Visa           Credit     1
# 4648  1998  Mastercard           Credit     1
# 4649  1999  Mastercard            Debit     1
# 4650  1999        Visa           Credit     1
#
# [4651 rows x 4 columns]

# %%
# Find the max frequency count all of distinct credit card combinations for users
max_cc_combinations = cc_combinations_df.groupby(['Card Brand', 'Card Type'], as_index = False)['size'].max()
max_cc_combinations
# Out:
#    Card Brand        Card Type  size
# 0        Amex           Credit     4
# 1    Discover           Credit     2
# 2  Mastercard           Credit     4
# 3  Mastercard            Debit     6
# 4  Mastercard  Debit (Prepaid)     3
# 5        Visa           Credit     4
# 6        Visa            Debit     5
# 7        Visa  Debit (Prepaid)     2

# %%
match_list = []

for index, row in max_cc_combinations.iterrows():
    match_list.append(row['Card Brand'] + " " + row['Card Type'])

match_list

cc_dict = {'Amex Credit': ['AMEX 1', 'AMEX 2', 'AMEX 3', 'AMEX 4'],
           'Discover Credit': ['DISC 1', 'DISC 2'],
           'Mastercard Credit': ['MCC 1', 'MCC 2', 'MCC 3', 'MCC 4'],
           'Mastercard Debit': ['MCD 1', 'MCD 2', 'MCD 3', 'MCD 4', 'MCD 5', 'MCD 6'],
           'Mastercard Debit (Prepaid)': ['MCP 1', 'MCP 2', 'MCP 3'],
           'Visa Credit': ['VC 1', 'VC 2', 'VC 3', 'VC 4'],
           'Visa Debit': ['VD 1', 'VD 2', 'VC 3', 'VC 4', 'VC 5'],
           'Visa Debit (Prepaid)': ['VDP 1', 'VDP 2']
           }

# %%
new_df = pd.DataFrame()

for user in cc_df['User'].unique():
    df = cc_df.loc[cc_df['User'] == user]
    
    # print(df)

    for index, row in df.iterrows():
        cc_combination = row['Card Brand'] + " " + row['Card Type']
        print(f"User {user} has a {cc_combination}")
        if cc_combination in match_list:
            cc_dict[cc_combination][0]
            print(f"  Assigning to... {cc_dict[cc_combination][0]}")
    # card_count = df['Card Brand'].value_counts()
    # print(f"User {user} has \n{card_count}")
    # print()
# Out:
# User 0 has a Visa Debit
#   Assigning to...
# User 0 has a Visa Debit
#   Assigning to...
# User 0 has a Visa Debit
#   Assigning to...
# User 0 has a Visa Credit
#   Assigning to...
# User 0 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1 has a Visa Credit
#   Assigning to...
# User 1 has a Visa Debit
#   Assigning to...
# User 1 has a Mastercard Debit
#   Assigning to...
# User 1 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 2 has a Mastercard Debit
#   Assigning to...
# User 2 has a Mastercard Debit
#   Assigning to...
# User 2 has a Mastercard Debit
#   Assigning to...
# User 2 has a Visa Debit
#   Assigning to...
# User 2 has a Mastercard Debit
#   Assigning to...
# User 3 has a Visa Credit
#   Assigning to...
# User 3 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 3 has a Visa Debit
#   Assigning to...
# User 3 has a Visa Debit
#   Assigning to...
# User 4 has a Mastercard Debit
#   Assigning to...
# User 5 has a Visa Credit
#   Assigning to...
# User 5 has a Visa Debit
#   Assigning to...
# User 5 has a Visa Credit
#   Assigning to...
# User 6 has a Mastercard Debit
#   Assigning to...
# User 6 has a Mastercard Credit
#   Assigning to...
# User 6 has a Mastercard Debit
#   Assigning to...
# User 7 has a Visa Debit
#   Assigning to...
# User 8 has a Mastercard Debit
#   Assigning to...
# User 8 has a Mastercard Debit
#   Assigning to...
# User 8 has a Visa Credit
#   Assigning to...
# User 8 has a Visa Credit
#   Assigning to...
# User 8 has a Mastercard Debit
#   Assigning to...
# User 9 has a Mastercard Debit
#   Assigning to...
# User 10 has a Visa Debit
#   Assigning to...
# User 10 has a Visa Debit
#   Assigning to...
# User 11 has a Visa Debit
#   Assigning to...
# User 12 has a Mastercard Debit
#   Assigning to...
# User 13 has a Visa Debit
#   Assigning to...
# User 13 has a Mastercard Debit
#   Assigning to...
# User 13 has a Visa Credit
#   Assigning to...
# User 14 has a Mastercard Debit
#   Assigning to...
# User 15 has a Visa Debit (Prepaid)
#   Assigning to...
# User 15 has a Discover Credit
#   Assigning to...
# User 15 has a Visa Credit
#   Assigning to...
# User 15 has a Mastercard Debit
#   Assigning to...
# User 15 has a Mastercard Credit
#   Assigning to...
# User 15 has a Visa Debit
#   Assigning to...
# User 16 has a Mastercard Debit
#   Assigning to...
# User 16 has a Mastercard Debit
#   Assigning to...
# User 16 has a Mastercard Debit
#   Assigning to...
# User 16 has a Visa Credit
#   Assigning to...
# User 16 has a Visa Debit
#   Assigning to...
# User 16 has a Mastercard Credit
#   Assigning to...
# User 17 has a Discover Credit
#   Assigning to...
# User 17 has a Mastercard Debit
#   Assigning to...
# User 17 has a Visa Debit
#   Assigning to...
# User 17 has a Mastercard Debit
#   Assigning to...
# User 18 has a Visa Debit
#   Assigning to...
# User 18 has a Visa Debit
#   Assigning to...
# User 18 has a Discover Credit
#   Assigning to...
# User 19 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 19 has a Mastercard Debit
#   Assigning to...
# User 19 has a Mastercard Debit
#   Assigning to...
# User 19 has a Mastercard Debit
#   Assigning to...
# User 19 has a Visa Credit
#   Assigning to...
# User 20 has a Mastercard Debit
#   Assigning to...
# User 20 has a Visa Credit
#   Assigning to...
# User 20 has a Visa Credit
#   Assigning to...
# User 21 has a Visa Debit
#   Assigning to...
# User 21 has a Mastercard Debit
#   Assigning to...
# User 22 has a Visa Debit
#   Assigning to...
# User 22 has a Visa Credit
#   Assigning to...
# User 23 has a Mastercard Debit
#   Assigning to...
# User 23 has a Amex Credit
#   Assigning to...
# User 24 has a Mastercard Credit
#   Assigning to...
# User 25 has a Mastercard Debit
#   Assigning to...
# User 25 has a Amex Credit
#   Assigning to...
# User 25 has a Mastercard Debit
#   Assigning to...
# User 26 has a Mastercard Debit
#   Assigning to...
# User 26 has a Mastercard Credit
#   Assigning to...
# User 27 has a Visa Debit
#   Assigning to...
# User 28 has a Mastercard Debit
#   Assigning to...
# User 28 has a Amex Credit
#   Assigning to...
# User 29 has a Mastercard Debit
#   Assigning to...
# User 29 has a Mastercard Debit
#   Assigning to...
# User 29 has a Mastercard Debit
#   Assigning to...
# User 29 has a Mastercard Debit
#   Assigning to...
# User 30 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 31 has a Mastercard Debit
#   Assigning to...
# User 31 has a Mastercard Credit
#   Assigning to...
# User 31 has a Mastercard Debit
#   Assigning to...
# User 31 has a Mastercard Debit
#   Assigning to...
# User 32 has a Visa Credit
#   Assigning to...
# User 32 has a Visa Credit
#   Assigning to...
# User 33 has a Visa Credit
#   Assigning to...
# User 33 has a Mastercard Debit
#   Assigning to...
# User 34 has a Amex Credit
#   Assigning to...
# User 34 has a Mastercard Debit
#   Assigning to...
# User 34 has a Mastercard Debit
#   Assigning to...
# User 35 has a Mastercard Debit
#   Assigning to...
# User 35 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 36 has a Visa Credit
#   Assigning to...
# User 36 has a Mastercard Debit
#   Assigning to...
# User 36 has a Mastercard Debit
#   Assigning to...
# User 36 has a Mastercard Credit
#   Assigning to...
# User 36 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 37 has a Amex Credit
#   Assigning to...
# User 38 has a Visa Credit
#   Assigning to...
# User 39 has a Mastercard Debit
#   Assigning to...
# User 40 has a Visa Credit
#   Assigning to...
# User 40 has a Mastercard Debit
#   Assigning to...
# User 40 has a Amex Credit
#   Assigning to...
# User 40 has a Mastercard Debit
#   Assigning to...
# User 40 has a Visa Debit
#   Assigning to...
# User 40 has a Mastercard Debit
#   Assigning to...
# User 40 has a Visa Debit
#   Assigning to...
# User 41 has a Visa Debit (Prepaid)
#   Assigning to...
# User 41 has a Discover Credit
#   Assigning to...
# User 41 has a Visa Debit
#   Assigning to...
# User 41 has a Mastercard Credit
#   Assigning to...
# User 41 has a Mastercard Debit
#   Assigning to...
# User 42 has a Visa Debit
#   Assigning to...
# User 42 has a Visa Debit (Prepaid)
#   Assigning to...
# User 42 has a Mastercard Credit
#   Assigning to...
# User 42 has a Mastercard Credit
#   Assigning to...
# User 43 has a Mastercard Debit
#   Assigning to...
# User 44 has a Visa Debit
#   Assigning to...
# User 44 has a Mastercard Credit
#   Assigning to...
# User 44 has a Mastercard Credit
#   Assigning to...
# User 45 has a Mastercard Credit
#   Assigning to...
# User 46 has a Amex Credit
#   Assigning to...
# User 47 has a Mastercard Debit
#   Assigning to...
# User 47 has a Discover Credit
#   Assigning to...
# User 47 has a Mastercard Credit
#   Assigning to...
# User 47 has a Visa Debit (Prepaid)
#   Assigning to...
# User 47 has a Mastercard Debit
#   Assigning to...
# User 48 has a Mastercard Debit
#   Assigning to...
# User 48 has a Mastercard Debit
#   Assigning to...
# User 48 has a Mastercard Credit
#   Assigning to...
# User 49 has a Mastercard Credit
#   Assigning to...
# User 49 has a Mastercard Debit
#   Assigning to...
# User 49 has a Mastercard Debit
#   Assigning to...
# User 50 has a Mastercard Debit
#   Assigning to...
# User 50 has a Mastercard Debit
#   Assigning to...
# User 50 has a Mastercard Debit
#   Assigning to...
# User 50 has a Mastercard Debit
#   Assigning to...
# User 51 has a Mastercard Debit
#   Assigning to...
# User 52 has a Mastercard Credit
#   Assigning to...
# User 52 has a Visa Debit
#   Assigning to...
# User 52 has a Visa Credit
#   Assigning to...
# User 53 has a Mastercard Debit
#   Assigning to...
# User 53 has a Mastercard Debit
#   Assigning to...
# User 54 has a Mastercard Debit
#   Assigning to...
# User 54 has a Mastercard Debit
#   Assigning to...
# User 54 has a Visa Debit
#   Assigning to...
# User 54 has a Visa Debit
#   Assigning to...
# User 54 has a Visa Debit
#   Assigning to...
# User 55 has a Visa Debit
#   Assigning to...
# User 55 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 55 has a Mastercard Debit
#   Assigning to...
# User 55 has a Mastercard Debit
#   Assigning to...
# User 56 has a Mastercard Credit
#   Assigning to...
# User 57 has a Mastercard Debit
#   Assigning to...
# User 57 has a Visa Debit
#   Assigning to...
# User 57 has a Visa Debit (Prepaid)
#   Assigning to...
# User 58 has a Mastercard Debit
#   Assigning to...
# User 59 has a Visa Credit
#   Assigning to...
# User 59 has a Mastercard Credit
#   Assigning to...
# User 60 has a Mastercard Debit
#   Assigning to...
# User 60 has a Discover Credit
#   Assigning to...
# User 61 has a Mastercard Debit
#   Assigning to...
# User 61 has a Visa Debit (Prepaid)
#   Assigning to...
# User 61 has a Discover Credit
#   Assigning to...
# User 61 has a Mastercard Debit
#   Assigning to...
# User 61 has a Mastercard Debit
#   Assigning to...
# User 61 has a Visa Debit
#   Assigning to...
# User 61 has a Visa Credit
#   Assigning to...
# User 61 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 62 has a Mastercard Debit
#   Assigning to...
# User 62 has a Mastercard Debit
#   Assigning to...
# User 62 has a Visa Credit
#   Assigning to...
# User 62 has a Amex Credit
#   Assigning to...
# User 63 has a Amex Credit
#   Assigning to...
# User 63 has a Visa Debit
#   Assigning to...
# User 63 has a Mastercard Credit
#   Assigning to...
# User 64 has a Amex Credit
#   Assigning to...
# User 64 has a Mastercard Credit
#   Assigning to...
# User 65 has a Mastercard Debit
#   Assigning to...
# User 65 has a Mastercard Credit
#   Assigning to...
# User 65 has a Mastercard Debit
#   Assigning to...
# User 66 has a Visa Debit
#   Assigning to...
# User 66 has a Mastercard Credit
#   Assigning to...
# User 67 has a Mastercard Debit
#   Assigning to...
# User 67 has a Visa Debit
#   Assigning to...
# User 67 has a Mastercard Credit
#   Assigning to...
# User 68 has a Mastercard Debit
#   Assigning to...
# User 68 has a Mastercard Debit
#   Assigning to...
# User 69 has a Visa Debit
#   Assigning to...
# User 69 has a Visa Credit
#   Assigning to...
# User 69 has a Visa Credit
#   Assigning to...
# User 70 has a Mastercard Debit
#   Assigning to...
# User 71 has a Visa Credit
#   Assigning to...
# User 71 has a Visa Credit
#   Assigning to...
# User 71 has a Mastercard Credit
#   Assigning to...
# User 71 has a Visa Debit
#   Assigning to...
# User 72 has a Mastercard Credit
#   Assigning to...
# User 72 has a Mastercard Debit
#   Assigning to...
# User 73 has a Mastercard Debit
#   Assigning to...
# User 73 has a Visa Debit
#   Assigning to...
# User 73 has a Mastercard Debit
#   Assigning to...
# User 73 has a Mastercard Credit
#   Assigning to...
# User 73 has a Mastercard Debit
#   Assigning to...
# User 73 has a Visa Credit
#   Assigning to...
# User 73 has a Amex Credit
#   Assigning to...
# User 74 has a Amex Credit
#   Assigning to...
# User 74 has a Mastercard Debit
#   Assigning to...
# User 74 has a Mastercard Debit
#   Assigning to...
# User 74 has a Visa Credit
#   Assigning to...
# User 75 has a Mastercard Debit
#   Assigning to...
# User 75 has a Mastercard Debit
#   Assigning to...
# User 75 has a Mastercard Debit
#   Assigning to...
# User 75 has a Mastercard Credit
#   Assigning to...
# User 75 has a Visa Debit
#   Assigning to...
# User 76 has a Visa Debit
#   Assigning to...
# User 77 has a Visa Credit
#   Assigning to...
# User 77 has a Mastercard Credit
#   Assigning to...
# User 77 has a Mastercard Credit
#   Assigning to...
# User 78 has a Visa Credit
#   Assigning to...
# User 78 has a Mastercard Credit
#   Assigning to...
# User 78 has a Visa Debit
#   Assigning to...
# User 78 has a Visa Credit
#   Assigning to...
# User 79 has a Mastercard Debit
#   Assigning to...
# User 79 has a Mastercard Debit
#   Assigning to...
# User 79 has a Visa Credit
#   Assigning to...
# User 79 has a Mastercard Debit
#   Assigning to...
# User 80 has a Mastercard Credit
#   Assigning to...
# User 80 has a Visa Credit
#   Assigning to...
# User 80 has a Mastercard Credit
#   Assigning to...
# User 81 has a Visa Debit
#   Assigning to...
# User 81 has a Visa Debit
#   Assigning to...
# User 81 has a Visa Credit
#   Assigning to...
# User 82 has a Mastercard Debit
#   Assigning to...
# User 83 has a Mastercard Debit
#   Assigning to...
# User 83 has a Mastercard Debit
#   Assigning to...
# User 83 has a Visa Debit
#   Assigning to...
# User 83 has a Visa Debit
#   Assigning to...
# User 84 has a Visa Debit
#   Assigning to...
# User 84 has a Visa Credit
#   Assigning to...
# User 84 has a Visa Debit (Prepaid)
#   Assigning to...
# User 85 has a Mastercard Debit
#   Assigning to...
# User 85 has a Visa Debit
#   Assigning to...
# User 86 has a Visa Credit
#   Assigning to...
# User 86 has a Mastercard Credit
#   Assigning to...
# User 86 has a Visa Debit
#   Assigning to...
# User 86 has a Visa Credit
#   Assigning to...
# User 87 has a Mastercard Debit
#   Assigning to...
# User 87 has a Visa Debit
#   Assigning to...
# User 88 has a Mastercard Debit
#   Assigning to...
# User 88 has a Visa Credit
#   Assigning to...
# User 89 has a Amex Credit
#   Assigning to...
# User 89 has a Visa Credit
#   Assigning to...
# User 89 has a Mastercard Credit
#   Assigning to...
# User 89 has a Mastercard Debit
#   Assigning to...
# User 89 has a Amex Credit
#   Assigning to...
# User 90 has a Visa Debit
#   Assigning to...
# User 91 has a Visa Debit
#   Assigning to...
# User 91 has a Visa Debit
#   Assigning to...
# User 92 has a Visa Debit (Prepaid)
#   Assigning to...
# User 92 has a Amex Credit
#   Assigning to...
# User 93 has a Mastercard Debit
#   Assigning to...
# User 93 has a Amex Credit
#   Assigning to...
# User 94 has a Amex Credit
#   Assigning to...
# User 95 has a Discover Credit
#   Assigning to...
# User 96 has a Visa Debit
#   Assigning to...
# User 96 has a Amex Credit
#   Assigning to...
# User 97 has a Mastercard Credit
#   Assigning to...
# User 97 has a Visa Credit
#   Assigning to...
# User 98 has a Mastercard Credit
#   Assigning to...
# User 98 has a Mastercard Debit
#   Assigning to...
# User 98 has a Visa Debit
#   Assigning to...
# User 98 has a Mastercard Credit
#   Assigning to...
# User 98 has a Mastercard Debit
#   Assigning to...
# User 98 has a Visa Debit
#   Assigning to...
# User 99 has a Visa Debit
#   Assigning to...
# User 99 has a Mastercard Debit
#   Assigning to...
# User 100 has a Mastercard Debit
#   Assigning to...
# User 100 has a Discover Credit
#   Assigning to...
# User 100 has a Mastercard Credit
#   Assigning to...
# User 100 has a Mastercard Debit
#   Assigning to...
# User 100 has a Mastercard Debit
#   Assigning to...
# User 100 has a Mastercard Debit
#   Assigning to...
# User 100 has a Mastercard Debit
#   Assigning to...
# User 101 has a Visa Debit
#   Assigning to...
# User 101 has a Amex Credit
#   Assigning to...
# User 101 has a Visa Debit
#   Assigning to...
# User 102 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 102 has a Mastercard Debit
#   Assigning to...
# User 102 has a Mastercard Debit
#   Assigning to...
# User 102 has a Mastercard Debit
#   Assigning to...
# User 102 has a Visa Credit
#   Assigning to...
# User 103 has a Mastercard Debit
#   Assigning to...
# User 103 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 103 has a Mastercard Debit
#   Assigning to...
# User 103 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 104 has a Mastercard Debit
#   Assigning to...
# User 104 has a Mastercard Debit
#   Assigning to...
# User 104 has a Visa Debit (Prepaid)
#   Assigning to...
# User 104 has a Visa Debit
#   Assigning to...
# User 105 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 106 has a Mastercard Debit
#   Assigning to...
# User 106 has a Mastercard Debit
#   Assigning to...
# User 106 has a Visa Debit
#   Assigning to...
# User 107 has a Mastercard Debit
#   Assigning to...
# User 107 has a Amex Credit
#   Assigning to...
# User 108 has a Visa Debit
#   Assigning to...
# User 108 has a Mastercard Debit
#   Assigning to...
# User 108 has a Mastercard Debit
#   Assigning to...
# User 109 has a Mastercard Credit
#   Assigning to...
# User 109 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 109 has a Mastercard Debit
#   Assigning to...
# User 110 has a Mastercard Debit
#   Assigning to...
# User 110 has a Mastercard Debit
#   Assigning to...
# User 111 has a Visa Debit
#   Assigning to...
# User 111 has a Amex Credit
#   Assigning to...
# User 111 has a Amex Credit
#   Assigning to...
# User 111 has a Mastercard Credit
#   Assigning to...
# User 111 has a Amex Credit
#   Assigning to...
# User 112 has a Mastercard Credit
#   Assigning to...
# User 112 has a Visa Credit
#   Assigning to...
# User 112 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 113 has a Mastercard Debit
#   Assigning to...
# User 114 has a Mastercard Credit
#   Assigning to...
# User 114 has a Mastercard Credit
#   Assigning to...
# User 114 has a Mastercard Debit
#   Assigning to...
# User 115 has a Mastercard Debit
#   Assigning to...
# User 116 has a Visa Debit
#   Assigning to...
# User 116 has a Visa Debit
#   Assigning to...
# User 116 has a Visa Debit
#   Assigning to...
# User 116 has a Visa Debit
#   Assigning to...
# User 116 has a Mastercard Debit
#   Assigning to...
# User 116 has a Mastercard Debit
#   Assigning to...
# User 116 has a Visa Debit
#   Assigning to...
# User 116 has a Mastercard Debit
#   Assigning to...
# User 116 has a Amex Credit
#   Assigning to...
# User 117 has a Mastercard Debit
#   Assigning to...
# User 117 has a Visa Debit (Prepaid)
#   Assigning to...
# User 117 has a Mastercard Credit
#   Assigning to...
# User 117 has a Mastercard Debit
#   Assigning to...
# User 118 has a Visa Debit
#   Assigning to...
# User 118 has a Mastercard Debit
#   Assigning to...
# User 118 has a Discover Credit
#   Assigning to...
# User 119 has a Visa Debit
#   Assigning to...
# User 119 has a Mastercard Debit
#   Assigning to...
# User 119 has a Mastercard Debit
#   Assigning to...
# User 120 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 120 has a Mastercard Credit
#   Assigning to...
# User 121 has a Mastercard Debit
#   Assigning to...
# User 121 has a Mastercard Debit
#   Assigning to...
# User 122 has a Mastercard Debit
#   Assigning to...
# User 122 has a Mastercard Debit
#   Assigning to...
# User 122 has a Mastercard Debit
#   Assigning to...
# User 122 has a Visa Credit
#   Assigning to...
# User 123 has a Mastercard Debit
#   Assigning to...
# User 123 has a Visa Debit (Prepaid)
#   Assigning to...
# User 123 has a Visa Credit
#   Assigning to...
# User 124 has a Mastercard Debit
#   Assigning to...
# User 124 has a Mastercard Credit
#   Assigning to...
# User 124 has a Mastercard Debit
#   Assigning to...
# User 125 has a Mastercard Debit
#   Assigning to...
# User 125 has a Mastercard Debit
#   Assigning to...
# User 125 has a Mastercard Debit
#   Assigning to...
# User 126 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 126 has a Mastercard Debit
#   Assigning to...
# User 126 has a Mastercard Debit
#   Assigning to...
# User 127 has a Mastercard Debit
#   Assigning to...
# User 127 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 128 has a Visa Debit
#   Assigning to...
# User 128 has a Visa Debit
#   Assigning to...
# User 128 has a Visa Debit
#   Assigning to...
# User 128 has a Mastercard Credit
#   Assigning to...
# User 129 has a Mastercard Debit
#   Assigning to...
# User 130 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 130 has a Mastercard Debit
#   Assigning to...
# User 130 has a Visa Credit
#   Assigning to...
# User 131 has a Mastercard Debit
#   Assigning to...
# User 131 has a Visa Debit (Prepaid)
#   Assigning to...
# User 132 has a Mastercard Debit
#   Assigning to...
# User 133 has a Mastercard Debit
#   Assigning to...
# User 133 has a Visa Credit
#   Assigning to...
# User 133 has a Mastercard Debit
#   Assigning to...
# User 133 has a Visa Debit (Prepaid)
#   Assigning to...
# User 134 has a Mastercard Credit
#   Assigning to...
# User 134 has a Visa Credit
#   Assigning to...
# User 134 has a Visa Debit
#   Assigning to...
# User 134 has a Visa Debit
#   Assigning to...
# User 134 has a Visa Debit (Prepaid)
#   Assigning to...
# User 134 has a Mastercard Debit
#   Assigning to...
# User 135 has a Mastercard Debit
#   Assigning to...
# User 136 has a Mastercard Debit
#   Assigning to...
# User 136 has a Visa Credit
#   Assigning to...
# User 136 has a Mastercard Debit
#   Assigning to...
# User 137 has a Visa Credit
#   Assigning to...
# User 137 has a Visa Debit (Prepaid)
#   Assigning to...
# User 137 has a Visa Debit
#   Assigning to...
# User 137 has a Mastercard Credit
#   Assigning to...
# User 137 has a Mastercard Debit
#   Assigning to...
# User 137 has a Amex Credit
#   Assigning to...
# User 138 has a Visa Credit
#   Assigning to...
# User 138 has a Mastercard Debit
#   Assigning to...
# User 138 has a Mastercard Credit
#   Assigning to...
# User 138 has a Mastercard Debit
#   Assigning to...
# User 138 has a Amex Credit
#   Assigning to...
# User 138 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 139 has a Amex Credit
#   Assigning to...
# User 139 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 139 has a Visa Credit
#   Assigning to...
# User 139 has a Visa Credit
#   Assigning to...
# User 140 has a Visa Credit
#   Assigning to...
# User 140 has a Visa Debit
#   Assigning to...
# User 140 has a Mastercard Debit
#   Assigning to...
# User 140 has a Discover Credit
#   Assigning to...
# User 140 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 141 has a Visa Debit
#   Assigning to...
# User 141 has a Visa Credit
#   Assigning to...
# User 142 has a Visa Debit
#   Assigning to...
# User 142 has a Visa Debit
#   Assigning to...
# User 142 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 142 has a Visa Debit
#   Assigning to...
# User 143 has a Amex Credit
#   Assigning to...
# User 143 has a Visa Credit
#   Assigning to...
# User 143 has a Visa Credit
#   Assigning to...
# User 143 has a Mastercard Debit
#   Assigning to...
# User 144 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 144 has a Visa Credit
#   Assigning to...
# User 144 has a Visa Debit
#   Assigning to...
# User 144 has a Visa Credit
#   Assigning to...
# User 145 has a Visa Credit
#   Assigning to...
# User 145 has a Mastercard Debit
#   Assigning to...
# User 146 has a Mastercard Credit
#   Assigning to...
# User 147 has a Mastercard Debit
#   Assigning to...
# User 148 has a Mastercard Debit
#   Assigning to...
# User 148 has a Mastercard Debit
#   Assigning to...
# User 148 has a Visa Credit
#   Assigning to...
# User 148 has a Mastercard Debit
#   Assigning to...
# User 148 has a Visa Credit
#   Assigning to...
# User 149 has a Visa Debit
#   Assigning to...
# User 149 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 149 has a Mastercard Debit
#   Assigning to...
# User 149 has a Mastercard Credit
#   Assigning to...
# User 149 has a Mastercard Debit
#   Assigning to...
# User 150 has a Visa Credit
#   Assigning to...
# User 150 has a Visa Credit
#   Assigning to...
# User 151 has a Mastercard Credit
#   Assigning to...
# User 151 has a Visa Debit
#   Assigning to...
# User 151 has a Mastercard Debit
#   Assigning to...
# User 151 has a Mastercard Debit
#   Assigning to...
# User 151 has a Visa Credit
#   Assigning to...
# User 151 has a Mastercard Debit
#   Assigning to...
# User 152 has a Mastercard Credit
#   Assigning to...
# User 153 has a Visa Debit
#   Assigning to...
# User 154 has a Mastercard Debit
#   Assigning to...
# User 154 has a Mastercard Debit
#   Assigning to...
# User 155 has a Visa Credit
#   Assigning to...
# User 155 has a Mastercard Credit
#   Assigning to...
# User 155 has a Visa Debit
#   Assigning to...
# User 155 has a Visa Credit
#   Assigning to...
# User 155 has a Mastercard Debit
#   Assigning to...
# User 156 has a Visa Debit
#   Assigning to...
# User 156 has a Visa Credit
#   Assigning to...
# User 156 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 156 has a Mastercard Debit
#   Assigning to...
# User 156 has a Visa Credit
#   Assigning to...
# User 157 has a Visa Debit
#   Assigning to...
# User 157 has a Visa Debit
#   Assigning to...
# User 157 has a Mastercard Debit
#   Assigning to...
# User 158 has a Visa Debit
#   Assigning to...
# User 159 has a Mastercard Debit
#   Assigning to...
# User 159 has a Visa Credit
#   Assigning to...
# User 159 has a Mastercard Credit
#   Assigning to...
# User 160 has a Mastercard Debit
#   Assigning to...
# User 160 has a Visa Debit
#   Assigning to...
# User 160 has a Visa Debit
#   Assigning to...
# User 160 has a Mastercard Debit
#   Assigning to...
# User 160 has a Visa Debit
#   Assigning to...
# User 161 has a Mastercard Debit
#   Assigning to...
# User 161 has a Visa Debit
#   Assigning to...
# User 161 has a Visa Debit
#   Assigning to...
# User 161 has a Visa Credit
#   Assigning to...
# User 162 has a Visa Debit
#   Assigning to...
# User 162 has a Visa Credit
#   Assigning to...
# User 162 has a Mastercard Debit
#   Assigning to...
# User 163 has a Mastercard Debit
#   Assigning to...
# User 163 has a Mastercard Debit
#   Assigning to...
# User 163 has a Mastercard Debit
#   Assigning to...
# User 163 has a Visa Credit
#   Assigning to...
# User 163 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 164 has a Mastercard Credit
#   Assigning to...
# User 165 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 165 has a Mastercard Credit
#   Assigning to...
# User 165 has a Amex Credit
#   Assigning to...
# User 165 has a Visa Debit
#   Assigning to...
# User 166 has a Discover Credit
#   Assigning to...
# User 166 has a Visa Debit
#   Assigning to...
# User 167 has a Visa Debit
#   Assigning to...
# User 168 has a Mastercard Debit
#   Assigning to...
# User 168 has a Mastercard Debit
#   Assigning to...
# User 169 has a Mastercard Credit
#   Assigning to...
# User 169 has a Visa Credit
#   Assigning to...
# User 169 has a Visa Debit
#   Assigning to...
# User 170 has a Visa Credit
#   Assigning to...
# User 170 has a Visa Credit
#   Assigning to...
# User 170 has a Mastercard Debit
#   Assigning to...
# User 170 has a Visa Credit
#   Assigning to...
# User 171 has a Mastercard Credit
#   Assigning to...
# User 171 has a Mastercard Debit
#   Assigning to...
# User 171 has a Mastercard Debit
#   Assigning to...
# User 172 has a Amex Credit
#   Assigning to...
# User 172 has a Visa Debit
#   Assigning to...
# User 172 has a Visa Debit
#   Assigning to...
# User 173 has a Visa Credit
#   Assigning to...
# User 173 has a Visa Debit
#   Assigning to...
# User 174 has a Mastercard Debit
#   Assigning to...
# User 174 has a Visa Debit
#   Assigning to...
# User 174 has a Visa Debit
#   Assigning to...
# User 175 has a Visa Debit
#   Assigning to...
# User 175 has a Mastercard Credit
#   Assigning to...
# User 175 has a Visa Debit
#   Assigning to...
# User 175 has a Mastercard Debit
#   Assigning to...
# User 175 has a Mastercard Debit
#   Assigning to...
# User 176 has a Visa Debit (Prepaid)
#   Assigning to...
# User 176 has a Mastercard Debit
#   Assigning to...
# User 176 has a Amex Credit
#   Assigning to...
# User 176 has a Mastercard Credit
#   Assigning to...
# User 177 has a Mastercard Debit
#   Assigning to...
# User 177 has a Mastercard Debit
#   Assigning to...
# User 177 has a Mastercard Debit
#   Assigning to...
# User 178 has a Visa Credit
#   Assigning to...
# User 178 has a Visa Credit
#   Assigning to...
# User 178 has a Mastercard Debit
#   Assigning to...
# User 178 has a Discover Credit
#   Assigning to...
# User 179 has a Mastercard Debit
#   Assigning to...
# User 179 has a Amex Credit
#   Assigning to...
# User 179 has a Visa Debit
#   Assigning to...
# User 179 has a Mastercard Debit
#   Assigning to...
# User 179 has a Visa Credit
#   Assigning to...
# User 180 has a Visa Debit
#   Assigning to...
# User 180 has a Visa Credit
#   Assigning to...
# User 180 has a Visa Debit (Prepaid)
#   Assigning to...
# User 180 has a Visa Debit
#   Assigning to...
# User 181 has a Visa Debit
#   Assigning to...
# User 181 has a Mastercard Debit
#   Assigning to...
# User 181 has a Mastercard Debit
#   Assigning to...
# User 182 has a Visa Credit
#   Assigning to...
# User 183 has a Mastercard Debit
#   Assigning to...
# User 184 has a Visa Debit
#   Assigning to...
# User 184 has a Visa Credit
#   Assigning to...
# User 184 has a Visa Credit
#   Assigning to...
# User 184 has a Visa Credit
#   Assigning to...
# User 184 has a Mastercard Debit
#   Assigning to...
# User 184 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 185 has a Amex Credit
#   Assigning to...
# User 185 has a Visa Debit
#   Assigning to...
# User 185 has a Mastercard Debit
#   Assigning to...
# User 185 has a Visa Debit
#   Assigning to...
# User 186 has a Visa Debit
#   Assigning to...
# User 186 has a Visa Debit (Prepaid)
#   Assigning to...
# User 187 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 187 has a Visa Credit
#   Assigning to...
# User 188 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 188 has a Amex Credit
#   Assigning to...
# User 188 has a Mastercard Debit
#   Assigning to...
# User 188 has a Mastercard Credit
#   Assigning to...
# User 188 has a Mastercard Credit
#   Assigning to...
# User 189 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 190 has a Mastercard Debit
#   Assigning to...
# User 190 has a Mastercard Credit
#   Assigning to...
# User 190 has a Visa Credit
#   Assigning to...
# User 190 has a Amex Credit
#   Assigning to...
# User 190 has a Mastercard Credit
#   Assigning to...
# User 191 has a Mastercard Credit
#   Assigning to...
# User 192 has a Visa Credit
#   Assigning to...
# User 192 has a Visa Debit
#   Assigning to...
# User 192 has a Mastercard Debit
#   Assigning to...
# User 193 has a Visa Debit
#   Assigning to...
# User 193 has a Visa Debit (Prepaid)
#   Assigning to...
# User 193 has a Visa Debit
#   Assigning to...
# User 193 has a Visa Debit
#   Assigning to...
# User 194 has a Amex Credit
#   Assigning to...
# User 194 has a Visa Credit
#   Assigning to...
# User 194 has a Mastercard Debit
#   Assigning to...
# User 195 has a Visa Credit
#   Assigning to...
# User 196 has a Mastercard Debit
#   Assigning to...
# User 197 has a Mastercard Debit
#   Assigning to...
# User 197 has a Mastercard Debit
#   Assigning to...
# User 198 has a Mastercard Debit
#   Assigning to...
# User 199 has a Visa Debit
#   Assigning to...
# User 199 has a Visa Debit (Prepaid)
#   Assigning to...
# User 199 has a Mastercard Debit
#   Assigning to...
# User 200 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 201 has a Mastercard Debit
#   Assigning to...
# User 201 has a Visa Debit
#   Assigning to...
# User 201 has a Visa Credit
#   Assigning to...
# User 201 has a Visa Debit (Prepaid)
#   Assigning to...
# User 201 has a Visa Credit
#   Assigning to...
# User 201 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 202 has a Mastercard Debit
#   Assigning to...
# User 203 has a Mastercard Debit
#   Assigning to...
# User 204 has a Mastercard Debit
#   Assigning to...
# User 204 has a Visa Credit
#   Assigning to...
# User 205 has a Mastercard Credit
#   Assigning to...
# User 205 has a Visa Debit (Prepaid)
#   Assigning to...
# User 205 has a Visa Credit
#   Assigning to...
# User 205 has a Visa Debit (Prepaid)
#   Assigning to...
# User 206 has a Mastercard Debit
#   Assigning to...
# User 206 has a Visa Debit
#   Assigning to...
# User 207 has a Mastercard Credit
#   Assigning to...
# User 207 has a Visa Debit
#   Assigning to...
# User 207 has a Mastercard Credit
#   Assigning to...
# User 208 has a Visa Debit
#   Assigning to...
# User 208 has a Visa Debit
#   Assigning to...
# User 208 has a Mastercard Debit
#   Assigning to...
# User 208 has a Amex Credit
#   Assigning to...
# User 209 has a Mastercard Debit
#   Assigning to...
# User 209 has a Mastercard Credit
#   Assigning to...
# User 210 has a Discover Credit
#   Assigning to...
# User 210 has a Mastercard Debit
#   Assigning to...
# User 210 has a Mastercard Debit
#   Assigning to...
# User 211 has a Mastercard Debit
#   Assigning to...
# User 211 has a Mastercard Credit
#   Assigning to...
# User 211 has a Visa Debit
#   Assigning to...
# User 212 has a Mastercard Debit
#   Assigning to...
# User 212 has a Mastercard Debit
#   Assigning to...
# User 212 has a Visa Credit
#   Assigning to...
# User 212 has a Mastercard Debit
#   Assigning to...
# User 212 has a Visa Debit
#   Assigning to...
# User 213 has a Visa Debit
#   Assigning to...
# User 214 has a Amex Credit
#   Assigning to...
# User 215 has a Mastercard Debit
#   Assigning to...
# User 215 has a Discover Credit
#   Assigning to...
# User 216 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 217 has a Amex Credit
#   Assigning to...
# User 217 has a Discover Credit
#   Assigning to...
# User 217 has a Visa Credit
#   Assigning to...
# User 217 has a Mastercard Debit
#   Assigning to...
# User 218 has a Mastercard Credit
#   Assigning to...
# User 219 has a Mastercard Credit
#   Assigning to...
# User 219 has a Mastercard Debit
#   Assigning to...
# User 219 has a Mastercard Debit
#   Assigning to...
# User 220 has a Visa Credit
#   Assigning to...
# User 220 has a Mastercard Credit
#   Assigning to...
# User 220 has a Visa Debit
#   Assigning to...
# User 220 has a Mastercard Debit
#   Assigning to...
# User 221 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 222 has a Visa Credit
#   Assigning to...
# User 222 has a Mastercard Debit
#   Assigning to...
# User 222 has a Mastercard Debit
#   Assigning to...
# User 222 has a Mastercard Debit
#   Assigning to...
# User 223 has a Mastercard Debit
#   Assigning to...
# User 223 has a Visa Debit
#   Assigning to...
# User 223 has a Visa Credit
#   Assigning to...
# User 223 has a Mastercard Credit
#   Assigning to...
# User 223 has a Mastercard Debit
#   Assigning to...
# User 223 has a Visa Debit (Prepaid)
#   Assigning to...
# User 224 has a Mastercard Credit
#   Assigning to...
# User 225 has a Visa Credit
#   Assigning to...
# User 226 has a Mastercard Debit
#   Assigning to...
# User 226 has a Mastercard Debit
#   Assigning to...
# User 226 has a Mastercard Credit
#   Assigning to...
# User 227 has a Mastercard Credit
#   Assigning to...
# User 228 has a Mastercard Credit
#   Assigning to...
# User 228 has a Visa Credit
#   Assigning to...
# User 228 has a Visa Credit
#   Assigning to...
# User 228 has a Mastercard Debit
#   Assigning to...
# User 229 has a Visa Debit
#   Assigning to...
# User 229 has a Visa Debit
#   Assigning to...
# User 230 has a Mastercard Debit
#   Assigning to...
# User 230 has a Visa Credit
#   Assigning to...
# User 230 has a Mastercard Credit
#   Assigning to...
# User 231 has a Visa Debit (Prepaid)
#   Assigning to...
# User 232 has a Visa Debit
#   Assigning to...
# User 232 has a Mastercard Credit
#   Assigning to...
# User 233 has a Mastercard Debit
#   Assigning to...
# User 233 has a Visa Debit (Prepaid)
#   Assigning to...
# User 233 has a Visa Credit
#   Assigning to...
# User 234 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 234 has a Mastercard Debit
#   Assigning to...
# User 234 has a Mastercard Debit
#   Assigning to...
# User 235 has a Mastercard Debit
#   Assigning to...
# User 235 has a Mastercard Debit
#   Assigning to...
# User 235 has a Visa Debit (Prepaid)
#   Assigning to...
# User 236 has a Visa Credit
#   Assigning to...
# User 236 has a Mastercard Debit
#   Assigning to...
# User 236 has a Mastercard Debit
#   Assigning to...
# User 237 has a Visa Credit
#   Assigning to...
# User 237 has a Mastercard Debit
#   Assigning to...
# User 237 has a Visa Debit
#   Assigning to...
# User 237 has a Visa Credit
#   Assigning to...
# User 238 has a Mastercard Credit
#   Assigning to...
# User 238 has a Visa Debit
#   Assigning to...
# User 238 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 238 has a Visa Debit
#   Assigning to...
# User 238 has a Visa Credit
#   Assigning to...
# User 239 has a Visa Debit
#   Assigning to...
# User 239 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 239 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 239 has a Visa Credit
#   Assigning to...
# User 239 has a Mastercard Debit
#   Assigning to...
# User 239 has a Mastercard Debit
#   Assigning to...
# User 239 has a Mastercard Debit
#   Assigning to...
# User 239 has a Mastercard Debit
#   Assigning to...
# User 240 has a Mastercard Debit
#   Assigning to...
# User 240 has a Visa Debit
#   Assigning to...
# User 240 has a Visa Debit
#   Assigning to...
# User 240 has a Visa Credit
#   Assigning to...
# User 241 has a Discover Credit
#   Assigning to...
# User 241 has a Visa Debit
#   Assigning to...
# User 241 has a Visa Credit
#   Assigning to...
# User 241 has a Mastercard Credit
#   Assigning to...
# User 242 has a Mastercard Credit
#   Assigning to...
# User 242 has a Visa Debit (Prepaid)
#   Assigning to...
# User 242 has a Mastercard Debit
#   Assigning to...
# User 243 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 243 has a Discover Credit
#   Assigning to...
# User 243 has a Mastercard Debit
#   Assigning to...
# User 244 has a Visa Debit
#   Assigning to...
# User 245 has a Mastercard Debit
#   Assigning to...
# User 246 has a Visa Debit
#   Assigning to...
# User 246 has a Mastercard Debit
#   Assigning to...
# User 247 has a Visa Credit
#   Assigning to...
# User 247 has a Mastercard Debit
#   Assigning to...
# User 248 has a Amex Credit
#   Assigning to...
# User 249 has a Visa Debit
#   Assigning to...
# User 250 has a Mastercard Debit
#   Assigning to...
# User 251 has a Visa Credit
#   Assigning to...
# User 252 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 252 has a Visa Debit
#   Assigning to...
# User 252 has a Visa Debit
#   Assigning to...
# User 253 has a Visa Credit
#   Assigning to...
# User 253 has a Mastercard Debit
#   Assigning to...
# User 254 has a Visa Credit
#   Assigning to...
# User 254 has a Mastercard Debit
#   Assigning to...
# User 254 has a Visa Credit
#   Assigning to...
# User 254 has a Mastercard Debit
#   Assigning to...
# User 254 has a Mastercard Debit
#   Assigning to...
# User 255 has a Mastercard Credit
#   Assigning to...
# User 255 has a Mastercard Debit
#   Assigning to...
# User 255 has a Mastercard Credit
#   Assigning to...
# User 255 has a Mastercard Credit
#   Assigning to...
# User 255 has a Discover Credit
#   Assigning to...
# User 255 has a Amex Credit
#   Assigning to...
# User 256 has a Mastercard Debit
#   Assigning to...
# User 256 has a Visa Debit
#   Assigning to...
# User 256 has a Amex Credit
#   Assigning to...
# User 256 has a Visa Debit
#   Assigning to...
# User 257 has a Mastercard Debit
#   Assigning to...
# User 257 has a Mastercard Debit
#   Assigning to...
# User 257 has a Discover Credit
#   Assigning to...
# User 257 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 257 has a Mastercard Credit
#   Assigning to...
# User 257 has a Mastercard Credit
#   Assigning to...
# User 257 has a Mastercard Debit
#   Assigning to...
# User 258 has a Discover Credit
#   Assigning to...
# User 259 has a Visa Credit
#   Assigning to...
# User 259 has a Mastercard Credit
#   Assigning to...
# User 259 has a Visa Debit
#   Assigning to...
# User 259 has a Visa Debit (Prepaid)
#   Assigning to...
# User 260 has a Visa Debit
#   Assigning to...
# User 260 has a Mastercard Debit
#   Assigning to...
# User 260 has a Visa Debit
#   Assigning to...
# User 260 has a Visa Credit
#   Assigning to...
# User 261 has a Mastercard Debit
#   Assigning to...
# User 261 has a Visa Debit
#   Assigning to...
# User 261 has a Visa Debit
#   Assigning to...
# User 261 has a Mastercard Debit
#   Assigning to...
# User 262 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 262 has a Visa Debit
#   Assigning to...
# User 262 has a Mastercard Debit
#   Assigning to...
# User 262 has a Mastercard Debit
#   Assigning to...
# User 262 has a Visa Debit
#   Assigning to...
# User 263 has a Mastercard Credit
#   Assigning to...
# User 263 has a Visa Debit
#   Assigning to...
# User 263 has a Visa Credit
#   Assigning to...
# User 264 has a Mastercard Debit
#   Assigning to...
# User 264 has a Discover Credit
#   Assigning to...
# User 265 has a Visa Credit
#   Assigning to...
# User 265 has a Visa Debit
#   Assigning to...
# User 265 has a Visa Debit
#   Assigning to...
# User 266 has a Visa Debit
#   Assigning to...
# User 266 has a Visa Debit (Prepaid)
#   Assigning to...
# User 266 has a Mastercard Debit
#   Assigning to...
# User 266 has a Mastercard Debit
#   Assigning to...
# User 267 has a Mastercard Debit
#   Assigning to...
# User 267 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 268 has a Mastercard Debit
#   Assigning to...
# User 268 has a Mastercard Debit
#   Assigning to...
# User 268 has a Visa Credit
#   Assigning to...
# User 268 has a Visa Debit
#   Assigning to...
# User 269 has a Mastercard Debit
#   Assigning to...
# User 269 has a Visa Credit
#   Assigning to...
# User 269 has a Mastercard Debit
#   Assigning to...
# User 269 has a Visa Debit
#   Assigning to...
# User 270 has a Visa Credit
#   Assigning to...
# User 270 has a Visa Credit
#   Assigning to...
# User 270 has a Mastercard Debit
#   Assigning to...
# User 271 has a Mastercard Debit
#   Assigning to...
# User 271 has a Mastercard Debit
#   Assigning to...
# User 271 has a Mastercard Debit
#   Assigning to...
# User 271 has a Mastercard Debit
#   Assigning to...
# User 271 has a Mastercard Credit
#   Assigning to...
# User 271 has a Mastercard Debit
#   Assigning to...
# User 271 has a Mastercard Debit
#   Assigning to...
# User 272 has a Visa Debit (Prepaid)
#   Assigning to...
# User 272 has a Mastercard Credit
#   Assigning to...
# User 272 has a Mastercard Debit
#   Assigning to...
# User 272 has a Amex Credit
#   Assigning to...
# User 272 has a Mastercard Credit
#   Assigning to...
# User 272 has a Amex Credit
#   Assigning to...
# User 273 has a Mastercard Debit
#   Assigning to...
# User 273 has a Mastercard Credit
#   Assigning to...
# User 273 has a Mastercard Debit
#   Assigning to...
# User 274 has a Mastercard Debit
#   Assigning to...
# User 274 has a Mastercard Credit
#   Assigning to...
# User 274 has a Visa Credit
#   Assigning to...
# User 275 has a Visa Debit
#   Assigning to...
# User 275 has a Mastercard Debit
#   Assigning to...
# User 275 has a Discover Credit
#   Assigning to...
# User 275 has a Mastercard Debit
#   Assigning to...
# User 275 has a Amex Credit
#   Assigning to...
# User 275 has a Visa Debit
#   Assigning to...
# User 276 has a Mastercard Credit
#   Assigning to...
# User 277 has a Mastercard Credit
#   Assigning to...
# User 277 has a Mastercard Debit
#   Assigning to...
# User 277 has a Mastercard Debit
#   Assigning to...
# User 277 has a Mastercard Credit
#   Assigning to...
# User 278 has a Mastercard Credit
#   Assigning to...
# User 278 has a Mastercard Debit
#   Assigning to...
# User 278 has a Visa Debit (Prepaid)
#   Assigning to...
# User 278 has a Visa Debit
#   Assigning to...
# User 279 has a Mastercard Credit
#   Assigning to...
# User 279 has a Amex Credit
#   Assigning to...
# User 280 has a Visa Credit
#   Assigning to...
# User 280 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 280 has a Mastercard Debit
#   Assigning to...
# User 280 has a Visa Debit
#   Assigning to...
# User 281 has a Mastercard Debit
#   Assigning to...
# User 281 has a Visa Credit
#   Assigning to...
# User 281 has a Mastercard Debit
#   Assigning to...
# User 282 has a Visa Debit
#   Assigning to...
# User 283 has a Visa Debit
#   Assigning to...
# User 283 has a Mastercard Debit
#   Assigning to...
# User 283 has a Mastercard Debit
#   Assigning to...
# User 284 has a Visa Debit
#   Assigning to...
# User 285 has a Mastercard Debit
#   Assigning to...
# User 285 has a Visa Credit
#   Assigning to...
# User 285 has a Mastercard Credit
#   Assigning to...
# User 285 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 286 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 286 has a Visa Debit (Prepaid)
#   Assigning to...
# User 287 has a Visa Debit
#   Assigning to...
# User 287 has a Visa Credit
#   Assigning to...
# User 287 has a Visa Credit
#   Assigning to...
# User 287 has a Mastercard Credit
#   Assigning to...
# User 288 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 288 has a Mastercard Credit
#   Assigning to...
# User 288 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 288 has a Discover Credit
#   Assigning to...
# User 288 has a Discover Credit
#   Assigning to...
# User 288 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 288 has a Mastercard Debit
#   Assigning to...
# User 288 has a Mastercard Debit
#   Assigning to...
# User 289 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 289 has a Mastercard Debit
#   Assigning to...
# User 289 has a Visa Debit
#   Assigning to...
# User 290 has a Mastercard Debit
#   Assigning to...
# User 291 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 291 has a Visa Debit (Prepaid)
#   Assigning to...
# User 291 has a Mastercard Debit
#   Assigning to...
# User 291 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 291 has a Visa Debit
#   Assigning to...
# User 291 has a Visa Debit
#   Assigning to...
# User 291 has a Mastercard Debit
#   Assigning to...
# User 291 has a Mastercard Debit
#   Assigning to...
# User 292 has a Visa Credit
#   Assigning to...
# User 292 has a Mastercard Debit
#   Assigning to...
# User 292 has a Mastercard Debit
#   Assigning to...
# User 292 has a Visa Debit
#   Assigning to...
# User 293 has a Visa Credit
#   Assigning to...
# User 294 has a Visa Debit
#   Assigning to...
# User 294 has a Mastercard Credit
#   Assigning to...
# User 295 has a Mastercard Debit
#   Assigning to...
# User 295 has a Visa Credit
#   Assigning to...
# User 296 has a Mastercard Credit
#   Assigning to...
# User 296 has a Mastercard Debit
#   Assigning to...
# User 297 has a Mastercard Credit
#   Assigning to...
# User 297 has a Amex Credit
#   Assigning to...
# User 298 has a Mastercard Credit
#   Assigning to...
# User 298 has a Mastercard Credit
#   Assigning to...
# User 298 has a Visa Debit
#   Assigning to...
# User 299 has a Mastercard Debit
#   Assigning to...
# User 299 has a Visa Debit
#   Assigning to...
# User 299 has a Amex Credit
#   Assigning to...
# User 300 has a Mastercard Credit
#   Assigning to...
# User 300 has a Visa Debit (Prepaid)
#   Assigning to...
# User 300 has a Mastercard Debit
#   Assigning to...
# User 300 has a Mastercard Credit
#   Assigning to...
# User 301 has a Visa Debit
#   Assigning to...
# User 301 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 301 has a Visa Debit
#   Assigning to...
# User 302 has a Visa Debit
#   Assigning to...
# User 302 has a Discover Credit
#   Assigning to...
# User 302 has a Mastercard Debit
#   Assigning to...
# User 302 has a Visa Debit
#   Assigning to...
# User 302 has a Visa Debit (Prepaid)
#   Assigning to...
# User 302 has a Mastercard Debit
#   Assigning to...
# User 302 has a Visa Debit
#   Assigning to...
# User 303 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 304 has a Mastercard Debit
#   Assigning to...
# User 304 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 304 has a Mastercard Credit
#   Assigning to...
# User 304 has a Mastercard Debit
#   Assigning to...
# User 305 has a Mastercard Credit
#   Assigning to...
# User 305 has a Visa Credit
#   Assigning to...
# User 306 has a Mastercard Debit
#   Assigning to...
# User 306 has a Discover Credit
#   Assigning to...
# User 307 has a Visa Debit
#   Assigning to...
# User 307 has a Mastercard Credit
#   Assigning to...
# User 307 has a Discover Credit
#   Assigning to...
# User 307 has a Amex Credit
#   Assigning to...
# User 308 has a Mastercard Debit
#   Assigning to...
# User 309 has a Mastercard Debit
#   Assigning to...
# User 309 has a Mastercard Debit
#   Assigning to...
# User 309 has a Visa Credit
#   Assigning to...
# User 309 has a Mastercard Debit
#   Assigning to...
# User 309 has a Mastercard Debit
#   Assigning to...
# User 310 has a Discover Credit
#   Assigning to...
# User 310 has a Discover Credit
#   Assigning to...
# User 310 has a Visa Credit
#   Assigning to...
# User 311 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 311 has a Mastercard Debit
#   Assigning to...
# User 311 has a Mastercard Debit
#   Assigning to...
# User 311 has a Amex Credit
#   Assigning to...
# User 311 has a Visa Credit
#   Assigning to...
# User 311 has a Mastercard Debit
#   Assigning to...
# User 312 has a Mastercard Credit
#   Assigning to...
# User 313 has a Mastercard Debit
#   Assigning to...
# User 314 has a Visa Credit
#   Assigning to...
# User 314 has a Discover Credit
#   Assigning to...
# User 314 has a Mastercard Debit
#   Assigning to...
# User 314 has a Visa Debit
#   Assigning to...
# User 314 has a Visa Credit
#   Assigning to...
# User 315 has a Mastercard Debit
#   Assigning to...
# User 315 has a Amex Credit
#   Assigning to...
# User 316 has a Visa Debit
#   Assigning to...
# User 317 has a Visa Debit
#   Assigning to...
# User 318 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 318 has a Amex Credit
#   Assigning to...
# User 318 has a Mastercard Credit
#   Assigning to...
# User 318 has a Mastercard Debit
#   Assigning to...
# User 319 has a Mastercard Debit
#   Assigning to...
# User 319 has a Mastercard Debit
#   Assigning to...
# User 319 has a Mastercard Debit
#   Assigning to...
# User 319 has a Mastercard Debit
#   Assigning to...
# User 319 has a Visa Credit
#   Assigning to...
# User 319 has a Visa Debit (Prepaid)
#   Assigning to...
# User 320 has a Mastercard Debit
#   Assigning to...
# User 320 has a Mastercard Credit
#   Assigning to...
# User 320 has a Discover Credit
#   Assigning to...
# User 320 has a Mastercard Debit
#   Assigning to...
# User 321 has a Visa Debit
#   Assigning to...
# User 321 has a Mastercard Debit
#   Assigning to...
# User 321 has a Mastercard Debit
#   Assigning to...
# User 321 has a Mastercard Debit
#   Assigning to...
# User 321 has a Mastercard Debit
#   Assigning to...
# User 322 has a Visa Debit
#   Assigning to...
# User 322 has a Visa Credit
#   Assigning to...
# User 322 has a Mastercard Debit
#   Assigning to...
# User 322 has a Visa Debit
#   Assigning to...
# User 323 has a Mastercard Debit
#   Assigning to...
# User 324 has a Mastercard Debit
#   Assigning to...
# User 324 has a Mastercard Debit
#   Assigning to...
# User 325 has a Visa Debit (Prepaid)
#   Assigning to...
# User 326 has a Visa Debit
#   Assigning to...
# User 326 has a Visa Credit
#   Assigning to...
# User 326 has a Mastercard Credit
#   Assigning to...
# User 326 has a Visa Credit
#   Assigning to...
# User 327 has a Mastercard Debit
#   Assigning to...
# User 327 has a Mastercard Credit
#   Assigning to...
# User 328 has a Visa Debit
#   Assigning to...
# User 328 has a Mastercard Debit
#   Assigning to...
# User 328 has a Visa Debit
#   Assigning to...
# User 328 has a Visa Debit
#   Assigning to...
# User 329 has a Visa Credit
#   Assigning to...
# ...
#   Assigning to...
# User 1894 has a Visa Debit
#   Assigning to...
# User 1894 has a Mastercard Debit
#   Assigning to...
# User 1894 has a Mastercard Debit
#   Assigning to...
# User 1894 has a Mastercard Debit
#   Assigning to...
# User 1894 has a Mastercard Credit
#   Assigning to...
# User 1894 has a Amex Credit
#   Assigning to...
# User 1895 has a Mastercard Debit
#   Assigning to...
# User 1895 has a Mastercard Debit
#   Assigning to...
# User 1895 has a Amex Credit
#   Assigning to...
# User 1895 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1895 has a Mastercard Debit
#   Assigning to...
# User 1895 has a Amex Credit
#   Assigning to...
# User 1896 has a Amex Credit
#   Assigning to...
# User 1896 has a Amex Credit
#   Assigning to...
# User 1896 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1897 has a Mastercard Credit
#   Assigning to...
# User 1897 has a Visa Credit
#   Assigning to...
# User 1897 has a Visa Debit
#   Assigning to...
# User 1897 has a Mastercard Debit
#   Assigning to...
# User 1898 has a Visa Debit
#   Assigning to...
# User 1898 has a Visa Debit
#   Assigning to...
# User 1899 has a Visa Credit
#   Assigning to...
# User 1899 has a Mastercard Debit
#   Assigning to...
# User 1900 has a Amex Credit
#   Assigning to...
# User 1900 has a Mastercard Debit
#   Assigning to...
# User 1900 has a Visa Credit
#   Assigning to...
# User 1900 has a Visa Debit
#   Assigning to...
# User 1900 has a Visa Debit
#   Assigning to...
# User 1900 has a Visa Credit
#   Assigning to...
# User 1901 has a Discover Credit
#   Assigning to...
# User 1901 has a Visa Credit
#   Assigning to...
# User 1902 has a Visa Debit
#   Assigning to...
# User 1902 has a Mastercard Debit
#   Assigning to...
# User 1903 has a Mastercard Credit
#   Assigning to...
# User 1903 has a Mastercard Debit
#   Assigning to...
# User 1903 has a Mastercard Debit
#   Assigning to...
# User 1903 has a Visa Debit
#   Assigning to...
# User 1903 has a Mastercard Debit
#   Assigning to...
# User 1904 has a Discover Credit
#   Assigning to...
# User 1904 has a Mastercard Debit
#   Assigning to...
# User 1904 has a Mastercard Debit
#   Assigning to...
# User 1904 has a Amex Credit
#   Assigning to...
# User 1905 has a Mastercard Credit
#   Assigning to...
# User 1905 has a Mastercard Debit
#   Assigning to...
# User 1906 has a Visa Debit
#   Assigning to...
# User 1906 has a Mastercard Credit
#   Assigning to...
# User 1906 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1907 has a Mastercard Debit
#   Assigning to...
# User 1907 has a Mastercard Debit
#   Assigning to...
# User 1907 has a Visa Debit
#   Assigning to...
# User 1908 has a Visa Credit
#   Assigning to...
# User 1908 has a Amex Credit
#   Assigning to...
# User 1908 has a Mastercard Debit
#   Assigning to...
# User 1908 has a Visa Credit
#   Assigning to...
# User 1909 has a Visa Debit
#   Assigning to...
# User 1909 has a Mastercard Debit
#   Assigning to...
# User 1909 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1910 has a Mastercard Debit
#   Assigning to...
# User 1910 has a Visa Credit
#   Assigning to...
# User 1910 has a Mastercard Credit
#   Assigning to...
# User 1911 has a Discover Credit
#   Assigning to...
# User 1911 has a Visa Debit
#   Assigning to...
# User 1911 has a Mastercard Debit
#   Assigning to...
# User 1911 has a Discover Credit
#   Assigning to...
# User 1911 has a Visa Credit
#   Assigning to...
# User 1912 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1912 has a Mastercard Debit
#   Assigning to...
# User 1912 has a Mastercard Debit
#   Assigning to...
# User 1912 has a Mastercard Debit
#   Assigning to...
# User 1913 has a Visa Credit
#   Assigning to...
# User 1913 has a Visa Debit
#   Assigning to...
# User 1914 has a Visa Debit
#   Assigning to...
# User 1915 has a Visa Debit
#   Assigning to...
# User 1915 has a Mastercard Debit
#   Assigning to...
# User 1916 has a Mastercard Debit
#   Assigning to...
# User 1917 has a Visa Debit
#   Assigning to...
# User 1917 has a Amex Credit
#   Assigning to...
# User 1917 has a Mastercard Credit
#   Assigning to...
# User 1917 has a Mastercard Credit
#   Assigning to...
# User 1918 has a Mastercard Debit
#   Assigning to...
# User 1918 has a Amex Credit
#   Assigning to...
# User 1918 has a Visa Debit
#   Assigning to...
# User 1919 has a Visa Debit
#   Assigning to...
# User 1919 has a Visa Debit
#   Assigning to...
# User 1919 has a Amex Credit
#   Assigning to...
# User 1919 has a Mastercard Debit
#   Assigning to...
# User 1920 has a Visa Credit
#   Assigning to...
# User 1920 has a Mastercard Credit
#   Assigning to...
# User 1920 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1920 has a Mastercard Debit
#   Assigning to...
# User 1920 has a Amex Credit
#   Assigning to...
# User 1921 has a Mastercard Credit
#   Assigning to...
# User 1921 has a Visa Credit
#   Assigning to...
# User 1921 has a Mastercard Debit
#   Assigning to...
# User 1922 has a Mastercard Debit
#   Assigning to...
# User 1922 has a Visa Debit
#   Assigning to...
# User 1922 has a Mastercard Debit
#   Assigning to...
# User 1922 has a Mastercard Debit
#   Assigning to...
# User 1923 has a Visa Debit
#   Assigning to...
# User 1923 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1923 has a Mastercard Debit
#   Assigning to...
# User 1924 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1925 has a Mastercard Debit
#   Assigning to...
# User 1925 has a Visa Credit
#   Assigning to...
# User 1926 has a Mastercard Debit
#   Assigning to...
# User 1926 has a Mastercard Debit
#   Assigning to...
# User 1926 has a Visa Credit
#   Assigning to...
# User 1926 has a Amex Credit
#   Assigning to...
# User 1926 has a Mastercard Debit
#   Assigning to...
# User 1926 has a Visa Debit
#   Assigning to...
# User 1926 has a Visa Debit
#   Assigning to...
# User 1927 has a Visa Credit
#   Assigning to...
# User 1927 has a Amex Credit
#   Assigning to...
# User 1927 has a Mastercard Debit
#   Assigning to...
# User 1927 has a Visa Credit
#   Assigning to...
# User 1928 has a Visa Debit (Prepaid)
#   Assigning to...
# User 1929 has a Visa Debit
#   Assigning to...
# User 1929 has a Visa Debit (Prepaid)
#   Assigning to...
# User 1929 has a Mastercard Debit
#   Assigning to...
# User 1930 has a Visa Credit
#   Assigning to...
# User 1930 has a Visa Credit
#   Assigning to...
# User 1930 has a Mastercard Debit
#   Assigning to...
# User 1931 has a Visa Debit
#   Assigning to...
# User 1931 has a Visa Debit (Prepaid)
#   Assigning to...
# User 1931 has a Mastercard Credit
#   Assigning to...
# User 1931 has a Amex Credit
#   Assigning to...
# User 1931 has a Visa Debit
#   Assigning to...
# User 1931 has a Mastercard Debit
#   Assigning to...
# User 1931 has a Visa Debit
#   Assigning to...
# User 1931 has a Visa Credit
#   Assigning to...
# User 1932 has a Discover Credit
#   Assigning to...
# User 1932 has a Mastercard Debit
#   Assigning to...
# User 1932 has a Mastercard Debit
#   Assigning to...
# User 1933 has a Amex Credit
#   Assigning to...
# User 1933 has a Mastercard Debit
#   Assigning to...
# User 1933 has a Visa Debit
#   Assigning to...
# User 1933 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1934 has a Mastercard Debit
#   Assigning to...
# User 1934 has a Mastercard Debit
#   Assigning to...
# User 1934 has a Mastercard Debit
#   Assigning to...
# User 1934 has a Visa Credit
#   Assigning to...
# User 1934 has a Mastercard Debit
#   Assigning to...
# User 1935 has a Mastercard Debit
#   Assigning to...
# User 1935 has a Visa Credit
#   Assigning to...
# User 1936 has a Amex Credit
#   Assigning to...
# User 1936 has a Amex Credit
#   Assigning to...
# User 1937 has a Mastercard Debit
#   Assigning to...
# User 1937 has a Visa Debit
#   Assigning to...
# User 1937 has a Visa Debit
#   Assigning to...
# User 1938 has a Mastercard Debit
#   Assigning to...
# User 1938 has a Discover Credit
#   Assigning to...
# User 1938 has a Mastercard Credit
#   Assigning to...
# User 1938 has a Visa Debit
#   Assigning to...
# User 1938 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1938 has a Visa Debit
#   Assigning to...
# User 1938 has a Visa Debit
#   Assigning to...
# User 1939 has a Mastercard Debit
#   Assigning to...
# User 1939 has a Mastercard Credit
#   Assigning to...
# User 1940 has a Mastercard Credit
#   Assigning to...
# User 1941 has a Mastercard Debit
#   Assigning to...
# User 1942 has a Visa Credit
#   Assigning to...
# User 1942 has a Mastercard Debit
#   Assigning to...
# User 1942 has a Mastercard Debit
#   Assigning to...
# User 1942 has a Discover Credit
#   Assigning to...
# User 1943 has a Mastercard Debit
#   Assigning to...
# User 1943 has a Amex Credit
#   Assigning to...
# User 1943 has a Mastercard Debit
#   Assigning to...
# User 1944 has a Mastercard Debit
#   Assigning to...
# User 1945 has a Visa Debit
#   Assigning to...
# User 1945 has a Visa Debit
#   Assigning to...
# User 1945 has a Visa Debit
#   Assigning to...
# User 1945 has a Mastercard Credit
#   Assigning to...
# User 1946 has a Mastercard Credit
#   Assigning to...
# User 1946 has a Mastercard Debit
#   Assigning to...
# User 1946 has a Visa Debit
#   Assigning to...
# User 1946 has a Mastercard Debit
#   Assigning to...
# User 1946 has a Mastercard Debit
#   Assigning to...
# User 1947 has a Mastercard Debit
#   Assigning to...
# User 1948 has a Mastercard Credit
#   Assigning to...
# User 1948 has a Visa Credit
#   Assigning to...
# User 1948 has a Mastercard Debit
#   Assigning to...
# User 1949 has a Mastercard Debit
#   Assigning to...
# User 1949 has a Mastercard Debit
#   Assigning to...
# User 1950 has a Mastercard Credit
#   Assigning to...
# User 1950 has a Visa Debit
#   Assigning to...
# User 1951 has a Mastercard Debit
#   Assigning to...
# User 1951 has a Amex Credit
#   Assigning to...
# User 1951 has a Mastercard Debit
#   Assigning to...
# User 1952 has a Visa Credit
#   Assigning to...
# User 1952 has a Mastercard Debit
#   Assigning to...
# User 1953 has a Visa Credit
#   Assigning to...
# User 1954 has a Mastercard Debit
#   Assigning to...
# User 1955 has a Visa Debit
#   Assigning to...
# User 1955 has a Visa Credit
#   Assigning to...
# User 1956 has a Visa Debit
#   Assigning to...
# User 1956 has a Amex Credit
#   Assigning to...
# User 1956 has a Mastercard Credit
#   Assigning to...
# User 1957 has a Visa Debit (Prepaid)
#   Assigning to...
# User 1958 has a Mastercard Debit
#   Assigning to...
# User 1958 has a Mastercard Debit
#   Assigning to...
# User 1958 has a Visa Credit
#   Assigning to...
# User 1958 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1958 has a Visa Debit
#   Assigning to...
# User 1959 has a Visa Credit
#   Assigning to...
# User 1959 has a Mastercard Debit
#   Assigning to...
# User 1960 has a Mastercard Debit
#   Assigning to...
# User 1960 has a Mastercard Credit
#   Assigning to...
# User 1961 has a Visa Credit
#   Assigning to...
# User 1961 has a Mastercard Debit
#   Assigning to...
# User 1961 has a Discover Credit
#   Assigning to...
# User 1961 has a Mastercard Debit
#   Assigning to...
# User 1961 has a Mastercard Debit
#   Assigning to...
# User 1961 has a Mastercard Debit
#   Assigning to...
# User 1961 has a Mastercard Debit
#   Assigning to...
# User 1961 has a Mastercard Debit
#   Assigning to...
# User 1962 has a Visa Debit
#   Assigning to...
# User 1963 has a Visa Credit
#   Assigning to...
# User 1963 has a Visa Debit
#   Assigning to...
# User 1963 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1964 has a Mastercard Debit
#   Assigning to...
# User 1964 has a Visa Debit
#   Assigning to...
# User 1964 has a Visa Debit
#   Assigning to...
# User 1964 has a Amex Credit
#   Assigning to...
# User 1965 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1965 has a Mastercard Debit
#   Assigning to...
# User 1965 has a Mastercard Debit
#   Assigning to...
# User 1966 has a Visa Debit
#   Assigning to...
# User 1967 has a Visa Credit
#   Assigning to...
# User 1967 has a Visa Debit
#   Assigning to...
# User 1967 has a Visa Debit
#   Assigning to...
# User 1967 has a Mastercard Debit
#   Assigning to...
# User 1967 has a Visa Debit
#   Assigning to...
# User 1968 has a Mastercard Debit
#   Assigning to...
# User 1968 has a Mastercard Debit
#   Assigning to...
# User 1968 has a Amex Credit
#   Assigning to...
# User 1969 has a Mastercard Debit
#   Assigning to...
# User 1969 has a Visa Debit (Prepaid)
#   Assigning to...
# User 1969 has a Mastercard Debit
#   Assigning to...
# User 1969 has a Visa Debit
#   Assigning to...
# User 1970 has a Visa Debit
#   Assigning to...
# User 1971 has a Amex Credit
#   Assigning to...
# User 1971 has a Mastercard Debit
#   Assigning to...
# User 1972 has a Mastercard Debit
#   Assigning to...
# User 1972 has a Mastercard Debit
#   Assigning to...
# User 1972 has a Mastercard Debit
#   Assigning to...
# User 1973 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1974 has a Mastercard Debit
#   Assigning to...
# User 1974 has a Mastercard Debit
#   Assigning to...
# User 1975 has a Mastercard Debit
#   Assigning to...
# User 1975 has a Visa Debit (Prepaid)
#   Assigning to...
# User 1975 has a Mastercard Debit
#   Assigning to...
# User 1976 has a Visa Debit (Prepaid)
#   Assigning to...
# User 1976 has a Mastercard Debit
#   Assigning to...
# User 1976 has a Mastercard Debit
#   Assigning to...
# User 1977 has a Mastercard Credit
#   Assigning to...
# User 1977 has a Mastercard Debit
#   Assigning to...
# User 1978 has a Visa Debit
#   Assigning to...
# User 1979 has a Visa Debit
#   Assigning to...
# User 1979 has a Mastercard Debit
#   Assigning to...
# User 1979 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1979 has a Mastercard Credit
#   Assigning to...
# User 1980 has a Mastercard Credit
#   Assigning to...
# User 1980 has a Mastercard Credit
#   Assigning to...
# User 1981 has a Mastercard Debit
#   Assigning to...
# User 1981 has a Amex Credit
#   Assigning to...
# User 1982 has a Visa Credit
#   Assigning to...
# User 1982 has a Discover Credit
#   Assigning to...
# User 1982 has a Visa Debit
#   Assigning to...
# User 1982 has a Amex Credit
#   Assigning to...
# User 1982 has a Mastercard Debit
#   Assigning to...
# User 1982 has a Mastercard Credit
#   Assigning to...
# User 1983 has a Discover Credit
#   Assigning to...
# User 1983 has a Mastercard Debit
#   Assigning to...
# User 1983 has a Visa Debit (Prepaid)
#   Assigning to...
# User 1983 has a Visa Credit
#   Assigning to...
# User 1983 has a Visa Credit
#   Assigning to...
# User 1983 has a Visa Debit
#   Assigning to...
# User 1984 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1984 has a Mastercard Debit
#   Assigning to...
# User 1984 has a Mastercard Debit
#   Assigning to...
# User 1985 has a Mastercard Debit
#   Assigning to...
# User 1985 has a Mastercard Debit
#   Assigning to...
# User 1985 has a Visa Credit
#   Assigning to...
# User 1986 has a Mastercard Debit
#   Assigning to...
# User 1987 has a Mastercard Debit
#   Assigning to...
# User 1987 has a Mastercard Debit
#   Assigning to...
# User 1987 has a Amex Credit
#   Assigning to...
# User 1988 has a Mastercard Debit
#   Assigning to...
# User 1988 has a Visa Debit (Prepaid)
#   Assigning to...
# User 1989 has a Visa Credit
#   Assigning to...
# User 1989 has a Visa Debit
#   Assigning to...
# User 1989 has a Visa Debit
#   Assigning to...
# User 1990 has a Mastercard Debit
#   Assigning to...
# User 1990 has a Visa Debit
#   Assigning to...
# User 1990 has a Mastercard Credit
#   Assigning to...
# User 1990 has a Visa Credit
#   Assigning to...
# User 1990 has a Visa Debit
#   Assigning to...
# User 1990 has a Amex Credit
#   Assigning to...
# User 1991 has a Visa Debit (Prepaid)
#   Assigning to...
# User 1992 has a Mastercard Debit
#   Assigning to...
# User 1992 has a Visa Debit
#   Assigning to...
# User 1993 has a Amex Credit
#   Assigning to...
# User 1993 has a Mastercard Debit
#   Assigning to...
# User 1993 has a Mastercard Debit (Prepaid)
#   Assigning to...
# User 1993 has a Mastercard Debit
#   Assigning to...
# User 1993 has a Visa Debit
#   Assigning to...
# User 1993 has a Visa Credit
#   Assigning to...
# User 1994 has a Visa Debit
#   Assigning to...
# User 1994 has a Discover Credit
#   Assigning to...
# User 1994 has a Mastercard Debit
#   Assigning to...
# User 1995 has a Visa Debit
#   Assigning to...
# User 1995 has a Visa Debit
#   Assigning to...
# User 1995 has a Discover Credit
#   Assigning to...
# User 1996 has a Mastercard Debit
#   Assigning to...
# User 1996 has a Mastercard Debit
#   Assigning to...
# User 1996 has a Visa Credit
#   Assigning to...
# User 1996 has a Mastercard Debit
#   Assigning to...
# User 1997 has a Mastercard Debit
#   Assigning to...
# User 1997 has a Amex Credit
#   Assigning to...
# User 1997 has a Visa Credit
#   Assigning to...
# User 1998 has a Mastercard Credit
#   Assigning to...
# User 1999 has a Mastercard Debit
#   Assigning to...
# User 1999 has a Visa Credit
#   Assigning to...

# %%
match_list = []

for index, row in cc_combinations_df.iterrows():
    match_list.append(row['Card Brand'] + " " + row['Card Type'])

match_list

# %%
user_cc_df['Mastercard']['Debit']

# %%
for user in cc_df['User'].unique():
    df = cc_df.loc[cc_df['User'] == user]
    card_count = df['CARD INDEX'].count()
    user_cc_df = df.groupby(by=["Card Brand", "Card Type"], as_index = False).size()
    print(f"User {user} has {card_count} credit cards")
    print(user_cc_df)
    print()

# %%
card_count['Mastercard']
