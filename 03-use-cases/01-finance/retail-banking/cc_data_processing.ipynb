# %% [markdown]
# ## Import Dependencies

# %%
import atoti
import pandas as pd
import time

# %% [markdown]
# ## Load Data from S3

# %%
# Load credit card info data
cc_df = pd.read_csv('s3://data.atoti.io/notebooks/retail-banking/sd254_cards.csv')
cc_df
# Out:
#       User  CARD INDEX  Card Brand        Card Type       Card Number  \
# 0        0           0        Visa            Debit  4344676511950444
# 1        0           1        Visa            Debit  4956965974959986
# 2        0           2        Visa            Debit  4582313478255491
# 3        0           3        Visa           Credit  4879494103069057
# 4        0           4  Mastercard  Debit (Prepaid)  5722874738736011
# ...    ...         ...         ...              ...               ...
# 6141  1997           1        Amex           Credit   300609782832003
# 6142  1997           2        Visa           Credit  4718517475996018
# 6143  1998           0  Mastercard           Credit  5929512204765914
# 6144  1999           0  Mastercard            Debit  5589768928167462
# 6145  1999           1        Visa           Credit  4994011318343994
#
#       Expires  CVV Has Chip  Cards Issued Credit Limit Acct Open Date  \
# 0     12/2022  623      YES             2       $24295        09/2002
# 1     12/2020  393      YES             2       $21968        04/2014
# 2     02/2024  719      YES             2       $46414        07/2003
# 3     08/2024  693       NO             1       $12400        01/2003
# 4     03/2009   75      YES             1          $28        09/2008
# ...       ...  ...      ...           ...          ...            ...
# 6141  01/2024  663      YES             1        $6900        11/2000
# 6142  01/2021  492      YES             2        $5700        04/2012
# 6143  08/2020  237       NO             2        $9200        02/2012
# 6144  01/2020  630      YES             1       $28074        01/2020
# 6145  12/2020  120      YES             1       $14400        05/2017
#
#       Year PIN last Changed Card on Dark Web
# 0                      2008               No
# 1                      2014               No
# 2                      2004               No
# 3                      2012               No
# 4                      2009               No
# ...                     ...              ...
# 6141                   2013               No
# 6142                   2012               No
# 6143                   2012               No
# 6144                   2020               No
# 6145                   2017               No
#
# [6146 rows x 13 columns]

# %% [markdown]
# ## Analyze User Credit Card Data

# %%
# Find the distinct credit card brands
unique_values = cc_df['Card Brand'].unique()
print(sorted(unique_values))
# Out:
# ['Amex', 'Discover', 'Mastercard', 'Visa']

# %%
# Find the distinct credit card combinations, and their frequency counts overall
cc_combinations_df = cc_df.groupby(['Card Brand', 'Card Type'], as_index = False).size()
cc_combinations_df
# Out:
#    Card Brand        Card Type  size
# 0        Amex           Credit   402
# 1    Discover           Credit   209
# 2  Mastercard           Credit   635
# 3  Mastercard            Debit  2191
# 4  Mastercard  Debit (Prepaid)   383
# 5        Visa           Credit   811
# 6        Visa            Debit  1320
# 7        Visa  Debit (Prepaid)   195

# %%
# Find the distinct credit card combinations for each user, and their frequency counts
cc_combinations_df = cc_df.groupby(['User', 'Card Brand', 'Card Type'], as_index = False).size()
cc_combinations_df
# Out:
#       User  Card Brand        Card Type  size
# 0        0  Mastercard  Debit (Prepaid)     1
# 1        0        Visa           Credit     1
# 2        0        Visa            Debit     3
# 3        1  Mastercard            Debit     1
# 4        1  Mastercard  Debit (Prepaid)     2
# ...    ...         ...              ...   ...
# 4646  1997  Mastercard            Debit     1
# 4647  1997        Visa           Credit     1
# 4648  1998  Mastercard           Credit     1
# 4649  1999  Mastercard            Debit     1
# 4650  1999        Visa           Credit     1
#
# [4651 rows x 4 columns]

# %%
# Find the max frequency count for all distinct credit card combinations at the user level
max_cc_combinations = cc_combinations_df.groupby(['Card Brand', 'Card Type'], as_index = False)['size'].max()
max_cc_combinations
# Out:
#    Card Brand        Card Type  size
# 0        Amex           Credit     4
# 1    Discover           Credit     2
# 2  Mastercard           Credit     4
# 3  Mastercard            Debit     6
# 4  Mastercard  Debit (Prepaid)     3
# 5        Visa           Credit     4
# 6        Visa            Debit     5
# 7        Visa  Debit (Prepaid)     2

# %%
# Load user credit card data
cc_df = pd.read_csv('s3://data.atoti.io/notebooks/retail-banking/sd254_cards.csv')
cc_df
# Out:
#       User  CARD INDEX  Card Brand        Card Type       Card Number  \
# 0        0           0        Visa            Debit  4344676511950444
# 1        0           1        Visa            Debit  4956965974959986
# 2        0           2        Visa            Debit  4582313478255491
# 3        0           3        Visa           Credit  4879494103069057
# 4        0           4  Mastercard  Debit (Prepaid)  5722874738736011
# ...    ...         ...         ...              ...               ...
# 6141  1997           1        Amex           Credit   300609782832003
# 6142  1997           2        Visa           Credit  4718517475996018
# 6143  1998           0  Mastercard           Credit  5929512204765914
# 6144  1999           0  Mastercard            Debit  5589768928167462
# 6145  1999           1        Visa           Credit  4994011318343994
#
#       Expires  CVV Has Chip  Cards Issued Credit Limit Acct Open Date  \
# 0     12/2022  623      YES             2       $24295        09/2002
# 1     12/2020  393      YES             2       $21968        04/2014
# 2     02/2024  719      YES             2       $46414        07/2003
# 3     08/2024  693       NO             1       $12400        01/2003
# 4     03/2009   75      YES             1          $28        09/2008
# ...       ...  ...      ...           ...          ...            ...
# 6141  01/2024  663      YES             1        $6900        11/2000
# 6142  01/2021  492      YES             2        $5700        04/2012
# 6143  08/2020  237       NO             2        $9200        02/2012
# 6144  01/2020  630      YES             1       $28074        01/2020
# 6145  12/2020  120      YES             1       $14400        05/2017
#
#       Year PIN last Changed Card on Dark Web
# 0                      2008               No
# 1                      2014               No
# 2                      2004               No
# 3                      2012               No
# 4                      2009               No
# ...                     ...              ...
# 6141                   2013               No
# 6142                   2012               No
# 6143                   2012               No
# 6144                   2020               No
# 6145                   2017               No
#
# [6146 rows x 13 columns]

# %%
# Load credit card info data
cc_info = pd.read_csv('s3://data.atoti.io/notebooks/retail-banking/cc_info.csv')
cc_info
# Out:
#     Retailer ID                                      Retailer Name  \
# 0             1                               Cathay Pacific Elite
# 1             2                                      Hilton Honors
# 2             3                             Delta SkyMiles Reserve
# 3             4                           Marriot Bonvoy Brilliant
# 4             5                                  Discover it Miles
# 5             6                                Discover it Secured
# 6             7                     Capital One VentureOne Rewards
# 7             8            Citi / AAdvantage Executive World Elite
# 8             9               Capital One Quicksilver Cash Rewards
# 9            10                           IHG One Rewards Traveler
# 10           11                                 TransferWise Debit
# 11           12                                              Venmo
# 12           13                                      Walmart Money
# 13           14                                            Revolut
# 14           15                                      Credit Sesame
# 15           16                                        Branch Card
# 16           17                          PayPal Prepaid Mastercard
# 17           18                          H&R Block Emerald Prepaid
# 18           19                    Ready Credit Prepaid Mastercard
# 19           20              Holland America LineRewards Visa Card
# 20           21                                   Princess Rewards
# 21           22                             Wyndham Rewards Earner
# 22           23                               Costco Anywhere Visa
# 23           24                                        Wells Fargo
# 24           25                                            TD Bank
# 25           26                                           Barclays
# 26           27                                    Bank of America
# 27           28                                              Chase
# 28           29                   H&R Advantage Prepaid Visa Card
# 29           30  Digital Commerce Bank Reloadable Visa Prepaid ...
#
#     Card Brand        Card Type                Industry
# 0         Amex           Credit             Industrials
# 1         Amex           Credit  Consumer Discretionary
# 2         Amex           Credit             Industrials
# 3         Amex           Credit  Consumer Discretionary
# 4     Discover           Credit              Financials
# 5     Discover           Credit              Financials
# 6   Mastercard           Credit              Financials
# 7   Mastercard           Credit             Industrials
# 8   Mastercard           Credit              Financials
# 9   Mastercard           Credit  Consumer Discretionary
# 10  Mastercard            Debit              Financials
# 11  Mastercard            Debit              Financials
# 12  Mastercard            Debit  Consumer Discretionary
# 13  Mastercard            Debit              Financials
# 14  Mastercard            Debit              Financials
# 15  Mastercard            Debit              Financials
# 16  Mastercard  Debit (Prepaid)              Financials
# 17  Mastercard  Debit (Prepaid)              Financials
# 18  Mastercard  Debit (Prepaid)              Financials
# 19        Visa           Credit  Consumer Discretionary
# 20        Visa           Credit  Consumer Discretionary
# 21        Visa           Credit  Consumer Discretionary
# 22        Visa           Credit        Consumer Staples
# 23        Visa            Debit              Financials
# 24        Visa            Debit              Financials
# 25        Visa            Debit              Financials
# 26        Visa            Debit              Financials
# 27        Visa            Debit              Financisls
# 28        Visa  Debit (Prepaid)              Financials
# 29        Visa  Debit (Prepaid)              Financials

# %%
# Due to lack of time, this is an extremely crude way
# of creating the entity relationship (hard-coding), sorry!
cc_dict = {'Amex Credit': [1, 2, 3, 4],
           'Discover Credit': [5, 6],
           'Mastercard Credit': [7, 8, 9, 10],
           'Mastercard Debit': [11, 12, 13, 14, 15, 16],
           'Mastercard Debit (Prepaid)': [17, 18, 19],
           'Visa Credit': [20, 21, 22, 23],
           'Visa Debit': [24, 25, 26, 27, 28],
           'Visa Debit (Prepaid)': [29, 30]
           }

# %%
# Add the new `Retailer ID` column with empty values
cc_df.insert(2, 'Retailer ID', "")
cc_df
# Out:
#       User  CARD INDEX Retailer ID  Card Brand        Card Type  \
# 0        0           0                    Visa            Debit
# 1        0           1                    Visa            Debit
# 2        0           2                    Visa            Debit
# 3        0           3                    Visa           Credit
# 4        0           4              Mastercard  Debit (Prepaid)
# ...    ...         ...         ...         ...              ...
# 6141  1997           1                    Amex           Credit
# 6142  1997           2                    Visa           Credit
# 6143  1998           0              Mastercard           Credit
# 6144  1999           0              Mastercard            Debit
# 6145  1999           1                    Visa           Credit
#
#            Card Number  Expires  CVV Has Chip  Cards Issued Credit Limit  \
# 0     4344676511950444  12/2022  623      YES             2       $24295
# 1     4956965974959986  12/2020  393      YES             2       $21968
# 2     4582313478255491  02/2024  719      YES             2       $46414
# 3     4879494103069057  08/2024  693       NO             1       $12400
# 4     5722874738736011  03/2009   75      YES             1          $28
# ...                ...      ...  ...      ...           ...          ...
# 6141   300609782832003  01/2024  663      YES             1        $6900
# 6142  4718517475996018  01/2021  492      YES             2        $5700
# 6143  5929512204765914  08/2020  237       NO             2        $9200
# 6144  5589768928167462  01/2020  630      YES             1       $28074
# 6145  4994011318343994  12/2020  120      YES             1       $14400
#
#      Acct Open Date  Year PIN last Changed Card on Dark Web
# 0           09/2002                   2008               No
# 1           04/2014                   2014               No
# 2           07/2003                   2004               No
# 3           01/2003                   2012               No
# 4           09/2008                   2009               No
# ...             ...                    ...              ...
# 6141        11/2000                   2013               No
# 6142        04/2012                   2012               No
# 6143        02/2012                   2012               No
# 6144        01/2020                   2020               No
# 6145        05/2017                   2017               No
#
# [6146 rows x 14 columns]

# %%
# Get cards for each unique user and sort by Card Brand and Card Type
# Set the Retailer ID for each user credit card, while accounting for
# Users with multiple distinct credit cards of the same Card Brand and Card Type
for user in cc_df['User'].unique():
    df = cc_df.loc[cc_df['User'] == user].sort_values(by=['Card Brand', 'Card Type'])
    prev_row = None
    
    for index, row in df.iterrows():
        cc_input = row['Card Brand'] + " " + row['Card Type']
        distinct_count = cc_combinations_df.loc[
                        (cc_combinations_df['User'] == user) & 
                        (cc_combinations_df['Card Brand'] == row['Card Brand']) 
                        & (cc_combinations_df['Card Type'] == row['Card Type'])]['size'].values[0]
        
        if prev_row is None:
            print("FIRST ROW AND NEW CARD FOR USER")
            num_counter = 0
            print(f"  User {user} has a {cc_input}, and has {distinct_count} distinct cards")
            assignment = cc_dict[cc_input][num_counter]
            print(f"    Assigning to Retailer ID... {assignment}")
            cc_df.loc[index, 'Retailer ID'] = assignment
            prev_row = row
            
        else:
            
            if str(prev_row['Card Brand']) == str(row['Card Brand']) and str(prev_row['Card Type']) == str(row['Card Type']):
                print("SAME CARD AS PREVIOUS ROW")
                num_counter+=1
                print(f"  User {user} has a {cc_input}, which is same as above, and has {distinct_count} distinct cards")
                assignment = cc_dict[cc_input][num_counter]
                print(f"    Assigning to Retailer ID... {assignment}")
                cc_df.loc[index, 'Retailer ID'] = assignment
                prev_row = row
                
            else:
                print("NEW CARD FOR SAME USER")
                num_counter = 0
                print(f"  User {user} has a {cc_input}, and has {distinct_count} distinct cards")
                assignment = cc_dict[cc_input][num_counter]
                print(f"    Assigning to Retailer ID... {assignment}")
                cc_df.loc[index, 'Retailer ID'] = assignment
                prev_row = row
# Out:
# FIRST ROW AND NEW CARD FOR USER
#   User 0 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# NEW CARD FOR SAME USER
#   User 0 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 0 has a Visa Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 0 has a Visa Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 25
# SAME CARD AS PREVIOUS ROW
#   User 0 has a Visa Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 26
# FIRST ROW AND NEW CARD FOR USER
#   User 1 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1 has a Mastercard Debit (Prepaid), and has 2 distinct cards
#     Assigning to Retailer ID... 17
# SAME CARD AS PREVIOUS ROW
#   User 1 has a Mastercard Debit (Prepaid), which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 18
# NEW CARD FOR SAME USER
#   User 1 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 1 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 2 has a Mastercard Debit, and has 4 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 2 has a Mastercard Debit, which is same as above, and has 4 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 2 has a Mastercard Debit, which is same as above, and has 4 distinct cards
#     Assigning to Retailer ID... 13
# SAME CARD AS PREVIOUS ROW
#   User 2 has a Mastercard Debit, which is same as above, and has 4 distinct cards
#     Assigning to Retailer ID... 14
# NEW CARD FOR SAME USER
#   User 2 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 3 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# NEW CARD FOR SAME USER
#   User 3 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 3 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 3 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 4 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 5 has a Visa Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 20
# SAME CARD AS PREVIOUS ROW
#   User 5 has a Visa Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 21
# NEW CARD FOR SAME USER
#   User 5 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 6 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 6 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 6 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 7 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 8 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 8 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 8 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# NEW CARD FOR SAME USER
#   User 8 has a Visa Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 20
# SAME CARD AS PREVIOUS ROW
#   User 8 has a Visa Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 21
# FIRST ROW AND NEW CARD FOR USER
#   User 9 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 10 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 10 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 11 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 12 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 13 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 13 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 13 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 14 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 15 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 15 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 15 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 15 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 15 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# NEW CARD FOR SAME USER
#   User 15 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 16 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 16 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 16 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 16 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# NEW CARD FOR SAME USER
#   User 16 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 16 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 17 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 17 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 17 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 17 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 18 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 18 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 18 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 19 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 19 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 19 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# NEW CARD FOR SAME USER
#   User 19 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# NEW CARD FOR SAME USER
#   User 19 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 20 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 20 has a Visa Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 20
# SAME CARD AS PREVIOUS ROW
#   User 20 has a Visa Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 21
# FIRST ROW AND NEW CARD FOR USER
#   User 21 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 21 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 22 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 22 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 23 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 23 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 24 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# FIRST ROW AND NEW CARD FOR USER
#   User 25 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 25 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 25 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 26 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 26 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 27 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 28 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 28 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 29 has a Mastercard Debit, and has 4 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 29 has a Mastercard Debit, which is same as above, and has 4 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 29 has a Mastercard Debit, which is same as above, and has 4 distinct cards
#     Assigning to Retailer ID... 13
# SAME CARD AS PREVIOUS ROW
#   User 29 has a Mastercard Debit, which is same as above, and has 4 distinct cards
#     Assigning to Retailer ID... 14
# FIRST ROW AND NEW CARD FOR USER
#   User 30 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# FIRST ROW AND NEW CARD FOR USER
#   User 31 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 31 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 31 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 31 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# FIRST ROW AND NEW CARD FOR USER
#   User 32 has a Visa Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 20
# SAME CARD AS PREVIOUS ROW
#   User 32 has a Visa Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 21
# FIRST ROW AND NEW CARD FOR USER
#   User 33 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 33 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 34 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 34 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 34 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 35 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 35 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# FIRST ROW AND NEW CARD FOR USER
#   User 36 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 36 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 36 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 36 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# NEW CARD FOR SAME USER
#   User 36 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 37 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# FIRST ROW AND NEW CARD FOR USER
#   User 38 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 39 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 40 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 40 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 40 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 40 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# NEW CARD FOR SAME USER
#   User 40 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 40 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 40 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 41 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 41 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 41 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 41 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# NEW CARD FOR SAME USER
#   User 41 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 42 has a Mastercard Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 7
# SAME CARD AS PREVIOUS ROW
#   User 42 has a Mastercard Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 8
# NEW CARD FOR SAME USER
#   User 42 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# NEW CARD FOR SAME USER
#   User 42 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 43 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 44 has a Mastercard Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 7
# SAME CARD AS PREVIOUS ROW
#   User 44 has a Mastercard Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 8
# NEW CARD FOR SAME USER
#   User 44 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 45 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# FIRST ROW AND NEW CARD FOR USER
#   User 46 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# FIRST ROW AND NEW CARD FOR USER
#   User 47 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 47 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 47 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 47 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 47 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 48 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 48 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 48 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 49 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 49 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 49 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 50 has a Mastercard Debit, and has 4 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 50 has a Mastercard Debit, which is same as above, and has 4 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 50 has a Mastercard Debit, which is same as above, and has 4 distinct cards
#     Assigning to Retailer ID... 13
# SAME CARD AS PREVIOUS ROW
#   User 50 has a Mastercard Debit, which is same as above, and has 4 distinct cards
#     Assigning to Retailer ID... 14
# FIRST ROW AND NEW CARD FOR USER
#   User 51 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 52 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 52 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 52 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 53 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 53 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 54 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 54 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 54 has a Visa Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 54 has a Visa Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 25
# SAME CARD AS PREVIOUS ROW
#   User 54 has a Visa Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 26
# FIRST ROW AND NEW CARD FOR USER
#   User 55 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 55 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 55 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# NEW CARD FOR SAME USER
#   User 55 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 56 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# FIRST ROW AND NEW CARD FOR USER
#   User 57 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 57 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# NEW CARD FOR SAME USER
#   User 57 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 58 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 59 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 59 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 60 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 60 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 61 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 61 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 61 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 61 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# NEW CARD FOR SAME USER
#   User 61 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# NEW CARD FOR SAME USER
#   User 61 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 61 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# NEW CARD FOR SAME USER
#   User 61 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 62 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 62 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 62 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 62 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 63 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 63 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 63 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 64 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 64 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# FIRST ROW AND NEW CARD FOR USER
#   User 65 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 65 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 65 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 66 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 66 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 67 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 67 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 67 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 68 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 68 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 69 has a Visa Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 20
# SAME CARD AS PREVIOUS ROW
#   User 69 has a Visa Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 21
# NEW CARD FOR SAME USER
#   User 69 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 70 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 71 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 71 has a Visa Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 20
# SAME CARD AS PREVIOUS ROW
#   User 71 has a Visa Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 21
# NEW CARD FOR SAME USER
#   User 71 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 72 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 72 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 73 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 73 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 73 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 73 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 73 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# NEW CARD FOR SAME USER
#   User 73 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 73 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 74 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 74 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 74 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 74 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 75 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 75 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 75 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 75 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# NEW CARD FOR SAME USER
#   User 75 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 76 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 77 has a Mastercard Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 7
# SAME CARD AS PREVIOUS ROW
#   User 77 has a Mastercard Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 8
# NEW CARD FOR SAME USER
#   User 77 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 78 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 78 has a Visa Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 20
# SAME CARD AS PREVIOUS ROW
#   User 78 has a Visa Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 21
# NEW CARD FOR SAME USER
#   User 78 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 79 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 79 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 79 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# NEW CARD FOR SAME USER
#   User 79 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 80 has a Mastercard Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 7
# SAME CARD AS PREVIOUS ROW
#   User 80 has a Mastercard Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 8
# NEW CARD FOR SAME USER
#   User 80 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 81 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 81 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 81 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 82 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 83 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 83 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 83 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 83 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 84 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 84 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# NEW CARD FOR SAME USER
#   User 84 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 85 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 85 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 86 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 86 has a Visa Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 20
# SAME CARD AS PREVIOUS ROW
#   User 86 has a Visa Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 21
# NEW CARD FOR SAME USER
#   User 86 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 87 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 87 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 88 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 88 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 89 has a Amex Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 1
# SAME CARD AS PREVIOUS ROW
#   User 89 has a Amex Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 2
# NEW CARD FOR SAME USER
#   User 89 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 89 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 89 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 90 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 91 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 91 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 92 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 92 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 93 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 93 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 94 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# FIRST ROW AND NEW CARD FOR USER
#   User 95 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# FIRST ROW AND NEW CARD FOR USER
#   User 96 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 96 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 97 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 97 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 98 has a Mastercard Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 7
# SAME CARD AS PREVIOUS ROW
#   User 98 has a Mastercard Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 8
# NEW CARD FOR SAME USER
#   User 98 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 98 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 98 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 98 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 99 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 99 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 100 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 100 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 100 has a Mastercard Debit, and has 5 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 100 has a Mastercard Debit, which is same as above, and has 5 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 100 has a Mastercard Debit, which is same as above, and has 5 distinct cards
#     Assigning to Retailer ID... 13
# SAME CARD AS PREVIOUS ROW
#   User 100 has a Mastercard Debit, which is same as above, and has 5 distinct cards
#     Assigning to Retailer ID... 14
# SAME CARD AS PREVIOUS ROW
#   User 100 has a Mastercard Debit, which is same as above, and has 5 distinct cards
#     Assigning to Retailer ID... 15
# FIRST ROW AND NEW CARD FOR USER
#   User 101 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 101 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 101 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 102 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 102 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 102 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# NEW CARD FOR SAME USER
#   User 102 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# NEW CARD FOR SAME USER
#   User 102 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 103 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 103 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 103 has a Mastercard Debit (Prepaid), and has 2 distinct cards
#     Assigning to Retailer ID... 17
# SAME CARD AS PREVIOUS ROW
#   User 103 has a Mastercard Debit (Prepaid), which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 18
# FIRST ROW AND NEW CARD FOR USER
#   User 104 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 104 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 104 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# NEW CARD FOR SAME USER
#   User 104 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 105 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# FIRST ROW AND NEW CARD FOR USER
#   User 106 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 106 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 106 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 107 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 107 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 108 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 108 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 108 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 109 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 109 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 109 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# FIRST ROW AND NEW CARD FOR USER
#   User 110 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 110 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 111 has a Amex Credit, and has 3 distinct cards
#     Assigning to Retailer ID... 1
# SAME CARD AS PREVIOUS ROW
#   User 111 has a Amex Credit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 2
# SAME CARD AS PREVIOUS ROW
#   User 111 has a Amex Credit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 3
# NEW CARD FOR SAME USER
#   User 111 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 111 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 112 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 112 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# NEW CARD FOR SAME USER
#   User 112 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 113 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 114 has a Mastercard Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 7
# SAME CARD AS PREVIOUS ROW
#   User 114 has a Mastercard Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 8
# NEW CARD FOR SAME USER
#   User 114 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 115 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 116 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 116 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 116 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 116 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# NEW CARD FOR SAME USER
#   User 116 has a Visa Debit, and has 5 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 116 has a Visa Debit, which is same as above, and has 5 distinct cards
#     Assigning to Retailer ID... 25
# SAME CARD AS PREVIOUS ROW
#   User 116 has a Visa Debit, which is same as above, and has 5 distinct cards
#     Assigning to Retailer ID... 26
# SAME CARD AS PREVIOUS ROW
#   User 116 has a Visa Debit, which is same as above, and has 5 distinct cards
#     Assigning to Retailer ID... 27
# SAME CARD AS PREVIOUS ROW
#   User 116 has a Visa Debit, which is same as above, and has 5 distinct cards
#     Assigning to Retailer ID... 28
# FIRST ROW AND NEW CARD FOR USER
#   User 117 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 117 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 117 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 117 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 118 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 118 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 118 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 119 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 119 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 119 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 120 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 120 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# FIRST ROW AND NEW CARD FOR USER
#   User 121 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 121 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 122 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 122 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 122 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# NEW CARD FOR SAME USER
#   User 122 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 123 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 123 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 123 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 124 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 124 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 124 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 125 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 125 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 125 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# FIRST ROW AND NEW CARD FOR USER
#   User 126 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 126 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 126 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# FIRST ROW AND NEW CARD FOR USER
#   User 127 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 127 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# FIRST ROW AND NEW CARD FOR USER
#   User 128 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 128 has a Visa Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 128 has a Visa Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 25
# SAME CARD AS PREVIOUS ROW
#   User 128 has a Visa Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 26
# FIRST ROW AND NEW CARD FOR USER
#   User 129 has a Mastercard Debit, and has 1 distinct cards
# ...
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 1957 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 1958 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1958 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 1958 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# NEW CARD FOR SAME USER
#   User 1958 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 1958 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 1959 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1959 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 1960 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 1960 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 1961 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 1961 has a Mastercard Debit, and has 6 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1961 has a Mastercard Debit, which is same as above, and has 6 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 1961 has a Mastercard Debit, which is same as above, and has 6 distinct cards
#     Assigning to Retailer ID... 13
# SAME CARD AS PREVIOUS ROW
#   User 1961 has a Mastercard Debit, which is same as above, and has 6 distinct cards
#     Assigning to Retailer ID... 14
# SAME CARD AS PREVIOUS ROW
#   User 1961 has a Mastercard Debit, which is same as above, and has 6 distinct cards
#     Assigning to Retailer ID... 15
# SAME CARD AS PREVIOUS ROW
#   User 1961 has a Mastercard Debit, which is same as above, and has 6 distinct cards
#     Assigning to Retailer ID... 16
# NEW CARD FOR SAME USER
#   User 1961 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 1962 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 1963 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# NEW CARD FOR SAME USER
#   User 1963 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 1963 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 1964 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 1964 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1964 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 1964 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 1965 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1965 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 1965 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# FIRST ROW AND NEW CARD FOR USER
#   User 1966 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 1967 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1967 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 1967 has a Visa Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 1967 has a Visa Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 25
# SAME CARD AS PREVIOUS ROW
#   User 1967 has a Visa Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 26
# FIRST ROW AND NEW CARD FOR USER
#   User 1968 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 1968 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1968 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 1969 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1969 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 1969 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# NEW CARD FOR SAME USER
#   User 1969 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 1970 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 1971 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 1971 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 1972 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1972 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 1972 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# FIRST ROW AND NEW CARD FOR USER
#   User 1973 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# FIRST ROW AND NEW CARD FOR USER
#   User 1974 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1974 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 1975 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1975 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 1975 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 1976 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1976 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 1976 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 1977 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 1977 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 1978 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 1979 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 1979 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1979 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# NEW CARD FOR SAME USER
#   User 1979 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 1980 has a Mastercard Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 7
# SAME CARD AS PREVIOUS ROW
#   User 1980 has a Mastercard Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 8
# FIRST ROW AND NEW CARD FOR USER
#   User 1981 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 1981 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 1982 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 1982 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 1982 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 1982 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1982 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 1982 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 1983 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 1983 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1983 has a Visa Credit, and has 2 distinct cards
#     Assigning to Retailer ID... 20
# SAME CARD AS PREVIOUS ROW
#   User 1983 has a Visa Credit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 21
# NEW CARD FOR SAME USER
#   User 1983 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# NEW CARD FOR SAME USER
#   User 1983 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 1984 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1984 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 1984 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# FIRST ROW AND NEW CARD FOR USER
#   User 1985 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1985 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 1985 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 1986 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# FIRST ROW AND NEW CARD FOR USER
#   User 1987 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 1987 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1987 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# FIRST ROW AND NEW CARD FOR USER
#   User 1988 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1988 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 1989 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 1989 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 1989 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 1990 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 1990 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# NEW CARD FOR SAME USER
#   User 1990 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1990 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 1990 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 1990 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 1991 has a Visa Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 29
# FIRST ROW AND NEW CARD FOR USER
#   User 1992 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1992 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 1993 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 1993 has a Mastercard Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1993 has a Mastercard Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 12
# NEW CARD FOR SAME USER
#   User 1993 has a Mastercard Debit (Prepaid), and has 1 distinct cards
#     Assigning to Retailer ID... 17
# NEW CARD FOR SAME USER
#   User 1993 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# NEW CARD FOR SAME USER
#   User 1993 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 1994 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 1994 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1994 has a Visa Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 24
# FIRST ROW AND NEW CARD FOR USER
#   User 1995 has a Discover Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 5
# NEW CARD FOR SAME USER
#   User 1995 has a Visa Debit, and has 2 distinct cards
#     Assigning to Retailer ID... 24
# SAME CARD AS PREVIOUS ROW
#   User 1995 has a Visa Debit, which is same as above, and has 2 distinct cards
#     Assigning to Retailer ID... 25
# FIRST ROW AND NEW CARD FOR USER
#   User 1996 has a Mastercard Debit, and has 3 distinct cards
#     Assigning to Retailer ID... 11
# SAME CARD AS PREVIOUS ROW
#   User 1996 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 12
# SAME CARD AS PREVIOUS ROW
#   User 1996 has a Mastercard Debit, which is same as above, and has 3 distinct cards
#     Assigning to Retailer ID... 13
# NEW CARD FOR SAME USER
#   User 1996 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 1997 has a Amex Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 1
# NEW CARD FOR SAME USER
#   User 1997 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1997 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20
# FIRST ROW AND NEW CARD FOR USER
#   User 1998 has a Mastercard Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 7
# FIRST ROW AND NEW CARD FOR USER
#   User 1999 has a Mastercard Debit, and has 1 distinct cards
#     Assigning to Retailer ID... 11
# NEW CARD FOR SAME USER
#   User 1999 has a Visa Credit, and has 1 distinct cards
#     Assigning to Retailer ID... 20

# %%
# Check Retailer ID values have been assigned
cc_df
# Out:
#       User  CARD INDEX Retailer ID  Card Brand        Card Type  \
# 0        0           0          24        Visa            Debit
# 1        0           1          25        Visa            Debit
# 2        0           2          26        Visa            Debit
# 3        0           3          20        Visa           Credit
# 4        0           4          17  Mastercard  Debit (Prepaid)
# ...    ...         ...         ...         ...              ...
# 6141  1997           1           1        Amex           Credit
# 6142  1997           2          20        Visa           Credit
# 6143  1998           0           7  Mastercard           Credit
# 6144  1999           0          11  Mastercard            Debit
# 6145  1999           1          20        Visa           Credit
#
#            Card Number  Expires  CVV Has Chip  Cards Issued Credit Limit  \
# 0     4344676511950444  12/2022  623      YES             2       $24295
# 1     4956965974959986  12/2020  393      YES             2       $21968
# 2     4582313478255491  02/2024  719      YES             2       $46414
# 3     4879494103069057  08/2024  693       NO             1       $12400
# 4     5722874738736011  03/2009   75      YES             1          $28
# ...                ...      ...  ...      ...           ...          ...
# 6141   300609782832003  01/2024  663      YES             1        $6900
# 6142  4718517475996018  01/2021  492      YES             2        $5700
# 6143  5929512204765914  08/2020  237       NO             2        $9200
# 6144  5589768928167462  01/2020  630      YES             1       $28074
# 6145  4994011318343994  12/2020  120      YES             1       $14400
#
#      Acct Open Date  Year PIN last Changed Card on Dark Web
# 0           09/2002                   2008               No
# 1           04/2014                   2014               No
# 2           07/2003                   2004               No
# 3           01/2003                   2012               No
# 4           09/2008                   2009               No
# ...             ...                    ...              ...
# 6141        11/2000                   2013               No
# 6142        04/2012                   2012               No
# 6143        02/2012                   2012               No
# 6144        01/2020                   2020               No
# 6145        05/2017                   2017               No
#
# [6146 rows x 14 columns]

# %%
# Remove the `Card Brand` and `Card Type` columns
cc_df.drop(columns=['Card Brand', 'Card Type'], inplace=True)
cc_df.head()
# Out:
#    User  CARD INDEX Retailer ID       Card Number  Expires  CVV Has Chip  \
# 0     0           0          24  4344676511950444  12/2022  623      YES
# 1     0           1          25  4956965974959986  12/2020  393      YES
# 2     0           2          26  4582313478255491  02/2024  719      YES
# 3     0           3          20  4879494103069057  08/2024  693       NO
# 4     0           4          17  5722874738736011  03/2009   75      YES
#
#    Cards Issued Credit Limit Acct Open Date  Year PIN last Changed  \
# 0             2       $24295        09/2002                   2008
# 1             2       $21968        04/2014                   2014
# 2             2       $46414        07/2003                   2004
# 3             1       $12400        01/2003                   2012
# 4             1          $28        09/2008                   2009
#
#   Card on Dark Web
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No

# %%
# Cast intended measures as numerical data types
cc_df['Credit Limit'] = cc_df['Credit Limit'].str.replace('$', '')
cc_df['Credit Limit'] = cc_df['Credit Limit'].astype(int)
cc_df['Credit Limit'] = cc_df['Credit Limit'] + 50000

# %%
# Output DataFrame to CSV file
cc_df.to_csv('processed_data/sd254_cards_processed.csv')

# %% [markdown]
# ## Add Credit Loss Attributes to Users Data

# %%
# Load users info data
users_df = pd.read_csv('s3://data.atoti.io/notebooks/retail-banking/sd254_users.csv')
users_df
# Out:
#                  Person  Current Age  Retirement Age  Birth Year  Birth Month  \
# 0        Hazel Robinson           53              66        1966           11
# 1            Sasha Sadr           53              68        1966           12
# 2            Saanvi Lee           81              67        1938           11
# 3         Everlee Clark           63              63        1957            1
# 4         Kyle Peterson           43              70        1976            9
# ...                 ...          ...             ...         ...          ...
# 1995       Jose Faraday           32              70        1987            7
# 1996  Ximena Richardson           62              65        1957           11
# 1997     Annika Russell           47              67        1973            1
# 1998        Juelz Roman           66              60        1954            2
# 1999       Kenia Harris           21              60        1998           11
#
#       Gender                   Address  Apartment           City State  \
# 0     Female             462 Rose Lane        NaN       La Verne    CA
# 1     Female    3606 Federal Boulevard        NaN    Little Neck    NY
# 2     Female           766 Third Drive        NaN    West Covina    CA
# 3     Female          3 Madison Street        NaN       New York    NY
# 4       Male  9620 Valley Stream Drive        NaN  San Francisco    CA
# ...      ...                       ...        ...            ...   ...
# 1995    Male       6577 Lexington Lane        9.0       Freeport    NY
# 1996  Female               2 Elm Drive      955.0   Independence    KY
# 1997  Female       276 Fifth Boulevard        NaN      Elizabeth    NJ
# 1998    Male      259 Valley Boulevard        NaN      Camp Hill    PA
# 1999  Female     472 Ocean View Street        NaN      Merrimack    NH
#
#       Zipcode  Latitude  Longitude Per Capita Income - Zipcode  \
# 0       91750     34.15    -117.76                      $29278
# 1       11363     40.76     -73.74                      $37891
# 2       91792     34.02    -117.89                      $22681
# 3       10069     40.71     -73.99                     $163145
# 4       94117     37.76    -122.44                      $53797
# ...       ...       ...        ...                         ...
# 1995    11520     40.65     -73.58                      $23550
# 1996    41051     38.95     -84.54                      $24218
# 1997     7201     40.66     -74.19                      $15175
# 1998    17011     40.24     -76.92                      $25336
# 1999     3054     42.86     -71.48                      $32325
#
#      Yearly Income - Person Total Debt  FICO Score  Num Credit Cards
# 0                    $59696    $127613         787                 5
# 1                    $77254    $191349         701                 5
# 2                    $33483       $196         698                 5
# 3                   $249925    $202328         722                 4
# 4                   $109687    $183855         675                 1
# ...                     ...        ...         ...               ...
# 1995                 $48010     $87837         703                 3
# 1996                 $49378    $104480         740                 4
# 1997                 $30942     $71066         779                 3
# 1998                 $54654     $27241         618                 1
# 1999                 $65909    $181261         673                 2
#
# [2000 rows x 18 columns]

# %%
contracts_df = pd.read_csv('contracts_2022-12-30 2.csv', low_memory=False)

# %%
contracts_df
# Out:
#        Reporting Date           EAD      PD12      PDLT       LGD  \
# 0            12/30/22  69795.693590  0.057123  0.024117  0.607348
# 1            12/30/22  24045.796250  0.056460  0.021793  0.613929
# 2            12/30/22   2019.251356  0.017708  0.017708  0.607348
# 3            12/30/22  20563.067570  0.034836  0.154493  0.613929
# 4            12/30/22   2666.804003  0.017043  0.017043  0.613929
# ...               ...           ...       ...       ...       ...
# 336393       12/30/22    460.992072  0.041017  0.041017  0.322573
# 336394       12/30/22    116.777909  0.041017  0.041017  0.322573
# 336395       12/30/22   2461.296310  0.013934  0.063931  0.497079
# 336396       12/30/22  41522.000000  0.019270  0.038064  0.607348
# 336397       12/30/22  41031.000000  0.020043  0.038103  0.613929
#
#        Maturity Date  Residual Maturity Bucketed Arrears  Reporting Index  \
# 0            11/5/32               3597                0                2
# 1            12/5/32               3598                0                0
# 2            8/10/23                460                0              113
# 3            8/15/31               3152                0               17
# 4            5/15/24                504                0               20
# ...              ...                ...              ...              ...
# 336393      10/15/23                290           91-180               50
# 336394       6/28/23                181                0               47
# 336395        4/9/26               1168                0               44
# 336396       1/15/25                746                0               11
# 336397       1/15/25                746                0               11
#
#         Is New Contract Client ID  FICO FICO Segment LTV Segment  \
# 0                 False  9XFALYXL   300      300-410     81%-90%
# 1                  True  KHAAK99A   300      300-410        >30%
# 2                 False  AZHHTHYX   300      300-410        >30%
# 3                 False  YZAZKX99   300      300-410        >30%
# 4                 False  AZLKF9YH   300      300-410     30%-50%
# ...                 ...       ...   ...          ...         ...
# 336393            False    BN9JJQ   850      741-850     71%-80%
# 336394            False     NSJJQ   850      741-850        >30%
# 336395            False    BJGBJ9   850      741-850     81%-90%
# 336396            False  122O9E2E   850      741-850     71%-80%
# 336397            False  12242K11   850      741-850        >30%
#
#        Macro Economic Scenario   Entity
# 0                         Base    Paris
# 1                         Base    Paris
# 2                         Base    Paris
# 3                         Base    Paris
# 4                         Base    Paris
# ...                        ...      ...
# 336393                    Base  NewYork
# 336394                    Base  NewYork
# 336395                    Base  NewYork
# 336396                    Base  NewYork
# 336397                    Base  NewYork
#
# [336398 rows x 16 columns]

# %%
groupby_contracts_df = contracts_df.groupby(['FICO']).mean(['EAD'])
groupby_contracts_df.reset_index()
# Out:
#      FICO          EAD      PD12      PDLT       LGD  Residual Maturity  \
# 0     300  8980.553229  0.104477  0.155930  0.604633        1787.578864
# 1     301  9349.136091  0.112370  0.163001  0.605998        1786.359551
# 2     302  8508.016229  0.100375  0.148074  0.602229        1739.838710
# 3     303  7804.911004  0.091073  0.137547  0.598811        1727.121685
# 4     304  8688.726128  0.103132  0.154085  0.604463        1741.822476
# ..    ...          ...       ...       ...       ...                ...
# 546   846  9125.236908  0.094646  0.143602  0.600449        1820.182566
# 547   847  8643.170678  0.103138  0.149518  0.605348        1697.993681
# 548   848  7772.732491  0.097820  0.148221  0.606113        1737.099130
# 549   849  7968.876954  0.104263  0.151679  0.607293        1769.934084
# 550   850  9627.143318  0.107191  0.156488  0.602894        1759.222910
#
#      Reporting Index  Is New Contract
# 0          26.446372         0.015773
# 1          26.280899         0.028892
# 2          27.416129         0.030645
# 3          26.806552         0.031201
# 4          28.037459         0.027687
# ..               ...              ...
# 546        27.258224         0.023026
# 547        27.949447         0.018957
# 548        27.521739         0.020870
# 549        26.741158         0.030547
# 550        26.934985         0.030960
#
# [551 rows x 8 columns]

# %%
df3 = pd.merge(users_df, groupby_contracts_df, left_on='FICO Score', right_on='FICO')

# %%
df3
# Out:
#                 Person  Current Age  Retirement Age  Birth Year  Birth Month  \
# 0       Hazel Robinson           53              66        1966           11
# 1       Nickolas Lopez           21              67        1999            2
# 2     Kallie Rodriguez           39              71        1980            7
# 3      Rylan Rodriguez           33              69        1986           10
# 4           Sasha Sadr           53              68        1966           12
# ...                ...          ...             ...         ...          ...
# 1995  Alessandro Davis           37              66        1982           12
# 1996     Darren Turner           31              63        1988            5
# 1997      August Braun           42              72        1977            8
# 1998    Kyng El-Mafouk           51              68        1968           10
# 1999  Janelle Campbell           30              64        1989            8
#
#       Gender                      Address  Apartment              City State  \
# 0     Female                462 Rose Lane        NaN          La Verne    CA
# 1       Male            92196 Tenth Drive        NaN          Leesburg    VA
# 2     Female        135 Littlewood Avenue        6.0         Oceanside    CA
# 3     Female           928 Bayview Street        NaN           Portage    WI
# 4     Female       3606 Federal Boulevard        NaN       Little Neck    NY
# ...      ...                          ...        ...               ...   ...
# 1995    Male            550 Forest Street        NaN            Helena    MT
# 1996    Male             6692 Lake Street        NaN      Taylorsville    KY
# 1997    Male                 331 Oak Lane        NaN           Antioch    CA
# 1998    Male        207 Ocean View Street        NaN  Berkeley Heights    NJ
# 1999  Female  847 Martin Luther King Lane       97.0          Ray City    GA
#
#       ...  Total Debt  FICO Score  Num Credit Cards          EAD      PD12  \
# 0     ...     $127613         787                 5  7543.452009  0.102502
# 1     ...      $85204         787                 2  7543.452009  0.102502
# 2     ...      $91549         787                 1  7543.452009  0.102502
# 3     ...          $0         787                 3  7543.452009  0.102502
# 4     ...     $191349         701                 5  8943.997200  0.105292
# ...   ...         ...         ...               ...          ...       ...
# 1995  ...      $71180         580                 1  8195.670961  0.103159
# 1996  ...      $53853         514                 1  8681.589080  0.123131
# 1997  ...      $99235         563                 2  9434.481972  0.097110
# 1998  ...     $242379         505                 1  8936.491473  0.101380
# 1999  ...      $33332         501                 2  8529.125961  0.097007
#
#           PDLT       LGD  Residual Maturity  Reporting Index  Is New Contract
# 0     0.148166  0.608904        1664.486322        28.908815         0.024316
# 1     0.148166  0.608904        1664.486322        28.908815         0.024316
# 2     0.148166  0.608904        1664.486322        28.908815         0.024316
# 3     0.148166  0.608904        1664.486322        28.908815         0.024316
# 4     0.150311  0.602701        1747.076299        26.618506         0.038961
# ...        ...       ...                ...              ...              ...
# 1995  0.150773  0.607600        1747.212670        26.556561         0.024133
# 1996  0.171764  0.611464        1825.388976        27.366929         0.020472
# 1997  0.143415  0.605630        1780.612245        26.211931         0.032967
# 1998  0.149277  0.602884        1747.658249        26.885522         0.040404
# 1999  0.142145  0.607841        1749.551938        25.522481         0.035659
#
# [2000 rows x 25 columns]

# %%
df3.columns
# Out:
# Index(['Person', 'Current Age', 'Retirement Age', 'Birth Year', 'Birth Month',
#        'Gender', 'Address', 'Apartment', 'City', 'State', 'Zipcode',
#        'Latitude', 'Longitude', 'Per Capita Income - Zipcode',
#        'Yearly Income - Person', 'Total Debt', 'FICO Score',
#        'Num Credit Cards', 'EAD', 'PD12', 'PDLT', 'LGD', 'Residual Maturity',
#        'Reporting Index', 'Is New Contract'],
#       dtype='object')

# %%
df3.drop(columns=['Residual Maturity', 'Reporting Index', 'Is New Contract'], inplace=True)

# %%
df3.to_csv("processed_data/sd254_users_processed.csv", index=False)

# %% [markdown]
# ## Modify Merchant Names to be MerchantN e.g. (Merchant1, Merchant2, etc.)

# %%
cc_sales_gzip_df = pd.read_csv("credit_card_transactions_ibm.csv.gz", compression="gzip",)
cc_sales_gzip_df
# Out:
#           User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0            0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1            0     0  2002      9    1  06:42   $38.48  Swipe Transaction
# 2            0     0  2002      9    2  06:22  $120.34  Swipe Transaction
# 3            0     0  2002      9    2  17:45  $128.95  Swipe Transaction
# 4            0     0  2002      9    3  06:23  $104.71  Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...      ...                ...
# 24386895  1999     1  2020      2   27  22:23  $-54.00   Chip Transaction
# 24386896  1999     1  2020      2   27  22:24   $54.00   Chip Transaction
# 24386897  1999     1  2020      2   28  07:43   $59.15   Chip Transaction
# 24386898  1999     1  2020      2   28  20:10   $43.12   Chip Transaction
# 24386899  1999     1  2020      2   28  23:10   $45.13   Chip Transaction
#
#                 Merchant Name  Merchant City Merchant State      Zip   MCC  \
# 0         3527213246127876953       La Verne             CA  91750.0  5300
# 1         -727612092139916043  Monterey Park             CA  91754.0  5411
# 2         -727612092139916043  Monterey Park             CA  91754.0  5411
# 3         3414527459579106770  Monterey Park             CA  91754.0  5651
# 4         5817218446178736267       La Verne             CA  91750.0  5912
# ...                       ...            ...            ...      ...   ...
# 24386895 -5162038175624867091      Merrimack             NH   3054.0  5541
# 24386896 -5162038175624867091      Merrimack             NH   3054.0  5541
# 24386897  2500998799892805156      Merrimack             NH   3054.0  4121
# 24386898  2500998799892805156      Merrimack             NH   3054.0  4121
# 24386899  4751695835751691036      Merrimack             NH   3054.0  5814
#
#          Errors? Is Fraud?
# 0            NaN        No
# 1            NaN        No
# 2            NaN        No
# 3            NaN        No
# 4            NaN        No
# ...          ...       ...
# 24386895     NaN        No
# 24386896     NaN        No
# 24386897     NaN        No
# 24386898     NaN        No
# 24386899     NaN        No
#
# [24386900 rows x 15 columns]

# %%
merchant_name_df = pd.DataFrame(cc_sales_gzip_df.groupby('Merchant Name').count().index.tolist(), columns=['Merchant Name'])

# %%
merchant_name_df.insert(1, 'Merchant Name (Revised)', "")

# %%
merchant_name_df
# Out:
#               Merchant Name Merchant Name (Revised)
# 0      -9222899435637403521
# 1      -9222692221935167526
# 2      -9222439367252190791
# 3      -9222264855000293132
# 4      -9222232253446715869
# ...                     ...                     ...
# 100338  9222821118491815331
# 100339  9222874644865944349
# 100340  9222877122873253163
# 100341  9222957302638210593
# 100342  9223291803303717674
#
# [100343 rows x 2 columns]

# %%
counter = 1

for index, row in merchant_name_df.iterrows():
    name = f"Merchant {counter}"
    merchant_name_df.loc[index, 'Merchant Name (Revised)'] = name
    counter+=1

# %%
merchant_name_df
# Out:
#               Merchant Name Merchant Name (Revised)
# 0      -9222899435637403521              Merchant 1
# 1      -9222692221935167526              Merchant 2
# 2      -9222439367252190791              Merchant 3
# 3      -9222264855000293132              Merchant 4
# 4      -9222232253446715869              Merchant 5
# ...                     ...                     ...
# 100338  9222821118491815331         Merchant 100339
# 100339  9222874644865944349         Merchant 100340
# 100340  9222877122873253163         Merchant 100341
# 100341  9222957302638210593         Merchant 100342
# 100342  9223291803303717674         Merchant 100343
#
# [100343 rows x 2 columns]

# %%
merchant_name_merge_df = pd.merge(cc_sales_gzip_df, merchant_name_df, left_on='Merchant Name', right_on='Merchant Name')
merchant_name_merge_df
# Out:
#           User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0            0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1            0     0  2002      9   10  06:22  $102.18  Swipe Transaction
# 2            0     0  2002      9   16  06:00  $115.34  Swipe Transaction
# 3            0     0  2002      9   18  06:19  $128.85  Swipe Transaction
# 4            0     0  2002      9   23  06:01  $134.89  Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...      ...                ...
# 24386895  1999     1  2019     12   21  07:59   $42.80   Chip Transaction
# 24386896  1999     1  2019     12   22  08:15   $46.72   Chip Transaction
# 24386897  1999     1  2019     12   22  20:25   $46.30   Chip Transaction
# 24386898  1999     1  2019     12   23  19:48   $49.00   Chip Transaction
# 24386899  1999     1  2019     12   24  07:50   $48.02   Chip Transaction
#
#                 Merchant Name Merchant City Merchant State      Zip   MCC  \
# 0         3527213246127876953      La Verne             CA  91750.0  5300
# 1         3527213246127876953      La Verne             CA  91750.0  5300
# 2         3527213246127876953      La Verne             CA  91750.0  5300
# 3         3527213246127876953      La Verne             CA  91750.0  5300
# 4         3527213246127876953      La Verne             CA  91750.0  5300
# ...                       ...           ...            ...      ...   ...
# 24386895 -3533580464561517260  Russellville             AL  35653.0  4121
# 24386896 -3533580464561517260  Russellville             AL  35653.0  4121
# 24386897 -3533580464561517260  Russellville             AL  35653.0  4121
# 24386898 -3533580464561517260  Russellville             AL  35653.0  4121
# 24386899 -3533580464561517260  Russellville             AL  35653.0  4121
#
#          Errors? Is Fraud? Merchant Name (Revised)
# 0            NaN        No          Merchant 69375
# 1            NaN        No          Merchant 69375
# 2            NaN        No          Merchant 69375
# 3            NaN        No          Merchant 69375
# 4            NaN        No          Merchant 69375
# ...          ...       ...                     ...
# 24386895     NaN        No          Merchant 31143
# 24386896     NaN        No          Merchant 31143
# 24386897     NaN        No          Merchant 31143
# 24386898     NaN        No          Merchant 31143
# 24386899     NaN        No          Merchant 31143
#
# [24386900 rows x 16 columns]

# %%
merchant_name_merge_df.pop('Merchant Name')
merchant_name_merge_df.rename(columns={"Merchant Name (Revised)": "Merchant Name"}, inplace=True)
merchant_name_merge_df
# Out:
#           User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0            0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1            0     0  2002      9   10  06:22  $102.18  Swipe Transaction
# 2            0     0  2002      9   16  06:00  $115.34  Swipe Transaction
# 3            0     0  2002      9   18  06:19  $128.85  Swipe Transaction
# 4            0     0  2002      9   23  06:01  $134.89  Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...      ...                ...
# 24386895  1999     1  2019     12   21  07:59   $42.80   Chip Transaction
# 24386896  1999     1  2019     12   22  08:15   $46.72   Chip Transaction
# 24386897  1999     1  2019     12   22  20:25   $46.30   Chip Transaction
# 24386898  1999     1  2019     12   23  19:48   $49.00   Chip Transaction
# 24386899  1999     1  2019     12   24  07:50   $48.02   Chip Transaction
#
#          Merchant City Merchant State      Zip   MCC Errors? Is Fraud?  \
# 0             La Verne             CA  91750.0  5300     NaN        No
# 1             La Verne             CA  91750.0  5300     NaN        No
# 2             La Verne             CA  91750.0  5300     NaN        No
# 3             La Verne             CA  91750.0  5300     NaN        No
# 4             La Verne             CA  91750.0  5300     NaN        No
# ...                ...            ...      ...   ...     ...       ...
# 24386895  Russellville             AL  35653.0  4121     NaN        No
# 24386896  Russellville             AL  35653.0  4121     NaN        No
# 24386897  Russellville             AL  35653.0  4121     NaN        No
# 24386898  Russellville             AL  35653.0  4121     NaN        No
# 24386899  Russellville             AL  35653.0  4121     NaN        No
#
#            Merchant Name
# 0         Merchant 69375
# 1         Merchant 69375
# 2         Merchant 69375
# 3         Merchant 69375
# 4         Merchant 69375
# ...                  ...
# 24386895  Merchant 31143
# 24386896  Merchant 31143
# 24386897  Merchant 31143
# 24386898  Merchant 31143
# 24386899  Merchant 31143
#
# [24386900 rows x 15 columns]

# %%
merchant_name_merge_df_revised = merchant_name_merge_df[['User',
 'Card',
 'Year',
 'Month',
 'Day',
 'Time',
 'Amount',
 'Use Chip',
 'Merchant Name',
 'Merchant City',
 'Merchant State',
 'Zip',
 'MCC',
 'Errors?',
 'Is Fraud?']]

# %%
merchant_name_merge_df_revised
# Out:
#           User  Card  Year  Month  Day   Time   Amount           Use Chip  \
# 0            0     0  2002      9    1  06:21  $134.09  Swipe Transaction
# 1            0     0  2002      9   10  06:22  $102.18  Swipe Transaction
# 2            0     0  2002      9   16  06:00  $115.34  Swipe Transaction
# 3            0     0  2002      9   18  06:19  $128.85  Swipe Transaction
# 4            0     0  2002      9   23  06:01  $134.89  Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...      ...                ...
# 24386895  1999     1  2019     12   21  07:59   $42.80   Chip Transaction
# 24386896  1999     1  2019     12   22  08:15   $46.72   Chip Transaction
# 24386897  1999     1  2019     12   22  20:25   $46.30   Chip Transaction
# 24386898  1999     1  2019     12   23  19:48   $49.00   Chip Transaction
# 24386899  1999     1  2019     12   24  07:50   $48.02   Chip Transaction
#
#            Merchant Name Merchant City Merchant State      Zip   MCC Errors?  \
# 0         Merchant 69375      La Verne             CA  91750.0  5300     NaN
# 1         Merchant 69375      La Verne             CA  91750.0  5300     NaN
# 2         Merchant 69375      La Verne             CA  91750.0  5300     NaN
# 3         Merchant 69375      La Verne             CA  91750.0  5300     NaN
# 4         Merchant 69375      La Verne             CA  91750.0  5300     NaN
# ...                  ...           ...            ...      ...   ...     ...
# 24386895  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386896  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386897  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386898  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386899  Merchant 31143  Russellville             AL  35653.0  4121     NaN
#
#          Is Fraud?
# 0               No
# 1               No
# 2               No
# 3               No
# 4               No
# ...            ...
# 24386895        No
# 24386896        No
# 24386897        No
# 24386898        No
# 24386899        No
#
# [24386900 rows x 15 columns]

# %%
# Cast intended measures as numerical data types
merchant_name_merge_df_revised['Amount'] = merchant_name_merge_df_revised['Amount'].str.replace('$', '')
merchant_name_merge_df_revised['Amount'] = merchant_name_merge_df_revised['Amount'].astype(float)
merchant_name_merge_df_revised['Amount'] = merchant_name_merge_df_revised['Amount'] * .20

# %%
merchant_name_merge_df_5MM = merchant_name_merge_df_revised[19386900:]
merchant_name_merge_df_10MM = merchant_name_merge_df_revised[14386900:]

# %%
merchant_name_merge_df_5MM.to_csv('processed_data/credit_card_transactions_ibm_processed_5MM.csv', index=False)
merchant_name_merge_df_10MM.to_csv('processed_data/credit_card_transactions_ibm_processed_10MM.csv', index=False)

# %%
# !gzip processed_data/credit_card_transactions_ibm_processed_5MM.csv

# %%
# !gzip processed_data/credit_card_transactions_ibm_processed_10MM.csv

# %%
# !rm -rf processed_data/credit_card_transactions_ibm_processed_5MM.csv processed_data/credit_card_transactions_ibm_processed_10MM.csv

# %% [markdown]
# ## Analyze Amounts

# %%
merchant_name_merge_df_5MM
# Out:
#           User  Card  Year  Month  Day   Time  Amount           Use Chip  \
# 19386900    50     0  2019      7    4  23:37   4.432   Chip Transaction
# 19386901    50     1  2019      6   28  23:33   3.436   Chip Transaction
# 19386902   792     1  2015     11   28  16:08   1.672   Chip Transaction
# 19386903  1210     1  2007      3    7  22:52   4.076  Swipe Transaction
# 19386904  1575     0  2016      5   23  07:07   2.462  Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...     ...                ...
# 24386895  1999     1  2019     12   21  07:59   8.560   Chip Transaction
# 24386896  1999     1  2019     12   22  08:15   9.344   Chip Transaction
# 24386897  1999     1  2019     12   22  20:25   9.260   Chip Transaction
# 24386898  1999     1  2019     12   23  19:48   9.800   Chip Transaction
# 24386899  1999     1  2019     12   24  07:50   9.604   Chip Transaction
#
#            Merchant Name Merchant City Merchant State      Zip   MCC Errors?  \
# 19386900  Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 19386901  Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 19386902  Merchant 47076       Yonkers             NY  10703.0  5921     NaN
# 19386903  Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 19386904  Merchant 47076    Shreveport             LA  71107.0  5921     NaN
# ...                  ...           ...            ...      ...   ...     ...
# 24386895  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386896  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386897  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386898  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386899  Merchant 31143  Russellville             AL  35653.0  4121     NaN
#
#          Is Fraud?
# 19386900        No
# 19386901        No
# 19386902        No
# 19386903        No
# 19386904        No
# ...            ...
# 24386895        No
# 24386896        No
# 24386897        No
# 24386898        No
# 24386899        No
#
# [5000000 rows x 15 columns]

# %%
dfupdate=merchant_name_merge_df_5MM.sample(1000000)
dfupdate.Amount *= -1
merchant_name_merge_df_5MM.update(dfupdate)

# %%
merchant_name_merge_df_5MM
# Out:
#           User  Card  Year  Month  Day   Time  Amount           Use Chip  \
# 19386900    50     0  2019      7    4  23:37   4.432   Chip Transaction
# 19386901    50     1  2019      6   28  23:33  -3.436   Chip Transaction
# 19386902   792     1  2015     11   28  16:08  -1.672   Chip Transaction
# 19386903  1210     1  2007      3    7  22:52   4.076  Swipe Transaction
# 19386904  1575     0  2016      5   23  07:07   2.462  Swipe Transaction
# ...        ...   ...   ...    ...  ...    ...     ...                ...
# 24386895  1999     1  2019     12   21  07:59   8.560   Chip Transaction
# 24386896  1999     1  2019     12   22  08:15   9.344   Chip Transaction
# 24386897  1999     1  2019     12   22  20:25   9.260   Chip Transaction
# 24386898  1999     1  2019     12   23  19:48  -9.800   Chip Transaction
# 24386899  1999     1  2019     12   24  07:50   9.604   Chip Transaction
#
#            Merchant Name Merchant City Merchant State      Zip   MCC Errors?  \
# 19386900  Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 19386901  Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 19386902  Merchant 47076       Yonkers             NY  10703.0  5921     NaN
# 19386903  Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 19386904  Merchant 47076    Shreveport             LA  71107.0  5921     NaN
# ...                  ...           ...            ...      ...   ...     ...
# 24386895  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386896  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386897  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386898  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 24386899  Merchant 31143  Russellville             AL  35653.0  4121     NaN
#
#          Is Fraud?
# 19386900        No
# 19386901        No
# 19386902        No
# 19386903        No
# 19386904        No
# ...            ...
# 24386895        No
# 24386896        No
# 24386897        No
# 24386898        No
# 24386899        No
#
# [5000000 rows x 15 columns]

# %%
merchant_name_merge_df_5MM.to_csv('processed_data/credit_card_transactions_ibm_processed_5MM.csv', index=False)

# %%
# !gzip processed_data/credit_card_transactions_ibm_processed_5MM.csv
