# %% [markdown]
# # Credit Card Analysis

# %% [markdown]
# ## Import Libraries

# %%
import atoti as tt
import pandas as pd
import time
from pprint import pprint
from script import *
import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

# %% [markdown]
# ## Load Data Into Pandas DataFrame from CSV

# %%
# Load credit card transaction data
# cc_sales_gzip_df = pd.read_csv("credit_card_transactions_ibm.csv.gz", compression="gzip",)
cc_sales_gzip_df = pd.read_csv(
    "credit_card_transactions_5MM.csv.gz",
    compression="gzip",
)
cc_sales_gzip_df
# Out:
#          User  Card  Year  Month  Day   Time  Amount           Use Chip  \
# 0          50     0  2019      7    4  23:37   4.432   Chip Transaction
# 1          50     1  2019      6   28  23:33  -3.436   Chip Transaction
# 2         792     1  2015     11   28  16:08  -1.672   Chip Transaction
# 3        1210     1  2007      3    7  22:52   4.076  Swipe Transaction
# 4        1575     0  2016      5   23  07:07   2.462  Swipe Transaction
# ...       ...   ...   ...    ...  ...    ...     ...                ...
# 4999995  1999     1  2019     12   21  07:59   8.560   Chip Transaction
# 4999996  1999     1  2019     12   22  08:15   9.344   Chip Transaction
# 4999997  1999     1  2019     12   22  20:25   9.260   Chip Transaction
# 4999998  1999     1  2019     12   23  19:48  -9.800   Chip Transaction
# 4999999  1999     1  2019     12   24  07:50   9.604   Chip Transaction
#
#           Merchant Name Merchant City Merchant State      Zip   MCC Errors?  \
# 0        Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 1        Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 2        Merchant 47076       Yonkers             NY  10703.0  5921     NaN
# 3        Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 4        Merchant 47076    Shreveport             LA  71107.0  5921     NaN
# ...                 ...           ...            ...      ...   ...     ...
# 4999995  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 4999996  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 4999997  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 4999998  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 4999999  Merchant 31143  Russellville             AL  35653.0  4121     NaN
#
#         Is Fraud?
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No
# ...           ...
# 4999995        No
# 4999996        No
# 4999997        No
# 4999998        No
# 4999999        No
#
# [5000000 rows x 15 columns]

# %%
# Load issued credit card data
user_cc_df = pd.read_csv("sd254_cards_processed.csv", index_col=0)
user_cc_df
# Out:
#       User  CARD INDEX  Retailer ID       Card Number  Expires  CVV Has Chip  \
# 0        0           0           24  4344676511950444  12/2022  623      YES
# 1        0           1           25  4956965974959986  12/2020  393      YES
# 2        0           2           26  4582313478255491  02/2024  719      YES
# 3        0           3           20  4879494103069057  08/2024  693       NO
# 4        0           4           17  5722874738736011  03/2009   75      YES
# ...    ...         ...          ...               ...      ...  ...      ...
# 6141  1997           1            1   300609782832003  01/2024  663      YES
# 6142  1997           2           20  4718517475996018  01/2021  492      YES
# 6143  1998           0            7  5929512204765914  08/2020  237       NO
# 6144  1999           0           11  5589768928167462  01/2020  630      YES
# 6145  1999           1           20  4994011318343994  12/2020  120      YES
#
#       Cards Issued Credit Limit Acct Open Date  Year PIN last Changed  \
# 0                2       $24295        09/2002                   2008
# 1                2       $21968        04/2014                   2014
# 2                2       $46414        07/2003                   2004
# 3                1       $12400        01/2003                   2012
# 4                1          $28        09/2008                   2009
# ...            ...          ...            ...                    ...
# 6141             1        $6900        11/2000                   2013
# 6142             2        $5700        04/2012                   2012
# 6143             2        $9200        02/2012                   2012
# 6144             1       $28074        01/2020                   2020
# 6145             1       $14400        05/2017                   2017
#
#      Card on Dark Web
# 0                  No
# 1                  No
# 2                  No
# 3                  No
# 4                  No
# ...               ...
# 6141               No
# 6142               No
# 6143               No
# 6144               No
# 6145               No
#
# [6146 rows x 12 columns]

# %%
user_cc_df
# Out:
#       User  CARD INDEX  Retailer ID       Card Number  Expires  CVV Has Chip  \
# 0        0           0           24  4344676511950444  12/2022  623      YES
# 1        0           1           25  4956965974959986  12/2020  393      YES
# 2        0           2           26  4582313478255491  02/2024  719      YES
# 3        0           3           20  4879494103069057  08/2024  693       NO
# 4        0           4           17  5722874738736011  03/2009   75      YES
# ...    ...         ...          ...               ...      ...  ...      ...
# 6141  1997           1            1   300609782832003  01/2024  663      YES
# 6142  1997           2           20  4718517475996018  01/2021  492      YES
# 6143  1998           0            7  5929512204765914  08/2020  237       NO
# 6144  1999           0           11  5589768928167462  01/2020  630      YES
# 6145  1999           1           20  4994011318343994  12/2020  120      YES
#
#       Cards Issued Credit Limit Acct Open Date  Year PIN last Changed  \
# 0                2       $24295        09/2002                   2008
# 1                2       $21968        04/2014                   2014
# 2                2       $46414        07/2003                   2004
# 3                1       $12400        01/2003                   2012
# 4                1          $28        09/2008                   2009
# ...            ...          ...            ...                    ...
# 6141             1        $6900        11/2000                   2013
# 6142             2        $5700        04/2012                   2012
# 6143             2        $9200        02/2012                   2012
# 6144             1       $28074        01/2020                   2020
# 6145             1       $14400        05/2017                   2017
#
#      Card on Dark Web
# 0                  No
# 1                  No
# 2                  No
# 3                  No
# 4                  No
# ...               ...
# 6141               No
# 6142               No
# 6143               No
# 6144               No
# 6145               No
#
# [6146 rows x 12 columns]

# %%
# Load user data
# users_df = pd.read_csv("s3://data.atoti.io/notebooks/retail-banking/sd254_users_processed.csv")
users_df = pd.read_csv("users_processed.csv")
# users_df = users_df.rename_axis("User").reset_index()
users_df
# Out:
#       User            Person  Current Age  Age Range  Retirement Age  \
# 0        0    Hazel Robinson           53         60              66
# 1        1    Nickolas Lopez           21         30              67
# 2        2  Kallie Rodriguez           39         40              71
# 3        3   Rylan Rodriguez           33         40              69
# 4        4        Sasha Sadr           53         60              68
# ...    ...               ...          ...        ...             ...
# 1995  1995  Alessandro Davis           37         40              66
# 1996  1996     Darren Turner           31         40              63
# 1997  1997      August Braun           42         50              72
# 1998  1998    Kyng El-Mafouk           51         60              68
# 1999  1999  Janelle Campbell           30         30              64
#
#       Birth Year  Birth Month  Gender                      Address  Apartment  \
# 0           1966           11  Female                462 Rose Lane        NaN
# 1           1999            2    Male            92196 Tenth Drive        NaN
# 2           1980            7  Female        135 Littlewood Avenue        6.0
# 3           1986           10  Female           928 Bayview Street        NaN
# 4           1966           12  Female       3606 Federal Boulevard        NaN
# ...          ...          ...     ...                          ...        ...
# 1995        1982           12    Male            550 Forest Street        NaN
# 1996        1988            5    Male             6692 Lake Street        NaN
# 1997        1977            8    Male                 331 Oak Lane        NaN
# 1998        1968           10    Male        207 Ocean View Street        NaN
# 1999        1989            8  Female  847 Martin Luther King Lane       97.0
#
#       ... Longitude Per Capita Income - Zipcode  Yearly Income - Person  \
# 0     ...   -117.76                       29278                   59696
# 1     ...    -77.55                       44196                   90104
# 2     ...   -117.29                       22050                   44958
# 3     ...    -89.46                       19635                   40029
# 4     ...    -73.74                       37891                   77254
# ...   ...       ...                         ...                     ...
# 1995  ...   -112.12                       20305                   41401
# 1996  ...    -85.34                       21444                   43724
# 1997  ...   -121.76                       28733                   58584
# 1998  ...    -74.42                       53790                  109673
# 1999  ...    -83.19                       13238                   26996
#
#       Income Range  Total Debt  FICO Score          EAD      PD12      PDLT  \
# 0        50K - 80K      127613         787  7543.452009  0.102502  0.148166
# 1       80K - 100K       85204         787  7543.452009  0.102502  0.148166
# 2        20K - 50K       91549         787  7543.452009  0.102502  0.148166
# 3        20K - 50K           0         787  7543.452009  0.102502  0.148166
# 4        50K - 80K      191349         701  8943.997200  0.105292  0.150311
# ...            ...         ...         ...          ...       ...       ...
# 1995     20K - 50K       71180         580  8195.670961  0.103159  0.150773
# 1996     20K - 50K       53853         514  8681.589080  0.123131  0.171764
# 1997     50K - 80K       99235         563  9434.481972  0.097110  0.143415
# 1998   100K - 150K      242379         505  8936.491473  0.101380  0.149277
# 1999     20K - 50K       33332         501  8529.125961  0.097007  0.142145
#
#            LGD
# 0     0.608904
# 1     0.608904
# 2     0.608904
# 3     0.608904
# 4     0.602701
# ...        ...
# 1995  0.607600
# 1996  0.611464
# 1997  0.605630
# 1998  0.602884
# 1999  0.607841
#
# [2000 rows x 24 columns]

# %%
# Load retailer data
# cc_info_df = pd.read_csv("s3://data.atoti.io/notebooks/retail-banking/cc_info.csv")
cc_info_df = pd.read_csv("Retailers.csv")
# cc_info_df

# %%
cc_info_df
# Out:
#     Retailer ID         Retailer Name  Card Brand Card Type   Level 1  \
# 0             1              Upromise  Mastercard    Credit  Barclays
# 1             2                  AARP  Mastercard    Credit  Barclays
# 2             3       Barnes & Nobele  Mastercard    Credit  Barclays
# 3             4               Athleta  Mastercard    Credit  Barclays
# 4             5       Banana Republic  Mastercard    Credit  Barclays
# 5             6                   GAP  Mastercard    Credit  Barclays
# 6             7              Old Navy  Mastercard    Credit  Barclays
# 7             8     American Airlines  Mastercard    Credit  Barclays
# 8             9     Emirates Airlines  Mastercard    Credit  Barclays
# 9            10     Frontier Airlines  Mastercard    Credit  Barclays
# 10           11     Hawaiian Airlines  Mastercard    Credit  Barclays
# 11           12               JetBlue  Mastercard    Credit  Barclays
# 12           13    Lufthansa Airlines  Mastercard    Credit  Barclays
# 13           14      Carnival Cruises  Mastercard    Credit  Barclays
# 14           15  Holland America Line        Visa    Credit  Barclays
# 15           16      Princess Cruises        Visa    Credit  Barclays
# 16           17           RCI Cruises  Mastercard    Credit  Barclays
# 17           18               Wyndham  Mastercard    Credit  Barclays
# 18           19              Barclays  Mastercard    Credit  Barclays
# 19           20                Costco        Visa    Credit  Barclays
# 20           21               Walmart        Visa    Credit  Barclays
# 21           22                PayPal  Mastercard    Credit  Barclays
# 22           23                 Venmo  Mastercard    Credit  Barclays
# 23           24                 Zelle  Mastercard    Credit  Barclays
# 24           25                Hilton  Mastercard    Credit  Barclays
# 25           26                Airbnb  Mastercard    Credit  Barclays
# 26           27          TWA Airlines  Mastercard    Credit  Barclays
# 27           28              Bulk Buy        Visa    Credit  Barclays
# 28           29                 Jcrew  Mastercard    Credit  Barclays
# 29           30            Gold Hotel  Mastercard    Credit  Barclays
#
#              Level 2         Level 3     Level 4                 Level 5  \
# 0   Consumer Banking  Cards Business   Nonprofit               Education
# 1   Consumer Banking  Cards Business   Nonprofit             Health Care
# 2   Consumer Banking  Cards Business      Retail  Consumer Discretionary
# 3   Consumer Banking  Cards Business      Retail  Consumer Discretionary
# 4   Consumer Banking  Cards Business      Retail  Consumer Discretionary
# 5   Consumer Banking  Cards Business      Retail  Consumer Discretionary
# 6   Consumer Banking  Cards Business      Retail  Consumer Discretionary
# 7   Consumer Banking  Cards Business      Travel                 Airline
# 8   Consumer Banking  Cards Business      Travel                 Airline
# 9   Consumer Banking  Cards Business      Travel                 Airline
# 10  Consumer Banking  Cards Business      Travel                 Airline
# 11  Consumer Banking  Cards Business      Travel                 Airline
# 12  Consumer Banking  Cards Business      Travel                 Airline
# 13  Consumer Banking  Cards Business      Travel                  Cruise
# 14  Consumer Banking  Cards Business      Travel                  Cruise
# 15  Consumer Banking  Cards Business      Travel                  Cruise
# 16  Consumer Banking  Cards Business      Travel                  Cruise
# 17  Consumer Banking  Cards Business      Travel                   Hotel
# 18  Consumer Banking  Cards Business  Financials         Cards & Banking
# 19  Consumer Banking  Cards Business      Retail        Consumer Staples
# 20  Consumer Banking  Cards Business      Retail        Consumer Staples
# 21  Consumer Banking  Cards Business  Financials         Cards & Banking
# 22  Consumer Banking  Cards Business  Financials         Cards & Banking
# 23  Consumer Banking  Cards Business  Financials         Cards & Banking
# 24  Consumer Banking  Cards Business      Travel                   Hotel
# 25  Consumer Banking  Cards Business      Travel                   Hotel
# 26  Consumer Banking  Cards Business      Travel                 Airline
# 27  Consumer Banking  Cards Business      Retail        Consumer Staples
# 28  Consumer Banking  Cards Business      Retail  Consumer Discretionary
# 29  Consumer Banking  Cards Business      Travel                   Hotel
#
#             Industry
# 0          Education
# 1        Health Care
# 2              Books
# 3            Fashion
# 4            Fashion
# 5            Fashion
# 6            Fashion
# 7            Airline
# 8            Airline
# 9            Airline
# 10           Airline
# 11           Airline
# 12           Airline
# 13            Cruise
# 14            Cruise
# 15            Cruise
# 16            Cruise
# 17             Hotel
# 18   Cards & Banking
# 19  Consumer Staples
# 20  Consumer Staples
# 21   Cards & Banking
# 22   Cards & Banking
# 23   Cards & Banking
# 24             Hotel
# 25             Hotel
# 26           Airline
# 27  Consumer Staples
# 28           Fashion
# 29             Hotel

# %%
cc_sales_gzip_df.dtypes
# Out:
# User                int64
# Card                int64
# Year                int64
# Month               int64
# Day                 int64
# Time               object
# Amount            float64
# Use Chip           object
# Merchant Name      object
# Merchant City      object
# Merchant State     object
# Zip               float64
# MCC                 int64
# Errors?            object
# Is Fraud?          object
# dtype: object

# %% [markdown]
# ## Format Data

# %%
# Cast intended hierarchies as strings
cc_sales_gzip_df["User"] = cc_sales_gzip_df["User"].astype(str)
cc_sales_gzip_df["Card"] = cc_sales_gzip_df["Card"].astype(str)
cc_sales_gzip_df["Year"] = cc_sales_gzip_df["Year"].astype(str)
cc_sales_gzip_df["Month"] = cc_sales_gzip_df["Month"].astype(str)
cc_sales_gzip_df["Day"] = cc_sales_gzip_df["Day"].astype(str)
cc_sales_gzip_df["Merchant Name"] = cc_sales_gzip_df["Merchant Name"].astype(str)
cc_sales_gzip_df["Zip"] = cc_sales_gzip_df["Zip"].astype(str)
cc_sales_gzip_df["MCC"] = cc_sales_gzip_df["MCC"].astype(str)

# Cast intended measures as numerical data types
# cc_sales_gzip_df['Amount'] = cc_sales_gzip_df['Amount'].str.replace('$', '')
cc_sales_gzip_df["Amount"] = cc_sales_gzip_df["Amount"].astype(float)

# Create a `Datetime` column and combine values
# From Year, Month, Day, and Time columns to
# Create a proper Datetime data type column
cc_sales_gzip_df.insert(2, "Datetime", "")
cc_sales_gzip_df["Datetime"] = pd.to_datetime(
    cc_sales_gzip_df["Year"]
    + " "
    + cc_sales_gzip_df["Month"]
    + " "
    + cc_sales_gzip_df["Day"]
    + " "
    + cc_sales_gzip_df["Time"]
)
cc_sales_gzip_df.drop(columns=["Year", "Month", "Day", "Time"], inplace=True)
cc_sales_gzip_df
# Out:
#          User Card            Datetime  Amount           Use Chip  \
# 0          50    0 2019-07-04 23:37:00   4.432   Chip Transaction
# 1          50    1 2019-06-28 23:33:00  -3.436   Chip Transaction
# 2         792    1 2015-11-28 16:08:00  -1.672   Chip Transaction
# 3        1210    1 2007-03-07 22:52:00   4.076  Swipe Transaction
# 4        1575    0 2016-05-23 07:07:00   2.462  Swipe Transaction
# ...       ...  ...                 ...     ...                ...
# 4999995  1999    1 2019-12-21 07:59:00   8.560   Chip Transaction
# 4999996  1999    1 2019-12-22 08:15:00   9.344   Chip Transaction
# 4999997  1999    1 2019-12-22 20:25:00   9.260   Chip Transaction
# 4999998  1999    1 2019-12-23 19:48:00  -9.800   Chip Transaction
# 4999999  1999    1 2019-12-24 07:50:00   9.604   Chip Transaction
#
#           Merchant Name Merchant City Merchant State      Zip   MCC Errors?  \
# 0        Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 1        Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 2        Merchant 47076       Yonkers             NY  10703.0  5921     NaN
# 3        Merchant 47076     Beaverton             OR  97007.0  5921     NaN
# 4        Merchant 47076    Shreveport             LA  71107.0  5921     NaN
# ...                 ...           ...            ...      ...   ...     ...
# 4999995  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 4999996  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 4999997  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 4999998  Merchant 31143  Russellville             AL  35653.0  4121     NaN
# 4999999  Merchant 31143  Russellville             AL  35653.0  4121     NaN
#
#         Is Fraud?
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No
# ...           ...
# 4999995        No
# 4999996        No
# 4999997        No
# 4999998        No
# 4999999        No
#
# [5000000 rows x 12 columns]

# %%
# Rename `CARD INDEX` column to `Card` to match joined `Card` column from cc_sales_gzip_df
user_cc_df.rename(columns={"CARD INDEX": "Card"}, inplace=True)

# Cast intended hierarchies as strings
user_cc_df["User"] = user_cc_df["User"].astype(str)
user_cc_df["Card"] = user_cc_df["Card"].astype(str)
user_cc_df["Retailer ID"] = user_cc_df["Retailer ID"].astype(str)
user_cc_df["Card Number"] = user_cc_df["Card Number"].astype(str)
user_cc_df["CVV"] = user_cc_df["CVV"].astype(str)

# Cast intended measures as numerical data types
user_cc_df["Credit Limit"] = user_cc_df["Credit Limit"].str.replace("$", "")
user_cc_df["Credit Limit"] = user_cc_df["Credit Limit"].astype(int)
user_cc_df
# Out:
#       User Card Retailer ID       Card Number  Expires  CVV Has Chip  \
# 0        0    0          24  4344676511950444  12/2022  623      YES
# 1        0    1          25  4956965974959986  12/2020  393      YES
# 2        0    2          26  4582313478255491  02/2024  719      YES
# 3        0    3          20  4879494103069057  08/2024  693       NO
# 4        0    4          17  5722874738736011  03/2009   75      YES
# ...    ...  ...         ...               ...      ...  ...      ...
# 6141  1997    1           1   300609782832003  01/2024  663      YES
# 6142  1997    2          20  4718517475996018  01/2021  492      YES
# 6143  1998    0           7  5929512204765914  08/2020  237       NO
# 6144  1999    0          11  5589768928167462  01/2020  630      YES
# 6145  1999    1          20  4994011318343994  12/2020  120      YES
#
#       Cards Issued  Credit Limit Acct Open Date  Year PIN last Changed  \
# 0                2         24295        09/2002                   2008
# 1                2         21968        04/2014                   2014
# 2                2         46414        07/2003                   2004
# 3                1         12400        01/2003                   2012
# 4                1            28        09/2008                   2009
# ...            ...           ...            ...                    ...
# 6141             1          6900        11/2000                   2013
# 6142             2          5700        04/2012                   2012
# 6143             2          9200        02/2012                   2012
# 6144             1         28074        01/2020                   2020
# 6145             1         14400        05/2017                   2017
#
#      Card on Dark Web
# 0                  No
# 1                  No
# 2                  No
# 3                  No
# 4                  No
# ...               ...
# 6141               No
# 6142               No
# 6143               No
# 6144               No
# 6145               No
#
# [6146 rows x 12 columns]

# %%
# Remove $ symbols for currency related numerical values
# users_df['Per Capita Income - Zipcode'] = users_df['Per Capita Income - Zipcode'].str.replace('$', '')
# users_df['Yearly Income - Person'] = users_df['Yearly Income - Person'].str.replace('$', '')
# users_df['Total Debt'] = users_df['Total Debt'].str.replace('$', '')

# Cast intended hierarchies as strings or numerical data types
users_df["User"] = users_df["User"].astype(str)
users_df["Birth Month"] = users_df["Birth Month"].astype(str)
users_df["Zipcode"] = users_df["Zipcode"].astype(str)
users_df["Per Capita Income - Zipcode"] = users_df[
    "Per Capita Income - Zipcode"
].astype(int)
users_df["Yearly Income - Person"] = users_df["Yearly Income - Person"].astype(int)
users_df["Total Debt"] = users_df["Total Debt"].astype(int)
users_df["FICO Score"] = users_df["FICO Score"].astype(str)
users_df["Current Age"] = users_df["Current Age"].astype(str)
users_df["Age Range"] = users_df["Age Range"].astype(str)
users_df["Retirement Age"] = users_df["Retirement Age"].astype(str)
# users_df

# %%
# Cast intended hierarchies as strings
cc_info_df["Retailer ID"] = cc_info_df["Retailer ID"].astype(str)

# %% [markdown]
# ## Instantiate Atoti Server

# %%
# Start an Atoti Server instance
session = tt.Session(
    user_content_storage="./content",
    port=9091,
    java_options=["-Xms1G", "-Xmx15G"],
    app_extensions=tt.ADVANCED_APP_EXTENSION,
)
session.link
# Out:
# http://localhost:9091 (This is the session's local URL: it may not be reachable if Atoti is running on another machine.)

# %% [markdown]
# ## Load Pandas DataFrames as Atoti Table Objects

# %%
# Implied Atoti Table creation using `Session.read_pandas()` function
cc_sales_table = session.read_pandas(
    cc_sales_gzip_df,
    table_name="Sales Transactions",
)

users_table = session.read_pandas(
    users_df,
    table_name="Users",
)

user_cc_table = session.read_pandas(
    user_cc_df,
    # keys=['Card Number'],
    table_name="User Credit Cards",
)

cc_info_table = session.read_pandas(
    cc_info_df,
    table_name="Credit Card Info",
)

fico_table = session.read_csv(
    "FICO.csv",
    #    keys=['FICO Score'],
    types={"FICO Score": tt.type.STRING},
    table_name="FICO",
)

user_loans_table = session.read_csv(
    "loans.csv",
    types={
        "User": tt.type.STRING,
        "Inq Last 6mos": tt.type.STRING,
        "Delinq 2yrs": tt.type.STRING,
        "Public Record": tt.type.STRING,
        "Not Fully Paid": tt.type.STRING,
    },
    table_name="loans",
)

# %% [markdown]
# ## Join Tables

# %%
# Join tables
cc_sales_table.join(
    user_cc_table,
    (cc_sales_table["User"] == user_cc_table["User"])
    & (cc_sales_table["Card"] == user_cc_table["Card"]),
)
cc_sales_table.join(users_table, cc_sales_table["User"] == users_table["User"])
users_table.join(fico_table, users_table["FICO Score"] == fico_table["FICO Score"])
user_cc_table.join(
    cc_info_table, user_cc_table["Retailer ID"] == cc_info_table["Retailer ID"]
)
users_table.join(user_loans_table, users_table["User"] == user_loans_table["User"])

# %%
# Create Cube from Atoti Table object
cube = session.create_cube(cc_sales_table, mode="no_measures")

# %%
# View the schema
session.tables.schema
# Out:
# erDiagram
#   "Sales Transactions" {
#     _ String "User"
#     _ String "Card"
#     _ LocalDateTime "Datetime"
#     nullable double "Amount"
#     _ String "Use Chip"
#     _ String "Merchant Name"
#     _ String "Merchant City"
#     _ String "Merchant State"
#     _ String "Zip"
#     _ String "MCC"
#     _ String "Errors?"
#     _ String "Is Fraud?"
#   }
#   "User Credit Cards" {
#     _ String "User"
#     _ String "Card"
#     _ String "Retailer ID"
#     _ String "Card Number"
#     _ String "Expires"
#     _ String "CVV"
#     _ String "Has Chip"
#     nullable long "Cards Issued"
#     nullable long "Credit Limit"
#     _ String "Acct Open Date"
#     nullable long "Year PIN last Changed"
#     _ String "Card on Dark Web"
#   }
#   "loans" {
#     _ String "User"
#     nullable int "Credit Policty"
#     _ String "Loan Purpose"
#     nullable double "Interest Rate"
#     nullable double "Installment"
#     nullable double "DTI"
#     nullable double "Days with Credit Line"
#     nullable int "Revolving Bal"
#     nullable double "Revol_Util"
#     _ String "Inq Last 6mos"
#     _ String "Delinq 2yrs"
#     _ String "Public Record"
#     _ String "Not Fully Paid"
#   }
#   "Users" {
#     _ String "User"
#     _ String "Person"
#     _ String "Current Age"
#     _ String "Age Range"
#     _ String "Retirement Age"
#     nullable long "Birth Year"
#     _ String "Birth Month"
#     _ String "Gender"
#     _ String "Address"
#     nullable double "Apartment"
#     _ String "City"
#     _ String "State"
#     _ String "Zipcode"
#     nullable double "Latitude"
#     nullable double "Longitude"
#     nullable long "Per Capita Income - Zipcode"
#     nullable long "Yearly Income - Person"
#     _ String "Income Range"
#     nullable long "Total Debt"
#     _ String "FICO Score"
#     nullable double "EAD"
#     nullable double "PD12"
#     nullable double "PDLT"
#     nullable double "LGD"
#   }
#   "Credit Card Info" {
#     _ String "Retailer ID"
#     _ String "Retailer Name"
#     _ String "Card Brand"
#     _ String "Card Type"
#     _ String "Level 1"
#     _ String "Level 2"
#     _ String "Level 3"
#     _ String "Level 4"
#     _ String "Level 5"
#     _ String "Industry"
#   }
#   "FICO" {
#     _ String "FICO Score"
#     _ String "FICO Level"
#     _ String "FICO Range"
#   }
#   "Sales Transactions" }o--o| "User Credit Cards" : "(`Card` == `Card`) & (`User` == `User`)"
#   "Sales Transactions" }o--o| "Users" : "`User` == `User`"
#   "User Credit Cards" }o--o| "Credit Card Info" : "`Retailer ID` == `Retailer ID`"
#   "Users" }o--o| "loans" : "`User` == `User`"
#   "Users" }o--o| "FICO" : "`FICO Score` == `FICO Score`"

# %% [markdown]
# ## Analyze and Create New Hierarchies, Levels, and Measures

# %%
# Set variables for hierarchies, levels, and measures
h, l, m = cube.hierarchies, cube.levels, cube.measures

# %%
cube.create_date_hierarchy(
    "Transaction Date",
    column=cc_sales_table["Datetime"],
    levels={
        "Year": "yyyy",
        "Quarter": "QQQ",
        "Month": "MMM",
        "Day": "dd",
        "Hour": "HH",
    },
    #   levels={"Year": "yyyy", "Quarter": "QQQ", "Month": "MMM", "Day": "dd", "Hour": "HH", "Minute": "mm", "Second": "ss"},
)

# %%
h["Retailer Levels"] = [
    l["Level 1"],
    l["Level 2"],
    l["Level 3"],
    l["Level 4"],
    l["Level 5"],
]
del h["Level 1"]
del h["Level 2"]
del h["Level 3"]
del h["Level 4"]
del h["Level 5"]

# %%
# Create measures from joined table numerical columns
m["Total Debt"] = tt.agg.sum(
    tt.agg.single_value(users_table["Total Debt"]), scope=tt.OriginScope(l["User"])
)
m["Income Annual"] = tt.agg.single_value(users_table["Yearly Income - Person"])
m["Num Credit Cards"] = tt.agg.count_distinct(user_cc_table["Card Number"])

# %%
m["Amount"] = tt.agg.sum(cc_sales_table["Amount"])
m["Credit_Limit"] = tt.agg.single_value(user_cc_table["Credit Limit"])
m["Credit Limit"] = tt.agg.sum(
    m["Credit_Limit"], scope=tt.OriginScope(l["Card Number"])
)
m["Utilization"] = m["Amount"] / m["Credit Limit"]
m["Utilization"].formatter = "DOUBLE[0.00%]"

# %%
m["PD12"] = tt.agg.mean(
    tt.agg.single_value(users_table["PD12"]), scope=tt.OriginScope(l["User"])
)
m["PD12"].formatter = "DOUBLE[0.00%]"
m["PDLT"] = tt.agg.mean(
    tt.agg.single_value(users_table["PDLT"]), scope=tt.OriginScope(l["User"])
)
m["PDLT"].formatter = "DOUBLE[0.00%]"
m["LGD"] = tt.agg.mean(
    tt.agg.single_value(users_table["LGD"]), scope=tt.OriginScope(l["User"])
)
m["LGD"].formatter = "DOUBLE[0.00%]"
m["EAD"] = m["Amount"]
m["ECL"] = tt.agg.sum_product(
    m["Amount"], m["LGD"], m["PD12"], scope=tt.OriginScope(l["User"])
)

# %%
m["PD12"].folder = "Credit Risk"
m["PDLT"].folder = "Credit Risk"
m["LGD"].folder = "Credit Risk"
m["EAD"].folder = "Credit Risk"
m["ECL"].folder = "Credit Risk"

# %%
m["Revolving Balance"] = tt.agg.sum(
    tt.agg.single_value(user_loans_table["Revolving Bal"]),
    scope=tt.OriginScope(l["User"]),
)
m["Interest Rate"] = tt.agg.single_value(user_loans_table["Interest Rate"])
m["Days with Credit Line"] = tt.agg.single_value(
    user_loans_table["Days with Credit Line"]
)
m["Revolving Utilization"] = tt.agg.sum(
    tt.agg.single_value(user_loans_table["Revol_Util"]), scope=tt.OriginScope(l["User"])
)

# %%
l["Income Range"].order = tt.CustomOrder(
    first_elements=[
        "0K - 20K",
        "20K - 50K",
        "50K - 80K",
        "80K - 100K",
        "100K - 150K",
        "150K - 200K",
        "200K+",
    ]
)

# %%
l["FICO Level"].order = tt.CustomOrder(
    first_elements=["Poor", "Fair", "Good", "Very Good", "Exceptional"]
)
